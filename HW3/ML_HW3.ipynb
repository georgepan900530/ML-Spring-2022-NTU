# %% [markdown]
# # HW3 Image Classification
# ## We strongly recommend that you run with Kaggle for this homework
# https://www.kaggle.com/c/ml2022spring-hw3b/code?competitionId=34954&sortBy=dateCreated

# %% [markdown]
# # Get Data
# Notes: if the links are dead, you can download the data directly from Kaggle and upload it to the workspace, or you can use the Kaggle API to directly download the data into colab.

# %%
# ! wget https://www.dropbox.com/s/6l2vcvxl54b0b6w/food11.zip

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip /content/drive/MyDrive/ML/HW3/food11.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: food11/training/8_805.jpg
#   inflating: food11/training/8_806.jpg
#   inflating: food11/training/8_807.jpg
#   inflating: food11/training/8_808.jpg
#   inflating: food11/training/8_809.jpg
#   inflating: food11/training/8_81.jpg
#   inflating: food11/training/8_810.jpg
#   inflating: food11/training/8_811.jpg
#   inflating: food11/training/8_812.jpg
#   inflating: food11/training/8_813.jpg
#   inflating: food11/training/8_814.jpg
#   inflating: food11/training/8_815.jpg
#   inflating: food11/training/8_816.jpg
#   inflating: food11/training/8_817.jpg
#   inflating: food11/training/8_818.jpg
#   inflating: food11/training/8_819.jpg
#   inflating: food11/training/8_82.jpg
#   inflating: food11/training/8_820.jpg
#   inflating: food11/training/8_821.jpg
#   inflating: food11/training/8_822.jpg
#   inflating: food11/training/8_823.jpg
#   inflating: food11/training/8_824.jpg
#   inflating: food11/training/8_825.jpg
#   inflating: food11/training/8_826.jpg
#   inflating: food11/training/8_827.jpg
#   inflating: food11/training/8_828.jpg
#   inflating: food11/training/8_829.jpg
#   inflating: food11/training/8_83.jpg
#   inflating: food11/training/8_830.jpg
#   inflating: food11/training/8_831.jpg
#   inflating: food11/training/8_832.jpg
#   inflating: food11/training/8_833.jpg
#   inflating: food11/training/8_834.jpg
#   inflating: food11/training/8_835.jpg
#   inflating: food11/training/8_836.jpg
#   inflating: food11/training/8_837.jpg
#   inflating: food11/training/8_838.jpg
#   inflating: food11/training/8_839.jpg
#   inflating: food11/training/8_84.jpg
#   inflating: food11/training/8_840.jpg
#   inflating: food11/training/8_841.jpg
#   inflating: food11/training/8_842.jpg
#   inflating: food11/training/8_843.jpg
#   inflating: food11/training/8_844.jpg
#   inflating: food11/training/8_845.jpg
#   inflating: food11/training/8_846.jpg
#   inflating: food11/training/8_847.jpg
#   inflating: food11/training/8_848.jpg
#   inflating: food11/training/8_849.jpg
#   inflating: food11/training/8_85.jpg
#   inflating: food11/training/8_850.jpg
#   inflating: food11/training/8_851.jpg
#   inflating: food11/training/8_852.jpg
#   inflating: food11/training/8_853.jpg
#   inflating: food11/training/8_854.jpg
#   inflating: food11/training/8_86.jpg
#   inflating: food11/training/8_87.jpg
#   inflating: food11/training/8_88.jpg
#   inflating: food11/training/8_89.jpg
#   inflating: food11/training/8_9.jpg
#   inflating: food11/training/8_90.jpg
#   inflating: food11/training/8_91.jpg
#   inflating: food11/training/8_92.jpg
#   inflating: food11/training/8_93.jpg
#   inflating: food11/training/8_94.jpg
#   inflating: food11/training/8_95.jpg
#   inflating: food11/training/8_96.jpg
#   inflating: food11/training/8_97.jpg
#   inflating: food11/training/8_98.jpg
#   inflating: food11/training/8_99.jpg
#   inflating: food11/training/9_0.jpg
#   inflating: food11/training/9_1.jpg
#   inflating: food11/training/9_10.jpg
#   inflating: food11/training/9_100.jpg
#   inflating: food11/training/9_1000.jpg
#   inflating: food11/training/9_1001.jpg
#   inflating: food11/training/9_1002.jpg
#   inflating: food11/training/9_1003.jpg
#   inflating: food11/training/9_1004.jpg
#   inflating: food11/training/9_1005.jpg
#   inflating: food11/training/9_1006.jpg
#   inflating: food11/training/9_1007.jpg
#   inflating: food11/training/9_1008.jpg
#   inflating: food11/training/9_1009.jpg
#   inflating: food11/training/9_101.jpg
#   inflating: food11/training/9_1010.jpg
#   inflating: food11/training/9_1011.jpg
#   inflating: food11/training/9_1012.jpg
#   inflating: food11/training/9_1013.jpg
#   inflating: food11/training/9_1014.jpg
#   inflating: food11/training/9_1015.jpg
#   inflating: food11/training/9_1016.jpg
#   inflating: food11/training/9_1017.jpg
#   inflating: food11/training/9_1018.jpg
#   inflating: food11/training/9_1019.jpg
#   inflating: food11/training/9_102.jpg
#   inflating: food11/training/9_1020.jpg
#   inflating: food11/training/9_1021.jpg
#   inflating: food11/training/9_1022.jpg
#   inflating: food11/training/9_1023.jpg
#   inflating: food11/training/9_1024.jpg
#   inflating: food11/training/9_1025.jpg
#   inflating: food11/training/9_1026.jpg
#   inflating: food11/training/9_1027.jpg
#   inflating: food11/training/9_1028.jpg
#   inflating: food11/training/9_1029.jpg
#   inflating: food11/training/9_103.jpg
#   inflating: food11/training/9_1030.jpg
#   inflating: food11/training/9_1031.jpg
#   inflating: food11/training/9_1032.jpg
#   inflating: food11/training/9_1033.jpg
#   inflating: food11/training/9_1034.jpg
#   inflating: food11/training/9_1035.jpg
#   inflating: food11/training/9_1036.jpg
#   inflating: food11/training/9_1037.jpg
#   inflating: food11/training/9_1038.jpg
#   inflating: food11/training/9_1039.jpg
#   inflating: food11/training/9_104.jpg
#   inflating: food11/training/9_1040.jpg
#   inflating: food11/training/9_1041.jpg
#   inflating: food11/training/9_1042.jpg
#   inflating: food11/training/9_1043.jpg
#   inflating: food11/training/9_1044.jpg
#   inflating: food11/training/9_1045.jpg
#   inflating: food11/training/9_1046.jpg
#   inflating: food11/training/9_1047.jpg
#   inflating: food11/training/9_1048.jpg
#   inflating: food11/training/9_1049.jpg
#   inflating: food11/training/9_105.jpg
#   inflating: food11/training/9_1050.jpg
#   inflating: food11/training/9_1051.jpg
#   inflating: food11/training/9_1052.jpg
#   inflating: food11/training/9_1053.jpg
#   inflating: food11/training/9_1054.jpg
#   inflating: food11/training/9_1055.jpg
#   inflating: food11/training/9_1056.jpg
#   inflating: food11/training/9_1057.jpg
#   inflating: food11/training/9_1058.jpg
#   inflating: food11/training/9_1059.jpg
#   inflating: food11/training/9_106.jpg
#   inflating: food11/training/9_1060.jpg
#   inflating: food11/training/9_1061.jpg
#   inflating: food11/training/9_1062.jpg
#   inflating: food11/training/9_1063.jpg
#   inflating: food11/training/9_1064.jpg
#   inflating: food11/training/9_1065.jpg
#   inflating: food11/training/9_1066.jpg
#   inflating: food11/training/9_1067.jpg
#   inflating: food11/training/9_1068.jpg
#   inflating: food11/training/9_1069.jpg
#   inflating: food11/training/9_107.jpg
#   inflating: food11/training/9_1070.jpg
#   inflating: food11/training/9_1071.jpg
#   inflating: food11/training/9_1072.jpg
#   inflating: food11/training/9_1073.jpg
#   inflating: food11/training/9_1074.jpg
#   inflating: food11/training/9_1075.jpg
#   inflating: food11/training/9_1076.jpg
#   inflating: food11/training/9_1077.jpg
#   inflating: food11/training/9_1078.jpg
#   inflating: food11/training/9_1079.jpg
#   inflating: food11/training/9_108.jpg
#   inflating: food11/training/9_1080.jpg
#   inflating: food11/training/9_1081.jpg
#   inflating: food11/training/9_1082.jpg
#   inflating: food11/training/9_1083.jpg
#   inflating: food11/training/9_1084.jpg
#   inflating: food11/training/9_1085.jpg
#   inflating: food11/training/9_1086.jpg
#   inflating: food11/training/9_1087.jpg
#   inflating: food11/training/9_1088.jpg
#   inflating: food11/training/9_1089.jpg
#   inflating: food11/training/9_109.jpg
#   inflating: food11/training/9_1090.jpg
#   inflating: food11/training/9_1091.jpg
#   inflating: food11/training/9_1092.jpg
#   inflating: food11/training/9_1093.jpg
#   inflating: food11/training/9_1094.jpg
#   inflating: food11/training/9_1095.jpg
#   inflating: food11/training/9_1096.jpg
#   inflating: food11/training/9_1097.jpg
#   inflating: food11/training/9_1098.jpg
#   inflating: food11/training/9_1099.jpg
#   inflating: food11/training/9_11.jpg
#   inflating: food11/training/9_110.jpg
#   inflating: food11/training/9_1100.jpg
#   inflating: food11/training/9_1101.jpg
#   inflating: food11/training/9_1102.jpg
#   inflating: food11/training/9_1103.jpg
#   inflating: food11/training/9_1104.jpg
#   inflating: food11/training/9_1105.jpg
#   inflating: food11/training/9_1106.jpg
#   inflating: food11/training/9_1107.jpg
#   inflating: food11/training/9_1108.jpg
#   inflating: food11/training/9_1109.jpg
#   inflating: food11/training/9_111.jpg
#   inflating: food11/training/9_1110.jpg
#   inflating: food11/training/9_1111.jpg
#   inflating: food11/training/9_1112.jpg
#   inflating: food11/training/9_1113.jpg
#   inflating: food11/training/9_1114.jpg
#   inflating: food11/training/9_1115.jpg
#   inflating: food11/training/9_1116.jpg
#   inflating: food11/training/9_1117.jpg
#   inflating: food11/training/9_1118.jpg
#   inflating: food11/training/9_1119.jpg
#   inflating: food11/training/9_112.jpg
#   inflating: food11/training/9_1120.jpg
#   inflating: food11/training/9_1121.jpg
#   inflating: food11/training/9_1122.jpg
#   inflating: food11/training/9_1123.jpg
#   inflating: food11/training/9_1124.jpg
#   inflating: food11/training/9_1125.jpg
#   inflating: food11/training/9_1126.jpg
#   inflating: food11/training/9_1127.jpg
#   inflating: food11/training/9_1128.jpg
#   inflating: food11/training/9_1129.jpg
#   inflating: food11/training/9_113.jpg
#   inflating: food11/training/9_1130.jpg
#   inflating: food11/training/9_1131.jpg
#   inflating: food11/training/9_1132.jpg
#   inflating: food11/training/9_1133.jpg
#   inflating: food11/training/9_1134.jpg
#   inflating: food11/training/9_1135.jpg
#   inflating: food11/training/9_1136.jpg
#   inflating: food11/training/9_1137.jpg
#   inflating: food11/training/9_1138.jpg
#   inflating: food11/training/9_1139.jpg
#   inflating: food11/training/9_114.jpg
#   inflating: food11/training/9_1140.jpg
#   inflating: food11/training/9_1141.jpg
#   inflating: food11/training/9_1142.jpg
#   inflating: food11/training/9_1143.jpg
#   inflating: food11/training/9_1144.jpg
#   inflating: food11/training/9_1145.jpg
#   inflating: food11/training/9_1146.jpg
#   inflating: food11/training/9_1147.jpg
#   inflating: food11/training/9_1148.jpg
#   inflating: food11/training/9_1149.jpg
#   inflating: food11/training/9_115.jpg
#   inflating: food11/training/9_1150.jpg
#   inflating: food11/training/9_1151.jpg
#   inflating: food11/training/9_1152.jpg
#   inflating: food11/training/9_1153.jpg
#   inflating: food11/training/9_1154.jpg
#   inflating: food11/training/9_1155.jpg
#   inflating: food11/training/9_1156.jpg
#   inflating: food11/training/9_1157.jpg
#   inflating: food11/training/9_1158.jpg
#   inflating: food11/training/9_1159.jpg
#   inflating: food11/training/9_116.jpg
#   inflating: food11/training/9_1160.jpg
#   inflating: food11/training/9_1161.jpg
#   inflating: food11/training/9_1162.jpg
#   inflating: food11/training/9_1163.jpg
#   inflating: food11/training/9_1164.jpg
#   inflating: food11/training/9_1165.jpg
#   inflating: food11/training/9_1166.jpg
#   inflating: food11/training/9_1167.jpg
#   inflating: food11/training/9_1168.jpg
#   inflating: food11/training/9_1169.jpg
#   inflating: food11/training/9_117.jpg
#   inflating: food11/training/9_1170.jpg
#   inflating: food11/training/9_1171.jpg
#   inflating: food11/training/9_1172.jpg
#   inflating: food11/training/9_1173.jpg
#   inflating: food11/training/9_1174.jpg
#   inflating: food11/training/9_1175.jpg
#   inflating: food11/training/9_1176.jpg
#   inflating: food11/training/9_1177.jpg
#   inflating: food11/training/9_1178.jpg
#   inflating: food11/training/9_1179.jpg
#   inflating: food11/training/9_118.jpg
#   inflating: food11/training/9_1180.jpg
#   inflating: food11/training/9_1181.jpg
#   inflating: food11/training/9_1182.jpg
#   inflating: food11/training/9_1183.jpg
#   inflating: food11/training/9_1184.jpg
#   inflating: food11/training/9_1185.jpg
#   inflating: food11/training/9_1186.jpg
#   inflating: food11/training/9_1187.jpg
#   inflating: food11/training/9_1188.jpg
#   inflating: food11/training/9_1189.jpg
#   inflating: food11/training/9_119.jpg
#   inflating: food11/training/9_1190.jpg
#   inflating: food11/training/9_1191.jpg
#   inflating: food11/training/9_1192.jpg
#   inflating: food11/training/9_1193.jpg
#   inflating: food11/training/9_1194.jpg
#   inflating: food11/training/9_1195.jpg
#   inflating: food11/training/9_1196.jpg
#   inflating: food11/training/9_1197.jpg
#   inflating: food11/training/9_1198.jpg
#   inflating: food11/training/9_1199.jpg
#   inflating: food11/training/9_12.jpg
#   inflating: food11/training/9_120.jpg
#   inflating: food11/training/9_1200.jpg
#   inflating: food11/training/9_1201.jpg
#   inflating: food11/training/9_1202.jpg
#   inflating: food11/training/9_1203.jpg
#   inflating: food11/training/9_1204.jpg
#   inflating: food11/training/9_1205.jpg
#   inflating: food11/training/9_1206.jpg
#   inflating: food11/training/9_1207.jpg
#   inflating: food11/training/9_1208.jpg
#   inflating: food11/training/9_1209.jpg
#   inflating: food11/training/9_121.jpg
#   inflating: food11/training/9_1210.jpg
#   inflating: food11/training/9_1211.jpg
#   inflating: food11/training/9_1212.jpg
#   inflating: food11/training/9_1213.jpg
#   inflating: food11/training/9_1214.jpg
#   inflating: food11/training/9_1215.jpg
#   inflating: food11/training/9_1216.jpg
#   inflating: food11/training/9_1217.jpg
#   inflating: food11/training/9_1218.jpg
#   inflating: food11/training/9_1219.jpg
#   inflating: food11/training/9_122.jpg
#   inflating: food11/training/9_1220.jpg
#   inflating: food11/training/9_1221.jpg
#   inflating: food11/training/9_1222.jpg
#   inflating: food11/training/9_1223.jpg
#   inflating: food11/training/9_1224.jpg
#   inflating: food11/training/9_1225.jpg
#   inflating: food11/training/9_1226.jpg
#   inflating: food11/training/9_1227.jpg
#   inflating: food11/training/9_1228.jpg
#   inflating: food11/training/9_1229.jpg
#   inflating: food11/training/9_123.jpg
#   inflating: food11/training/9_1230.jpg
#   inflating: food11/training/9_1231.jpg
#   inflating: food11/training/9_1232.jpg
#   inflating: food11/training/9_1233.jpg
#   inflating: food11/training/9_1234.jpg
#   inflating: food11/training/9_1235.jpg
#   inflating: food11/training/9_1236.jpg
#   inflating: food11/training/9_1237.jpg
#   inflating: food11/training/9_1238.jpg
#   inflating: food11/training/9_1239.jpg
#   inflating: food11/training/9_124.jpg
#   inflating: food11/training/9_1240.jpg
#   inflating: food11/training/9_1241.jpg
#   inflating: food11/training/9_1242.jpg
#   inflating: food11/training/9_1243.jpg
#   inflating: food11/training/9_1244.jpg
#   inflating: food11/training/9_1245.jpg
#   inflating: food11/training/9_1246.jpg
#   inflating: food11/training/9_1247.jpg
#   inflating: food11/training/9_1248.jpg
#   inflating: food11/training/9_1249.jpg
#   inflating: food11/training/9_125.jpg
#   inflating: food11/training/9_1250.jpg
#   inflating: food11/training/9_1251.jpg
#   inflating: food11/training/9_1252.jpg
#   inflating: food11/training/9_1253.jpg
#   inflating: food11/training/9_1254.jpg
#   inflating: food11/training/9_1255.jpg
#   inflating: food11/training/9_1256.jpg
#   inflating: food11/training/9_1257.jpg
#   inflating: food11/training/9_1258.jpg
#   inflating: food11/training/9_1259.jpg
#   inflating: food11/training/9_126.jpg
#   inflating: food11/training/9_1260.jpg
#   inflating: food11/training/9_1261.jpg
#   inflating: food11/training/9_1262.jpg
#   inflating: food11/training/9_1263.jpg
#   inflating: food11/training/9_1264.jpg
#   inflating: food11/training/9_1265.jpg
#   inflating: food11/training/9_1266.jpg
#   inflating: food11/training/9_1267.jpg
#   inflating: food11/training/9_1268.jpg
#   inflating: food11/training/9_1269.jpg
#   inflating: food11/training/9_127.jpg
#   inflating: food11/training/9_1270.jpg
#   inflating: food11/training/9_1271.jpg
#   inflating: food11/training/9_1272.jpg
#   inflating: food11/training/9_1273.jpg
#   inflating: food11/training/9_1274.jpg
#   inflating: food11/training/9_1275.jpg
#   inflating: food11/training/9_1276.jpg
#   inflating: food11/training/9_1277.jpg
#   inflating: food11/training/9_1278.jpg
#   inflating: food11/training/9_1279.jpg
#   inflating: food11/training/9_128.jpg
#   inflating: food11/training/9_1280.jpg
#   inflating: food11/training/9_1281.jpg
#   inflating: food11/training/9_1282.jpg
#   inflating: food11/training/9_1283.jpg
#   inflating: food11/training/9_1284.jpg
#   inflating: food11/training/9_1285.jpg
#   inflating: food11/training/9_1286.jpg
#   inflating: food11/training/9_1287.jpg
#   inflating: food11/training/9_1288.jpg
#   inflating: food11/training/9_1289.jpg
#   inflating: food11/training/9_129.jpg
#   inflating: food11/training/9_1290.jpg
#   inflating: food11/training/9_1291.jpg
#   inflating: food11/training/9_1292.jpg
#   inflating: food11/training/9_1293.jpg
#   inflating: food11/training/9_1294.jpg
#   inflating: food11/training/9_1295.jpg
#   inflating: food11/training/9_1296.jpg
#   inflating: food11/training/9_1297.jpg
#   inflating: food11/training/9_1298.jpg
#   inflating: food11/training/9_1299.jpg
#   inflating: food11/training/9_13.jpg
#   inflating: food11/training/9_130.jpg
#   inflating: food11/training/9_1300.jpg
#   inflating: food11/training/9_1301.jpg
#   inflating: food11/training/9_1302.jpg
#   inflating: food11/training/9_1303.jpg
#   inflating: food11/training/9_1304.jpg
#   inflating: food11/training/9_1305.jpg
#   inflating: food11/training/9_1306.jpg
#   inflating: food11/training/9_1307.jpg
#   inflating: food11/training/9_1308.jpg
#   inflating: food11/training/9_1309.jpg
#   inflating: food11/training/9_131.jpg
#   inflating: food11/training/9_1310.jpg
#   inflating: food11/training/9_1311.jpg
#   inflating: food11/training/9_1312.jpg
#   inflating: food11/training/9_1313.jpg
#   inflating: food11/training/9_1314.jpg
#   inflating: food11/training/9_1315.jpg
#   inflating: food11/training/9_1316.jpg
#   inflating: food11/training/9_1317.jpg
#   inflating: food11/training/9_1318.jpg
#   inflating: food11/training/9_1319.jpg
#   inflating: food11/training/9_132.jpg
#   inflating: food11/training/9_1320.jpg
#   inflating: food11/training/9_1321.jpg
#   inflating: food11/training/9_1322.jpg
#   inflating: food11/training/9_1323.jpg
#   inflating: food11/training/9_1324.jpg
#   inflating: food11/training/9_1325.jpg
#   inflating: food11/training/9_1326.jpg
#   inflating: food11/training/9_1327.jpg
#   inflating: food11/training/9_1328.jpg
#   inflating: food11/training/9_1329.jpg
#   inflating: food11/training/9_133.jpg
#   inflating: food11/training/9_1330.jpg
#   inflating: food11/training/9_1331.jpg
#   inflating: food11/training/9_1332.jpg
#   inflating: food11/training/9_1333.jpg
#   inflating: food11/training/9_1334.jpg
#   inflating: food11/training/9_1335.jpg
#   inflating: food11/training/9_1336.jpg
#   inflating: food11/training/9_1337.jpg
#   inflating: food11/training/9_1338.jpg
#   inflating: food11/training/9_1339.jpg
#   inflating: food11/training/9_134.jpg
#   inflating: food11/training/9_1340.jpg
#   inflating: food11/training/9_1341.jpg
#   inflating: food11/training/9_1342.jpg
#   inflating: food11/training/9_1343.jpg
#   inflating: food11/training/9_1344.jpg
#   inflating: food11/training/9_1345.jpg
#   inflating: food11/training/9_1346.jpg
#   inflating: food11/training/9_1347.jpg
#   inflating: food11/training/9_1348.jpg
#   inflating: food11/training/9_1349.jpg
#   inflating: food11/training/9_135.jpg
#   inflating: food11/training/9_1350.jpg
#   inflating: food11/training/9_1351.jpg
#   inflating: food11/training/9_1352.jpg
#   inflating: food11/training/9_1353.jpg
#   inflating: food11/training/9_1354.jpg
#   inflating: food11/training/9_1355.jpg
#   inflating: food11/training/9_1356.jpg
#   inflating: food11/training/9_1357.jpg
#   inflating: food11/training/9_1358.jpg
#   inflating: food11/training/9_1359.jpg
#   inflating: food11/training/9_136.jpg
#   inflating: food11/training/9_1360.jpg
#   inflating: food11/training/9_1361.jpg
#   inflating: food11/training/9_1362.jpg
#   inflating: food11/training/9_1363.jpg
#   inflating: food11/training/9_1364.jpg
#   inflating: food11/training/9_1365.jpg
#   inflating: food11/training/9_1366.jpg
#   inflating: food11/training/9_1367.jpg
#   inflating: food11/training/9_1368.jpg
#   inflating: food11/training/9_1369.jpg
#   inflating: food11/training/9_137.jpg
#   inflating: food11/training/9_1370.jpg
#   inflating: food11/training/9_1371.jpg
#   inflating: food11/training/9_1372.jpg
#   inflating: food11/training/9_1373.jpg
#   inflating: food11/training/9_1374.jpg
#   inflating: food11/training/9_1375.jpg
#   inflating: food11/training/9_1376.jpg
#   inflating: food11/training/9_1377.jpg
#   inflating: food11/training/9_1378.jpg
#   inflating: food11/training/9_1379.jpg
#   inflating: food11/training/9_138.jpg
#   inflating: food11/training/9_1380.jpg
#   inflating: food11/training/9_1381.jpg
#   inflating: food11/training/9_1382.jpg
#   inflating: food11/training/9_1383.jpg
#   inflating: food11/training/9_1384.jpg
#   inflating: food11/training/9_1385.jpg
#   inflating: food11/training/9_1386.jpg
#   inflating: food11/training/9_1387.jpg
#   inflating: food11/training/9_1388.jpg
#   inflating: food11/training/9_1389.jpg
#   inflating: food11/training/9_139.jpg
#   inflating: food11/training/9_1390.jpg
#   inflating: food11/training/9_1391.jpg
#   inflating: food11/training/9_1392.jpg
#   inflating: food11/training/9_1393.jpg
#   inflating: food11/training/9_1394.jpg
#   inflating: food11/training/9_1395.jpg
#   inflating: food11/training/9_1396.jpg
#   inflating: food11/training/9_1397.jpg
#   inflating: food11/training/9_1398.jpg
#   inflating: food11/training/9_1399.jpg
#   inflating: food11/training/9_14.jpg
#   inflating: food11/training/9_140.jpg
#   inflating: food11/training/9_1400.jpg
#   inflating: food11/training/9_1401.jpg
#   inflating: food11/training/9_1402.jpg
#   inflating: food11/training/9_1403.jpg
#   inflating: food11/training/9_1404.jpg
#   inflating: food11/training/9_1405.jpg
#   inflating: food11/training/9_1406.jpg
#   inflating: food11/training/9_1407.jpg
#   inflating: food11/training/9_1408.jpg
#   inflating: food11/training/9_1409.jpg
#   inflating: food11/training/9_141.jpg
#   inflating: food11/training/9_1410.jpg
#   inflating: food11/training/9_1411.jpg
#   inflating: food11/training/9_1412.jpg
#   inflating: food11/training/9_1413.jpg
#   inflating: food11/training/9_1414.jpg
#   inflating: food11/training/9_1415.jpg
#   inflating: food11/training/9_1416.jpg
#   inflating: food11/training/9_1417.jpg
#   inflating: food11/training/9_1418.jpg
#   inflating: food11/training/9_1419.jpg
#   inflating: food11/training/9_142.jpg
#   inflating: food11/training/9_1420.jpg
#   inflating: food11/training/9_1421.jpg
#   inflating: food11/training/9_1422.jpg
#   inflating: food11/training/9_1423.jpg
#   inflating: food11/training/9_1424.jpg
#   inflating: food11/training/9_1425.jpg
#   inflating: food11/training/9_1426.jpg
#   inflating: food11/training/9_1427.jpg
#   inflating: food11/training/9_1428.jpg
#   inflating: food11/training/9_1429.jpg
#   inflating: food11/training/9_143.jpg
#   inflating: food11/training/9_1430.jpg
#   inflating: food11/training/9_1431.jpg
#   inflating: food11/training/9_1432.jpg
#   inflating: food11/training/9_1433.jpg
#   inflating: food11/training/9_1434.jpg
#   inflating: food11/training/9_1435.jpg
#   inflating: food11/training/9_1436.jpg
#   inflating: food11/training/9_1437.jpg
#   inflating: food11/training/9_1438.jpg
#   inflating: food11/training/9_1439.jpg
#   inflating: food11/training/9_144.jpg
#   inflating: food11/training/9_1440.jpg
#   inflating: food11/training/9_1441.jpg
#   inflating: food11/training/9_1442.jpg
#   inflating: food11/training/9_1443.jpg
#   inflating: food11/training/9_1444.jpg
#   inflating: food11/training/9_1445.jpg
#   inflating: food11/training/9_1446.jpg
#   inflating: food11/training/9_1447.jpg
#   inflating: food11/training/9_1448.jpg
#   inflating: food11/training/9_1449.jpg
#   inflating: food11/training/9_145.jpg
#   inflating: food11/training/9_1450.jpg
#   inflating: food11/training/9_1451.jpg
#   inflating: food11/training/9_1452.jpg
#   inflating: food11/training/9_1453.jpg
#   inflating: food11/training/9_1454.jpg
#   inflating: food11/training/9_1455.jpg
#   inflating: food11/training/9_1456.jpg
#   inflating: food11/training/9_1457.jpg
#   inflating: food11/training/9_1458.jpg
#   inflating: food11/training/9_1459.jpg
#   inflating: food11/training/9_146.jpg
#   inflating: food11/training/9_1460.jpg
#   inflating: food11/training/9_1461.jpg
#   inflating: food11/training/9_1462.jpg
#   inflating: food11/training/9_1463.jpg
#   inflating: food11/training/9_1464.jpg
#   inflating: food11/training/9_1465.jpg
#   inflating: food11/training/9_1466.jpg
#   inflating: food11/training/9_1467.jpg
#   inflating: food11/training/9_1468.jpg
#   inflating: food11/training/9_1469.jpg
#   inflating: food11/training/9_147.jpg
#   inflating: food11/training/9_1470.jpg
#   inflating: food11/training/9_1471.jpg
#   inflating: food11/training/9_1472.jpg
#   inflating: food11/training/9_1473.jpg
#   inflating: food11/training/9_1474.jpg
#   inflating: food11/training/9_1475.jpg
#   inflating: food11/training/9_1476.jpg
#   inflating: food11/training/9_1477.jpg
#   inflating: food11/training/9_1478.jpg
#   inflating: food11/training/9_1479.jpg
#   inflating: food11/training/9_148.jpg
#   inflating: food11/training/9_1480.jpg
#   inflating: food11/training/9_1481.jpg
#   inflating: food11/training/9_1482.jpg
#   inflating: food11/training/9_1483.jpg
#   inflating: food11/training/9_1484.jpg
#   inflating: food11/training/9_1485.jpg
#   inflating: food11/training/9_1486.jpg
#   inflating: food11/training/9_1487.jpg
#   inflating: food11/training/9_1488.jpg
#   inflating: food11/training/9_1489.jpg
#   inflating: food11/training/9_149.jpg
#   inflating: food11/training/9_1490.jpg
#   inflating: food11/training/9_1491.jpg
#   inflating: food11/training/9_1492.jpg
#   inflating: food11/training/9_1493.jpg
#   inflating: food11/training/9_1494.jpg
#   inflating: food11/training/9_1495.jpg
#   inflating: food11/training/9_1496.jpg
#   inflating: food11/training/9_1497.jpg
#   inflating: food11/training/9_1498.jpg
#   inflating: food11/training/9_1499.jpg
#   inflating: food11/training/9_15.jpg
#   inflating: food11/training/9_150.jpg
#   inflating: food11/training/9_151.jpg
#   inflating: food11/training/9_152.jpg
#   inflating: food11/training/9_153.jpg
#   inflating: food11/training/9_154.jpg
#   inflating: food11/training/9_155.jpg
#   inflating: food11/training/9_156.jpg
#   inflating: food11/training/9_157.jpg
#   inflating: food11/training/9_158.jpg
#   inflating: food11/training/9_159.jpg
#   inflating: food11/training/9_16.jpg
#   inflating: food11/training/9_160.jpg
#   inflating: food11/training/9_161.jpg
#   inflating: food11/training/9_162.jpg
#   inflating: food11/training/9_163.jpg
#   inflating: food11/training/9_164.jpg
#   inflating: food11/training/9_165.jpg
#   inflating: food11/training/9_166.jpg
#   inflating: food11/training/9_167.jpg
#   inflating: food11/training/9_168.jpg
#   inflating: food11/training/9_169.jpg
#   inflating: food11/training/9_17.jpg
#   inflating: food11/training/9_170.jpg
#   inflating: food11/training/9_171.jpg
#   inflating: food11/training/9_172.jpg
#   inflating: food11/training/9_173.jpg
#   inflating: food11/training/9_174.jpg
#   inflating: food11/training/9_175.jpg
#   inflating: food11/training/9_176.jpg
#   inflating: food11/training/9_177.jpg
#   inflating: food11/training/9_178.jpg
#   inflating: food11/training/9_179.jpg
#   inflating: food11/training/9_18.jpg
#   inflating: food11/training/9_180.jpg
#   inflating: food11/training/9_181.jpg
#   inflating: food11/training/9_182.jpg
#   inflating: food11/training/9_183.jpg
#   inflating: food11/training/9_184.jpg
#   inflating: food11/training/9_185.jpg
#   inflating: food11/training/9_186.jpg
#   inflating: food11/training/9_187.jpg
#   inflating: food11/training/9_188.jpg
#   inflating: food11/training/9_189.jpg
#   inflating: food11/training/9_19.jpg
#   inflating: food11/training/9_190.jpg
#   inflating: food11/training/9_191.jpg
#   inflating: food11/training/9_192.jpg
#   inflating: food11/training/9_193.jpg
#   inflating: food11/training/9_194.jpg
#   inflating: food11/training/9_195.jpg
#   inflating: food11/training/9_196.jpg
#   inflating: food11/training/9_197.jpg
#   inflating: food11/training/9_198.jpg
#   inflating: food11/training/9_199.jpg
#   inflating: food11/training/9_2.jpg
#   inflating: food11/training/9_20.jpg
#   inflating: food11/training/9_200.jpg
#   inflating: food11/training/9_201.jpg
#   inflating: food11/training/9_202.jpg
#   inflating: food11/training/9_203.jpg
#   inflating: food11/training/9_204.jpg
#   inflating: food11/training/9_205.jpg
#   inflating: food11/training/9_206.jpg
#   inflating: food11/training/9_207.jpg
#   inflating: food11/training/9_208.jpg
#   inflating: food11/training/9_209.jpg
#   inflating: food11/training/9_21.jpg
#   inflating: food11/training/9_210.jpg
#   inflating: food11/training/9_211.jpg
#   inflating: food11/training/9_212.jpg
#   inflating: food11/training/9_213.jpg
#   inflating: food11/training/9_214.jpg
#   inflating: food11/training/9_215.jpg
#   inflating: food11/training/9_216.jpg
#   inflating: food11/training/9_217.jpg
#   inflating: food11/training/9_218.jpg
#   inflating: food11/training/9_219.jpg
#   inflating: food11/training/9_22.jpg
#   inflating: food11/training/9_220.jpg
#   inflating: food11/training/9_221.jpg
#   inflating: food11/training/9_222.jpg
#   inflating: food11/training/9_223.jpg
#   inflating: food11/training/9_224.jpg
#   inflating: food11/training/9_225.jpg
#   inflating: food11/training/9_226.jpg
#   inflating: food11/training/9_227.jpg
#   inflating: food11/training/9_228.jpg
#   inflating: food11/training/9_229.jpg
#   inflating: food11/training/9_23.jpg
#   inflating: food11/training/9_230.jpg
#   inflating: food11/training/9_231.jpg
#   inflating: food11/training/9_232.jpg
#   inflating: food11/training/9_233.jpg
#   inflating: food11/training/9_234.jpg
#   inflating: food11/training/9_235.jpg
#   inflating: food11/training/9_236.jpg
#   inflating: food11/training/9_237.jpg
#   inflating: food11/training/9_238.jpg
#   inflating: food11/training/9_239.jpg
#   inflating: food11/training/9_24.jpg
#   inflating: food11/training/9_240.jpg
#   inflating: food11/training/9_241.jpg
#   inflating: food11/training/9_242.jpg
#   inflating: food11/training/9_243.jpg
#   inflating: food11/training/9_244.jpg
#   inflating: food11/training/9_245.jpg
#   inflating: food11/training/9_246.jpg
#   inflating: food11/training/9_247.jpg
#   inflating: food11/training/9_248.jpg
#   inflating: food11/training/9_249.jpg
#   inflating: food11/training/9_25.jpg
#   inflating: food11/training/9_250.jpg
#   inflating: food11/training/9_251.jpg
#   inflating: food11/training/9_252.jpg
#   inflating: food11/training/9_253.jpg
#   inflating: food11/training/9_254.jpg
#   inflating: food11/training/9_255.jpg
#   inflating: food11/training/9_256.jpg
#   inflating: food11/training/9_257.jpg
#   inflating: food11/training/9_258.jpg
#   inflating: food11/training/9_259.jpg
#   inflating: food11/training/9_26.jpg
#   inflating: food11/training/9_260.jpg
#   inflating: food11/training/9_261.jpg
#   inflating: food11/training/9_262.jpg
#   inflating: food11/training/9_263.jpg
#   inflating: food11/training/9_264.jpg
#   inflating: food11/training/9_265.jpg
#   inflating: food11/training/9_266.jpg
#   inflating: food11/training/9_267.jpg
#   inflating: food11/training/9_268.jpg
#   inflating: food11/training/9_269.jpg
#   inflating: food11/training/9_27.jpg
#   inflating: food11/training/9_270.jpg
#   inflating: food11/training/9_271.jpg
#   inflating: food11/training/9_272.jpg
#   inflating: food11/training/9_273.jpg
#   inflating: food11/training/9_274.jpg
#   inflating: food11/training/9_275.jpg
#   inflating: food11/training/9_276.jpg
#   inflating: food11/training/9_277.jpg
#   inflating: food11/training/9_278.jpg
#   inflating: food11/training/9_279.jpg
#   inflating: food11/training/9_28.jpg
#   inflating: food11/training/9_280.jpg
#   inflating: food11/training/9_281.jpg
#   inflating: food11/training/9_282.jpg
#   inflating: food11/training/9_283.jpg
#   inflating: food11/training/9_284.jpg
#   inflating: food11/training/9_285.jpg
#   inflating: food11/training/9_286.jpg
#   inflating: food11/training/9_287.jpg
#   inflating: food11/training/9_288.jpg
#   inflating: food11/training/9_289.jpg
#   inflating: food11/training/9_29.jpg
#   inflating: food11/training/9_290.jpg
#   inflating: food11/training/9_291.jpg
#   inflating: food11/training/9_292.jpg
#   inflating: food11/training/9_293.jpg
#   inflating: food11/training/9_294.jpg
#   inflating: food11/training/9_295.jpg
#   inflating: food11/training/9_296.jpg
#   inflating: food11/training/9_297.jpg
#   inflating: food11/training/9_298.jpg
#   inflating: food11/training/9_299.jpg
#   inflating: food11/training/9_3.jpg
#   inflating: food11/training/9_30.jpg
#   inflating: food11/training/9_300.jpg
#   inflating: food11/training/9_301.jpg
#   inflating: food11/training/9_302.jpg
#   inflating: food11/training/9_303.jpg
#   inflating: food11/training/9_304.jpg
#   inflating: food11/training/9_305.jpg
#   inflating: food11/training/9_306.jpg
#   inflating: food11/training/9_307.jpg
#   inflating: food11/training/9_308.jpg
#   inflating: food11/training/9_309.jpg
#   inflating: food11/training/9_31.jpg
#   inflating: food11/training/9_310.jpg
#   inflating: food11/training/9_311.jpg
#   inflating: food11/training/9_312.jpg
#   inflating: food11/training/9_313.jpg
#   inflating: food11/training/9_314.jpg
#   inflating: food11/training/9_315.jpg
#   inflating: food11/training/9_316.jpg
#   inflating: food11/training/9_317.jpg
#   inflating: food11/training/9_318.jpg
#   inflating: food11/training/9_319.jpg
#   inflating: food11/training/9_32.jpg
#   inflating: food11/training/9_320.jpg
#   inflating: food11/training/9_321.jpg
#   inflating: food11/training/9_322.jpg
#   inflating: food11/training/9_323.jpg
#   inflating: food11/training/9_324.jpg
#   inflating: food11/training/9_325.jpg
#   inflating: food11/training/9_326.jpg
#   inflating: food11/training/9_327.jpg
#   inflating: food11/training/9_328.jpg
#   inflating: food11/training/9_329.jpg
#   inflating: food11/training/9_33.jpg
#   inflating: food11/training/9_330.jpg
#   inflating: food11/training/9_331.jpg
#   inflating: food11/training/9_332.jpg
#   inflating: food11/training/9_333.jpg
#   inflating: food11/training/9_334.jpg
#   inflating: food11/training/9_335.jpg
#   inflating: food11/training/9_336.jpg
#   inflating: food11/training/9_337.jpg
#   inflating: food11/training/9_338.jpg
#   inflating: food11/training/9_339.jpg
#   inflating: food11/training/9_34.jpg
#   inflating: food11/training/9_340.jpg
#   inflating: food11/training/9_341.jpg
#   inflating: food11/training/9_342.jpg
#   inflating: food11/training/9_343.jpg
#   inflating: food11/training/9_344.jpg
#   inflating: food11/training/9_345.jpg
#   inflating: food11/training/9_346.jpg
#   inflating: food11/training/9_347.jpg
#   inflating: food11/training/9_348.jpg
#   inflating: food11/training/9_349.jpg
#   inflating: food11/training/9_35.jpg
#   inflating: food11/training/9_350.jpg
#   inflating: food11/training/9_351.jpg
#   inflating: food11/training/9_352.jpg
#   inflating: food11/training/9_353.jpg
#   inflating: food11/training/9_354.jpg
#   inflating: food11/training/9_355.jpg
#   inflating: food11/training/9_356.jpg
#   inflating: food11/training/9_357.jpg
#   inflating: food11/training/9_358.jpg
#   inflating: food11/training/9_359.jpg
#   inflating: food11/training/9_36.jpg
#   inflating: food11/training/9_360.jpg
#   inflating: food11/training/9_361.jpg
#   inflating: food11/training/9_362.jpg
#   inflating: food11/training/9_363.jpg
#   inflating: food11/training/9_364.jpg
#   inflating: food11/training/9_365.jpg
#   inflating: food11/training/9_366.jpg
#   inflating: food11/training/9_367.jpg
#   inflating: food11/training/9_368.jpg
#   inflating: food11/training/9_369.jpg
#   inflating: food11/training/9_37.jpg
#   inflating: food11/training/9_370.jpg
#   inflating: food11/training/9_371.jpg
#   inflating: food11/training/9_372.jpg
#   inflating: food11/training/9_373.jpg
#   inflating: food11/training/9_374.jpg
#   inflating: food11/training/9_375.jpg
#   inflating: food11/training/9_376.jpg
#   inflating: food11/training/9_377.jpg
#   inflating: food11/training/9_378.jpg
#   inflating: food11/training/9_379.jpg
#   inflating: food11/training/9_38.jpg
#   inflating: food11/training/9_380.jpg
#   inflating: food11/training/9_381.jpg
#   inflating: food11/training/9_382.jpg
#   inflating: food11/training/9_383.jpg
#   inflating: food11/training/9_384.jpg
#   inflating: food11/training/9_385.jpg
#   inflating: food11/training/9_386.jpg
#   inflating: food11/training/9_387.jpg
#   inflating: food11/training/9_388.jpg
#   inflating: food11/training/9_389.jpg
#   inflating: food11/training/9_39.jpg
#   inflating: food11/training/9_390.jpg
#   inflating: food11/training/9_391.jpg
#   inflating: food11/training/9_392.jpg
#   inflating: food11/training/9_393.jpg
#   inflating: food11/training/9_394.jpg
#   inflating: food11/training/9_395.jpg
#   inflating: food11/training/9_396.jpg
#   inflating: food11/training/9_397.jpg
#   inflating: food11/training/9_398.jpg
#   inflating: food11/training/9_399.jpg
#   inflating: food11/training/9_4.jpg
#   inflating: food11/training/9_40.jpg
#   inflating: food11/training/9_400.jpg
#   inflating: food11/training/9_401.jpg
#   inflating: food11/training/9_402.jpg
#   inflating: food11/training/9_403.jpg
#   inflating: food11/training/9_404.jpg
#   inflating: food11/training/9_405.jpg
#   inflating: food11/training/9_406.jpg
#   inflating: food11/training/9_407.jpg
#   inflating: food11/training/9_408.jpg
#   inflating: food11/training/9_409.jpg
#   inflating: food11/training/9_41.jpg
#   inflating: food11/training/9_410.jpg
#   inflating: food11/training/9_411.jpg
#   inflating: food11/training/9_412.jpg
#   inflating: food11/training/9_413.jpg
#   inflating: food11/training/9_414.jpg
#   inflating: food11/training/9_415.jpg
#   inflating: food11/training/9_416.jpg
#   inflating: food11/training/9_417.jpg
#   inflating: food11/training/9_418.jpg
#   inflating: food11/training/9_419.jpg
#   inflating: food11/training/9_42.jpg
#   inflating: food11/training/9_420.jpg
#   inflating: food11/training/9_421.jpg
#   inflating: food11/training/9_422.jpg
#   inflating: food11/training/9_423.jpg
#   inflating: food11/training/9_424.jpg
#   inflating: food11/training/9_425.jpg
#   inflating: food11/training/9_426.jpg
#   inflating: food11/training/9_427.jpg
#   inflating: food11/training/9_428.jpg
#   inflating: food11/training/9_429.jpg
#   inflating: food11/training/9_43.jpg
#   inflating: food11/training/9_430.jpg
#   inflating: food11/training/9_431.jpg
#   inflating: food11/training/9_432.jpg
#   inflating: food11/training/9_433.jpg
#   inflating: food11/training/9_434.jpg
#   inflating: food11/training/9_435.jpg
#   inflating: food11/training/9_436.jpg
#   inflating: food11/training/9_437.jpg
#   inflating: food11/training/9_438.jpg
#   inflating: food11/training/9_439.jpg
#   inflating: food11/training/9_44.jpg
#   inflating: food11/training/9_440.jpg
#   inflating: food11/training/9_441.jpg
#   inflating: food11/training/9_442.jpg
#   inflating: food11/training/9_443.jpg
#   inflating: food11/training/9_444.jpg
#   inflating: food11/training/9_445.jpg
#   inflating: food11/training/9_446.jpg
#   inflating: food11/training/9_447.jpg
#   inflating: food11/training/9_448.jpg
#   inflating: food11/training/9_449.jpg
#   inflating: food11/training/9_45.jpg
#   inflating: food11/training/9_450.jpg
#   inflating: food11/training/9_451.jpg
#   inflating: food11/training/9_452.jpg
#   inflating: food11/training/9_453.jpg
#   inflating: food11/training/9_454.jpg
#   inflating: food11/training/9_455.jpg
#   inflating: food11/training/9_456.jpg
#   inflating: food11/training/9_457.jpg
#   inflating: food11/training/9_458.jpg
#   inflating: food11/training/9_459.jpg
#   inflating: food11/training/9_46.jpg
#   inflating: food11/training/9_460.jpg
#   inflating: food11/training/9_461.jpg
#   inflating: food11/training/9_462.jpg
#   inflating: food11/training/9_463.jpg
#   inflating: food11/training/9_464.jpg
#   inflating: food11/training/9_465.jpg
#   inflating: food11/training/9_466.jpg
#   inflating: food11/training/9_467.jpg
#   inflating: food11/training/9_468.jpg
#   inflating: food11/training/9_469.jpg
#   inflating: food11/training/9_47.jpg
#   inflating: food11/training/9_470.jpg
#   inflating: food11/training/9_471.jpg
#   inflating: food11/training/9_472.jpg
#   inflating: food11/training/9_473.jpg
#   inflating: food11/training/9_474.jpg
#   inflating: food11/training/9_475.jpg
#   inflating: food11/training/9_476.jpg
#   inflating: food11/training/9_477.jpg
#   inflating: food11/training/9_478.jpg
#   inflating: food11/training/9_479.jpg
#   inflating: food11/training/9_48.jpg
#   inflating: food11/training/9_480.jpg
#   inflating: food11/training/9_481.jpg
#   inflating: food11/training/9_482.jpg
#   inflating: food11/training/9_483.jpg
#   inflating: food11/training/9_484.jpg
#   inflating: food11/training/9_485.jpg
#   inflating: food11/training/9_486.jpg
#   inflating: food11/training/9_487.jpg
#   inflating: food11/training/9_488.jpg
#   inflating: food11/training/9_489.jpg
#   inflating: food11/training/9_49.jpg
#   inflating: food11/training/9_490.jpg
#   inflating: food11/training/9_491.jpg
#   inflating: food11/training/9_492.jpg
#   inflating: food11/training/9_493.jpg
#   inflating: food11/training/9_494.jpg
#   inflating: food11/training/9_495.jpg
#   inflating: food11/training/9_496.jpg
#   inflating: food11/training/9_497.jpg
#   inflating: food11/training/9_498.jpg
#   inflating: food11/training/9_499.jpg
#   inflating: food11/training/9_5.jpg
#   inflating: food11/training/9_50.jpg
#   inflating: food11/training/9_500.jpg
#   inflating: food11/training/9_501.jpg
#   inflating: food11/training/9_502.jpg
#   inflating: food11/training/9_503.jpg
#   inflating: food11/training/9_504.jpg
#   inflating: food11/training/9_505.jpg
#   inflating: food11/training/9_506.jpg
#   inflating: food11/training/9_507.jpg
#   inflating: food11/training/9_508.jpg
#   inflating: food11/training/9_509.jpg
#   inflating: food11/training/9_51.jpg
#   inflating: food11/training/9_510.jpg
#   inflating: food11/training/9_511.jpg
#   inflating: food11/training/9_512.jpg
#   inflating: food11/training/9_513.jpg
#   inflating: food11/training/9_514.jpg
#   inflating: food11/training/9_515.jpg
#   inflating: food11/training/9_516.jpg
#   inflating: food11/training/9_517.jpg
#   inflating: food11/training/9_518.jpg
#   inflating: food11/training/9_519.jpg
#   inflating: food11/training/9_52.jpg
#   inflating: food11/training/9_520.jpg
#   inflating: food11/training/9_521.jpg
#   inflating: food11/training/9_522.jpg
#   inflating: food11/training/9_523.jpg
#   inflating: food11/training/9_524.jpg
#   inflating: food11/training/9_525.jpg
#   inflating: food11/training/9_526.jpg
#   inflating: food11/training/9_527.jpg
#   inflating: food11/training/9_528.jpg
#   inflating: food11/training/9_529.jpg
#   inflating: food11/training/9_53.jpg
#   inflating: food11/training/9_530.jpg
#   inflating: food11/training/9_531.jpg
#   inflating: food11/training/9_532.jpg
#   inflating: food11/training/9_533.jpg
#   inflating: food11/training/9_534.jpg
#   inflating: food11/training/9_535.jpg
#   inflating: food11/training/9_536.jpg
#   inflating: food11/training/9_537.jpg
#   inflating: food11/training/9_538.jpg
#   inflating: food11/training/9_539.jpg
#   inflating: food11/training/9_54.jpg
#   inflating: food11/training/9_540.jpg
#   inflating: food11/training/9_541.jpg
#   inflating: food11/training/9_542.jpg
#   inflating: food11/training/9_543.jpg
#   inflating: food11/training/9_544.jpg
#   inflating: food11/training/9_545.jpg
#   inflating: food11/training/9_546.jpg
#   inflating: food11/training/9_547.jpg
#   inflating: food11/training/9_548.jpg
#   inflating: food11/training/9_549.jpg
#   inflating: food11/training/9_55.jpg
#   inflating: food11/training/9_550.jpg
#   inflating: food11/training/9_551.jpg
#   inflating: food11/training/9_552.jpg
#   inflating: food11/training/9_553.jpg
#   inflating: food11/training/9_554.jpg
#   inflating: food11/training/9_555.jpg
#   inflating: food11/training/9_556.jpg
#   inflating: food11/training/9_557.jpg
#   inflating: food11/training/9_558.jpg
#   inflating: food11/training/9_559.jpg
#   inflating: food11/training/9_56.jpg
#   inflating: food11/training/9_560.jpg
#   inflating: food11/training/9_561.jpg
#   inflating: food11/training/9_562.jpg
#   inflating: food11/training/9_563.jpg
#   inflating: food11/training/9_564.jpg
#   inflating: food11/training/9_565.jpg
#   inflating: food11/training/9_566.jpg
#   inflating: food11/training/9_567.jpg
#   inflating: food11/training/9_568.jpg
#   inflating: food11/training/9_569.jpg
#   inflating: food11/training/9_57.jpg
#   inflating: food11/training/9_570.jpg
#   inflating: food11/training/9_571.jpg
#   inflating: food11/training/9_572.jpg
#   inflating: food11/training/9_573.jpg
#   inflating: food11/training/9_574.jpg
#   inflating: food11/training/9_575.jpg
#   inflating: food11/training/9_576.jpg
#   inflating: food11/training/9_577.jpg
#   inflating: food11/training/9_578.jpg
#   inflating: food11/training/9_579.jpg
#   inflating: food11/training/9_58.jpg
#   inflating: food11/training/9_580.jpg
#   inflating: food11/training/9_581.jpg
#   inflating: food11/training/9_582.jpg
#   inflating: food11/training/9_583.jpg
#   inflating: food11/training/9_584.jpg
#   inflating: food11/training/9_585.jpg
#   inflating: food11/training/9_586.jpg
#   inflating: food11/training/9_587.jpg
#   inflating: food11/training/9_588.jpg
#   inflating: food11/training/9_589.jpg
#   inflating: food11/training/9_59.jpg
#   inflating: food11/training/9_590.jpg
#   inflating: food11/training/9_591.jpg
#   inflating: food11/training/9_592.jpg
#   inflating: food11/training/9_593.jpg
#   inflating: food11/training/9_594.jpg
#   inflating: food11/training/9_595.jpg
#   inflating: food11/training/9_596.jpg
#   inflating: food11/training/9_597.jpg
#   inflating: food11/training/9_598.jpg
#   inflating: food11/training/9_599.jpg
#   inflating: food11/training/9_6.jpg
#   inflating: food11/training/9_60.jpg
#   inflating: food11/training/9_600.jpg
#   inflating: food11/training/9_601.jpg
#   inflating: food11/training/9_602.jpg
#   inflating: food11/training/9_603.jpg
#   inflating: food11/training/9_604.jpg
#   inflating: food11/training/9_605.jpg
#   inflating: food11/training/9_606.jpg
#   inflating: food11/training/9_607.jpg
#   inflating: food11/training/9_608.jpg
#   inflating: food11/training/9_609.jpg
#   inflating: food11/training/9_61.jpg
#   inflating: food11/training/9_610.jpg
#   inflating: food11/training/9_611.jpg
#   inflating: food11/training/9_612.jpg
#   inflating: food11/training/9_613.jpg
#   inflating: food11/training/9_614.jpg
#   inflating: food11/training/9_615.jpg
#   inflating: food11/training/9_616.jpg
#   inflating: food11/training/9_617.jpg
#   inflating: food11/training/9_618.jpg
#   inflating: food11/training/9_619.jpg
#   inflating: food11/training/9_62.jpg
#   inflating: food11/training/9_620.jpg
#   inflating: food11/training/9_621.jpg
#   inflating: food11/training/9_622.jpg
#   inflating: food11/training/9_623.jpg
#   inflating: food11/training/9_624.jpg
#   inflating: food11/training/9_625.jpg
#   inflating: food11/training/9_626.jpg
#   inflating: food11/training/9_627.jpg
#   inflating: food11/training/9_628.jpg
#   inflating: food11/training/9_629.jpg
# ...
#   inflating: food11/validation/9_211.jpg
#   inflating: food11/validation/9_212.jpg
#   inflating: food11/validation/9_213.jpg
#   inflating: food11/validation/9_214.jpg
#   inflating: food11/validation/9_215.jpg
#   inflating: food11/validation/9_216.jpg
#   inflating: food11/validation/9_217.jpg
#   inflating: food11/validation/9_218.jpg
#   inflating: food11/validation/9_219.jpg
#   inflating: food11/validation/9_22.jpg
#   inflating: food11/validation/9_220.jpg
#   inflating: food11/validation/9_221.jpg
#   inflating: food11/validation/9_222.jpg
#   inflating: food11/validation/9_223.jpg
#   inflating: food11/validation/9_224.jpg
#   inflating: food11/validation/9_225.jpg
#   inflating: food11/validation/9_226.jpg
#   inflating: food11/validation/9_227.jpg
#   inflating: food11/validation/9_228.jpg
#   inflating: food11/validation/9_229.jpg
#   inflating: food11/validation/9_23.jpg
#   inflating: food11/validation/9_230.jpg
#   inflating: food11/validation/9_231.jpg
#   inflating: food11/validation/9_232.jpg
#   inflating: food11/validation/9_233.jpg
#   inflating: food11/validation/9_234.jpg
#   inflating: food11/validation/9_235.jpg
#   inflating: food11/validation/9_236.jpg
#   inflating: food11/validation/9_237.jpg
#   inflating: food11/validation/9_238.jpg
#   inflating: food11/validation/9_239.jpg
#   inflating: food11/validation/9_24.jpg
#   inflating: food11/validation/9_240.jpg
#   inflating: food11/validation/9_241.jpg
#   inflating: food11/validation/9_242.jpg
#   inflating: food11/validation/9_243.jpg
#   inflating: food11/validation/9_244.jpg
#   inflating: food11/validation/9_245.jpg
#   inflating: food11/validation/9_246.jpg
#   inflating: food11/validation/9_247.jpg
#   inflating: food11/validation/9_248.jpg
#   inflating: food11/validation/9_249.jpg
#   inflating: food11/validation/9_25.jpg
#   inflating: food11/validation/9_250.jpg
#   inflating: food11/validation/9_251.jpg
#   inflating: food11/validation/9_252.jpg
#   inflating: food11/validation/9_253.jpg
#   inflating: food11/validation/9_254.jpg
#   inflating: food11/validation/9_255.jpg
#   inflating: food11/validation/9_256.jpg
#   inflating: food11/validation/9_257.jpg
#   inflating: food11/validation/9_258.jpg
#   inflating: food11/validation/9_259.jpg
#   inflating: food11/validation/9_26.jpg
#   inflating: food11/validation/9_260.jpg
#   inflating: food11/validation/9_261.jpg
#   inflating: food11/validation/9_262.jpg
#   inflating: food11/validation/9_263.jpg
#   inflating: food11/validation/9_264.jpg
#   inflating: food11/validation/9_265.jpg
#   inflating: food11/validation/9_266.jpg
#   inflating: food11/validation/9_267.jpg
#   inflating: food11/validation/9_268.jpg
#   inflating: food11/validation/9_269.jpg
#   inflating: food11/validation/9_27.jpg
#   inflating: food11/validation/9_270.jpg
#   inflating: food11/validation/9_271.jpg
#   inflating: food11/validation/9_272.jpg
#   inflating: food11/validation/9_273.jpg
#   inflating: food11/validation/9_274.jpg
#   inflating: food11/validation/9_275.jpg
#   inflating: food11/validation/9_276.jpg
#   inflating: food11/validation/9_277.jpg
#   inflating: food11/validation/9_278.jpg
#   inflating: food11/validation/9_279.jpg
#   inflating: food11/validation/9_28.jpg
#   inflating: food11/validation/9_280.jpg
#   inflating: food11/validation/9_281.jpg
#   inflating: food11/validation/9_282.jpg
#   inflating: food11/validation/9_283.jpg
#   inflating: food11/validation/9_284.jpg
#   inflating: food11/validation/9_285.jpg
#   inflating: food11/validation/9_286.jpg
#   inflating: food11/validation/9_287.jpg
#   inflating: food11/validation/9_288.jpg
#   inflating: food11/validation/9_289.jpg
#   inflating: food11/validation/9_29.jpg
#   inflating: food11/validation/9_290.jpg
#   inflating: food11/validation/9_291.jpg
#   inflating: food11/validation/9_292.jpg
#   inflating: food11/validation/9_293.jpg
#   inflating: food11/validation/9_294.jpg
#   inflating: food11/validation/9_295.jpg
#   inflating: food11/validation/9_296.jpg
#   inflating: food11/validation/9_297.jpg
#   inflating: food11/validation/9_298.jpg
#   inflating: food11/validation/9_299.jpg
#   inflating: food11/validation/9_3.jpg
#   inflating: food11/validation/9_30.jpg
#   inflating: food11/validation/9_300.jpg
#   inflating: food11/validation/9_301.jpg
#   inflating: food11/validation/9_302.jpg
#   inflating: food11/validation/9_303.jpg
#   inflating: food11/validation/9_304.jpg
#   inflating: food11/validation/9_305.jpg
#   inflating: food11/validation/9_306.jpg
#   inflating: food11/validation/9_307.jpg
#   inflating: food11/validation/9_308.jpg
#   inflating: food11/validation/9_309.jpg
#   inflating: food11/validation/9_31.jpg
#   inflating: food11/validation/9_310.jpg
#   inflating: food11/validation/9_311.jpg
#   inflating: food11/validation/9_312.jpg
#   inflating: food11/validation/9_313.jpg
#   inflating: food11/validation/9_314.jpg
#   inflating: food11/validation/9_315.jpg
#   inflating: food11/validation/9_316.jpg
#   inflating: food11/validation/9_317.jpg
#   inflating: food11/validation/9_318.jpg
#   inflating: food11/validation/9_319.jpg
#   inflating: food11/validation/9_32.jpg
#   inflating: food11/validation/9_320.jpg
#   inflating: food11/validation/9_321.jpg
#   inflating: food11/validation/9_322.jpg
#   inflating: food11/validation/9_323.jpg
#   inflating: food11/validation/9_324.jpg
#   inflating: food11/validation/9_325.jpg
#   inflating: food11/validation/9_326.jpg
#   inflating: food11/validation/9_327.jpg
#   inflating: food11/validation/9_328.jpg
#   inflating: food11/validation/9_329.jpg
#   inflating: food11/validation/9_33.jpg
#   inflating: food11/validation/9_330.jpg
#   inflating: food11/validation/9_331.jpg
#   inflating: food11/validation/9_332.jpg
#   inflating: food11/validation/9_333.jpg
#   inflating: food11/validation/9_334.jpg
#   inflating: food11/validation/9_335.jpg
#   inflating: food11/validation/9_336.jpg
#   inflating: food11/validation/9_337.jpg
#   inflating: food11/validation/9_338.jpg
#   inflating: food11/validation/9_339.jpg
#   inflating: food11/validation/9_34.jpg
#   inflating: food11/validation/9_340.jpg
#   inflating: food11/validation/9_341.jpg
#   inflating: food11/validation/9_342.jpg
#   inflating: food11/validation/9_343.jpg
#   inflating: food11/validation/9_344.jpg
#   inflating: food11/validation/9_345.jpg
#   inflating: food11/validation/9_346.jpg
#   inflating: food11/validation/9_347.jpg
#   inflating: food11/validation/9_348.jpg
#   inflating: food11/validation/9_349.jpg
#   inflating: food11/validation/9_35.jpg
#   inflating: food11/validation/9_350.jpg
#   inflating: food11/validation/9_351.jpg
#   inflating: food11/validation/9_352.jpg
#   inflating: food11/validation/9_353.jpg
#   inflating: food11/validation/9_354.jpg
#   inflating: food11/validation/9_355.jpg
#   inflating: food11/validation/9_356.jpg
#   inflating: food11/validation/9_357.jpg
#   inflating: food11/validation/9_358.jpg
#   inflating: food11/validation/9_359.jpg
#   inflating: food11/validation/9_36.jpg
#   inflating: food11/validation/9_360.jpg
#   inflating: food11/validation/9_361.jpg
#   inflating: food11/validation/9_362.jpg
#   inflating: food11/validation/9_363.jpg
#   inflating: food11/validation/9_364.jpg
#   inflating: food11/validation/9_365.jpg
#   inflating: food11/validation/9_366.jpg
#   inflating: food11/validation/9_367.jpg
#   inflating: food11/validation/9_368.jpg
#   inflating: food11/validation/9_369.jpg
#   inflating: food11/validation/9_37.jpg
#   inflating: food11/validation/9_370.jpg
#   inflating: food11/validation/9_371.jpg
#   inflating: food11/validation/9_372.jpg
#   inflating: food11/validation/9_373.jpg
#   inflating: food11/validation/9_374.jpg
#   inflating: food11/validation/9_375.jpg
#   inflating: food11/validation/9_376.jpg
#   inflating: food11/validation/9_377.jpg
#   inflating: food11/validation/9_378.jpg
#   inflating: food11/validation/9_379.jpg
#   inflating: food11/validation/9_38.jpg
#   inflating: food11/validation/9_380.jpg
#   inflating: food11/validation/9_381.jpg
#   inflating: food11/validation/9_382.jpg
#   inflating: food11/validation/9_383.jpg
#   inflating: food11/validation/9_384.jpg
#   inflating: food11/validation/9_385.jpg
#   inflating: food11/validation/9_386.jpg
#   inflating: food11/validation/9_387.jpg
#   inflating: food11/validation/9_388.jpg
#   inflating: food11/validation/9_389.jpg
#   inflating: food11/validation/9_39.jpg
#   inflating: food11/validation/9_390.jpg
#   inflating: food11/validation/9_391.jpg
#   inflating: food11/validation/9_392.jpg
#   inflating: food11/validation/9_393.jpg
#   inflating: food11/validation/9_394.jpg
#   inflating: food11/validation/9_395.jpg
#   inflating: food11/validation/9_396.jpg
#   inflating: food11/validation/9_397.jpg
#   inflating: food11/validation/9_398.jpg
#   inflating: food11/validation/9_399.jpg
#   inflating: food11/validation/9_4.jpg
#   inflating: food11/validation/9_40.jpg
#   inflating: food11/validation/9_400.jpg
#   inflating: food11/validation/9_401.jpg
#   inflating: food11/validation/9_402.jpg
#   inflating: food11/validation/9_403.jpg
#   inflating: food11/validation/9_404.jpg
#   inflating: food11/validation/9_405.jpg
#   inflating: food11/validation/9_406.jpg
#   inflating: food11/validation/9_407.jpg
#   inflating: food11/validation/9_408.jpg
#   inflating: food11/validation/9_409.jpg
#   inflating: food11/validation/9_41.jpg
#   inflating: food11/validation/9_410.jpg
#   inflating: food11/validation/9_411.jpg
#   inflating: food11/validation/9_412.jpg
#   inflating: food11/validation/9_413.jpg
#   inflating: food11/validation/9_414.jpg
#   inflating: food11/validation/9_415.jpg
#   inflating: food11/validation/9_416.jpg
#   inflating: food11/validation/9_417.jpg
#   inflating: food11/validation/9_418.jpg
#   inflating: food11/validation/9_419.jpg
#   inflating: food11/validation/9_42.jpg
#   inflating: food11/validation/9_420.jpg
#   inflating: food11/validation/9_421.jpg
#   inflating: food11/validation/9_422.jpg
#   inflating: food11/validation/9_423.jpg
#   inflating: food11/validation/9_424.jpg
#   inflating: food11/validation/9_425.jpg
#   inflating: food11/validation/9_426.jpg
#   inflating: food11/validation/9_427.jpg
#   inflating: food11/validation/9_428.jpg
#   inflating: food11/validation/9_429.jpg
#   inflating: food11/validation/9_43.jpg
#   inflating: food11/validation/9_430.jpg
#   inflating: food11/validation/9_431.jpg
#   inflating: food11/validation/9_432.jpg
#   inflating: food11/validation/9_433.jpg
#   inflating: food11/validation/9_434.jpg
#   inflating: food11/validation/9_435.jpg
#   inflating: food11/validation/9_436.jpg
#   inflating: food11/validation/9_437.jpg
#   inflating: food11/validation/9_438.jpg
#   inflating: food11/validation/9_439.jpg
#   inflating: food11/validation/9_44.jpg
#   inflating: food11/validation/9_440.jpg
#   inflating: food11/validation/9_441.jpg
#   inflating: food11/validation/9_442.jpg
#   inflating: food11/validation/9_443.jpg
#   inflating: food11/validation/9_444.jpg
#   inflating: food11/validation/9_445.jpg
#   inflating: food11/validation/9_446.jpg
#   inflating: food11/validation/9_447.jpg
#   inflating: food11/validation/9_448.jpg
#   inflating: food11/validation/9_449.jpg
#   inflating: food11/validation/9_45.jpg
#   inflating: food11/validation/9_450.jpg
#   inflating: food11/validation/9_451.jpg
#   inflating: food11/validation/9_452.jpg
#   inflating: food11/validation/9_453.jpg
#   inflating: food11/validation/9_454.jpg
#   inflating: food11/validation/9_455.jpg
#   inflating: food11/validation/9_456.jpg
#   inflating: food11/validation/9_457.jpg
#   inflating: food11/validation/9_458.jpg
#   inflating: food11/validation/9_459.jpg
#   inflating: food11/validation/9_46.jpg
#   inflating: food11/validation/9_460.jpg
#   inflating: food11/validation/9_461.jpg
#   inflating: food11/validation/9_462.jpg
#   inflating: food11/validation/9_463.jpg
#   inflating: food11/validation/9_464.jpg
#   inflating: food11/validation/9_465.jpg
#   inflating: food11/validation/9_466.jpg
#   inflating: food11/validation/9_467.jpg
#   inflating: food11/validation/9_468.jpg
#   inflating: food11/validation/9_469.jpg
#   inflating: food11/validation/9_47.jpg
#   inflating: food11/validation/9_470.jpg
#   inflating: food11/validation/9_471.jpg
#   inflating: food11/validation/9_472.jpg
#   inflating: food11/validation/9_473.jpg
#   inflating: food11/validation/9_474.jpg
#   inflating: food11/validation/9_475.jpg
#   inflating: food11/validation/9_476.jpg
#   inflating: food11/validation/9_477.jpg
#   inflating: food11/validation/9_478.jpg
#   inflating: food11/validation/9_479.jpg
#   inflating: food11/validation/9_48.jpg
#   inflating: food11/validation/9_480.jpg
#   inflating: food11/validation/9_481.jpg
#   inflating: food11/validation/9_482.jpg
#   inflating: food11/validation/9_483.jpg
#   inflating: food11/validation/9_484.jpg
#   inflating: food11/validation/9_485.jpg
#   inflating: food11/validation/9_486.jpg
#   inflating: food11/validation/9_487.jpg
#   inflating: food11/validation/9_488.jpg
#   inflating: food11/validation/9_489.jpg
#   inflating: food11/validation/9_49.jpg
#   inflating: food11/validation/9_490.jpg
#   inflating: food11/validation/9_491.jpg
#   inflating: food11/validation/9_492.jpg
#   inflating: food11/validation/9_493.jpg
#   inflating: food11/validation/9_494.jpg
#   inflating: food11/validation/9_495.jpg
#   inflating: food11/validation/9_496.jpg
#   inflating: food11/validation/9_497.jpg
#   inflating: food11/validation/9_498.jpg
#   inflating: food11/validation/9_499.jpg
#   inflating: food11/validation/9_5.jpg
#   inflating: food11/validation/9_50.jpg
#   inflating: food11/validation/9_51.jpg
#   inflating: food11/validation/9_52.jpg
#   inflating: food11/validation/9_53.jpg
#   inflating: food11/validation/9_54.jpg
#   inflating: food11/validation/9_55.jpg
#   inflating: food11/validation/9_56.jpg
#   inflating: food11/validation/9_57.jpg
#   inflating: food11/validation/9_58.jpg
#   inflating: food11/validation/9_59.jpg
#   inflating: food11/validation/9_6.jpg
#   inflating: food11/validation/9_60.jpg
#   inflating: food11/validation/9_61.jpg
#   inflating: food11/validation/9_62.jpg
#   inflating: food11/validation/9_63.jpg
#   inflating: food11/validation/9_64.jpg
#   inflating: food11/validation/9_65.jpg
#   inflating: food11/validation/9_66.jpg
#   inflating: food11/validation/9_67.jpg
#   inflating: food11/validation/9_68.jpg
#   inflating: food11/validation/9_69.jpg
#   inflating: food11/validation/9_7.jpg
#   inflating: food11/validation/9_70.jpg
#   inflating: food11/validation/9_71.jpg
#   inflating: food11/validation/9_72.jpg
#   inflating: food11/validation/9_73.jpg
#   inflating: food11/validation/9_74.jpg
#   inflating: food11/validation/9_75.jpg
#   inflating: food11/validation/9_76.jpg
#   inflating: food11/validation/9_77.jpg
#   inflating: food11/validation/9_78.jpg
#   inflating: food11/validation/9_79.jpg
#   inflating: food11/validation/9_8.jpg
#   inflating: food11/validation/9_80.jpg
#   inflating: food11/validation/9_81.jpg
#   inflating: food11/validation/9_82.jpg
#   inflating: food11/validation/9_83.jpg
#   inflating: food11/validation/9_84.jpg
#   inflating: food11/validation/9_85.jpg
#   inflating: food11/validation/9_86.jpg
#   inflating: food11/validation/9_87.jpg
#   inflating: food11/validation/9_88.jpg
#   inflating: food11/validation/9_89.jpg
#   inflating: food11/validation/9_9.jpg
#   inflating: food11/validation/9_90.jpg
#   inflating: food11/validation/9_91.jpg
#   inflating: food11/validation/9_92.jpg
#   inflating: food11/validation/9_93.jpg
#   inflating: food11/validation/9_94.jpg
#   inflating: food11/validation/9_95.jpg
#   inflating: food11/validation/9_96.jpg
#   inflating: food11/validation/9_97.jpg
#   inflating: food11/validation/9_98.jpg
#   inflating: food11/validation/9_99.jpg

# %% [markdown]
# # Training

# %%
_exp_name = "mixup"

# %%
# Import necessary packages.
import numpy as np
import pandas as pd
import torch
import os
import torch.nn as nn
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
# "ConcatDataset" and "Subset" are possibly useful when doing semi-supervised learning.
from torch.utils.data import ConcatDataset, DataLoader, Subset, Dataset, random_split,SubsetRandomSampler
from torchvision.datasets import DatasetFolder, VisionDataset
from torchvision import models
from sklearn.model_selection import KFold
# This is for the progress bar.
from tqdm.auto import tqdm
import random
from torch.autograd import Variable

# %%
myseed = 1126  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# ## **Transforms**
# Torchvision provides lots of useful utilities for image preprocessing, data wrapping as well as data augmentation.
#
# Please refer to PyTorch official website for details about different transforms.

# %%
from torchvision.transforms.transforms import RandomGrayscale
# Normally, We don't need augmentations in testing and validation.
# All we need here is to resize the PIL image and transform it into Tensor.
test_tfm = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])
])

# However, it is also possible to use augmentation in the testing phase.
# You may use train_tfm to produce a variety of images and then test using ensemble methods
train_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    transforms.Resize((128, 128)),
    # You may add some transforms here.
    # ToTensor() should be the last one of the transforms.
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.RandomGrayscale(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])
])

# %% [markdown]
# ## **Datasets**
# The data is labelled by the name, so we load images and label while calling '__getitem__'

# %%
class FoodDataset(Dataset):

    def __init__(self,path,tfm=test_tfm,files = None, mode = 'train'):
        super(FoodDataset).__init__()
        self.path = path
        self.mode = mode
        self.files = sorted([os.path.join(path,x) for x in os.listdir(path) if x.endswith(".jpg")])
        if files != None:
            self.files = files
        print(f"One {path} sample",self.files[0])
        self.transform = tfm
  
    def __len__(self):
        return len(self.files)
  
    def __getitem__(self,idx):
        fname = self.files[idx]
        im = Image.open(fname)
        im = self.transform(im)
        #im = self.data[idx]
        if self.mode == 'train':
            if idx % 5 == 0:
                label = int(fname.split("/")[-1].split("_")[0])
                mix_idx = random.randint(0, len(self.files)-1)
                mix_name = self.files[mix_idx]
                mix_img = Image.open(mix_name)
                mix_img = self.transform(mix_img)
                alpha = 1.0
                lam = np.random.beta(alpha, alpha)
                im = lam*im + (1-lam)*mix_img
                mix_label = int(mix_name.split("/")[-1].split("_")[0])
                return im, label, mix_label, lam
            else:
                label = int(fname.split("/")[-1].split("_")[0])
                mix_label = 0
                lam = 1
                return im, label, mix_label, lam
        else:
            label = -1 # test has no label
        return im,label

# %%
class Residual_Block(nn.Module):
    def __init__(self, in_channel, out_channel, stride=1, down_sample=None):
        super(Residual_Block, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channel, 
                    out_channels=out_channel, 
                    kernel_size=3, 
                    stride=stride, 
                    padding=1,
                    bias=False)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(in_channels=out_channel, 
                    out_channels=out_channel, 
                    kernel_size=3, 
                    stride=1, 
                    padding=1,
                    bias=False)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.down_sample = down_sample

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        
        if self.down_sample:
            residual = self.down_sample(x)
        out += residual
        out = self.relu(out)

        return out
    
class Classifier(nn.Module):
    def __init__(self, block, layers, num_classes=11):
        super(Classifier, self).__init__()
        self.conv = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1, bias=False)
        self.in_channels = 16
        self.bn = nn.BatchNorm2d(16)
        self.relu = nn.ReLU(inplace=True)
        self.layer1 = self.make_layer(block, 16, layers[0])
        self.layer2 = self.make_layer(block, 32, layers[0], 2)
        self.layer3 = self.make_layer(block, 64, layers[1], 2)
        self.avg_pool = nn.AvgPool2d(8)
        self.fc = nn.Linear(1024, num_classes)
        self.dropout = nn.Dropout(p=0.5)
        
    def make_layer(self, block, out_channels, blocks, stride=1):  
        down_sample = None
        if (stride != 1) or (self.in_channels != out_channels):
            down_sample = nn.Sequential(
                nn.Conv2d(self.in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
                nn.BatchNorm2d(out_channels)
            )

        layers = []
        layers.append(block(self.in_channels, out_channels, stride, down_sample))
        self.in_channels = out_channels
        for i in range(1, blocks):
            layers.append(block(out_channels, out_channels))
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv(x)
        out = self.bn(out)
        out = self.relu(out)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avg_pool(out)
        out = self.dropout(out) # dropout
        out = out.view(out.size()[0], -1)
        out = self.fc(out)
        return out

# %%
batch_size = 48
_dataset_dir = "./food11"
# Construct datasets.
# The argument "loader" tells how torchvision reads the data.
train_set = FoodDataset(os.path.join(_dataset_dir,"training"), tfm=train_tfm, mode='train')
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
# Out:
# One ./food11/training sample ./food11/training/0_0.jpg

# %%
valid_set = FoodDataset(os.path.join(_dataset_dir,"validation"), tfm=train_tfm,mode='train')
full_set = ConcatDataset([train_set,valid_set])
full_loader = DataLoader(full_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
# Out:
# One ./food11/validation sample ./food11/validation/0_0.jpg

# %%
# "cuda" only when GPUs are available.
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model = Classifier(Residual_Block, [2, 2, 2, 2]).to(device)
model.load_state_dict(torch.load(f"/content/drive/MyDrive/ML/HW3/{_exp_name}_best.ckpt"))
# Out:
# <All keys matched successfully>

# %%
# For the classification task, we use cross-entropy as the measurement of performance.
# Reference: https://github.com/facebookresearch/mixup-cifar10/blob/main/train.py
criterion = nn.CrossEntropyLoss(label_smoothing=0.2)
def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
# The number of training epochs and patience.
n_epochs = 150
patience = 30 # If no improvement in 'patience' epochs, early stop


# Initialize optimizer, you may fine-tune some hyperparameters such as learning rate on your own.
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5) 
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', patience=5, verbose=True,min_lr=0.00001)
# Initialize trackers, these are not parameters and should not be changed
stale = 0
best_acc = 0

for epoch in range(n_epochs):

    # ---------- Training ----------
    # Make sure the model is in train mode before training.
    model.train()

    # These are used to record information in training.
    train_loss = []
    train_accs = []
    for batch in full_loader:

        # A batch consists of image data and corresponding labels.
        imgs, label_a, label_b, lam = batch
        imgs, label_a, label_b, lam = imgs.to(device), label_a.to(device), label_b.to(device), lam.to(device)
        # Forward the data. (Make sure data and model are on the same device.)
        imgs, label_a, label_b, = map(Variable, (imgs,label_a,label_b))
        logits = model(imgs.to(device))
        # Calculate the cross-entropy loss.
        # We don't need to apply softmax before computing cross-entropy as it is done automatically.
        loss = mixup_criterion(criterion, logits, label_a, label_b, lam)
        loss = loss.mean()
        # Gradients stored in the parameters in the previous step should be cleared out first.
        optimizer.zero_grad()

        # Compute the gradients for parameters.
        loss.backward()

        # Clip the gradient norms for stable training.
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)

        # Update the parameters with computed gradients.
        optimizer.step()

        # Compute the accuracy for current batch.
        pred = logits.argmax(dim=-1)
        acc = ((lam * (pred == label_a)) + ((1 - lam) * (pred == label_b))).float().mean()

        # Record the loss and accuracy.
        train_loss.append(loss.item())
        train_accs.append(acc)
        
    train_loss = sum(train_loss) / len(train_loss)
    train_acc = sum(train_accs) / len(train_accs)
    # Print the information.
    print(f"[ Train | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f}")
    # update logs
    scheduler.step(train_acc)
    if train_acc > best_acc:
        with open(f"./{_exp_name}_log.txt","a"):
            print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f} -> best")
    else:
        with open(f"./{_exp_name}_log.txt","a"):
            print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f}")


    # save models
    if train_acc > best_acc:
        print(f"Best model found at epoch {epoch}, saving model")
        torch.save(model.state_dict(), f"/content/drive/MyDrive/ML/HW3/{_exp_name}_best.ckpt") # only save best to prevent output memory exceed error
        best_acc = train_acc
        stale = 0
    else:
        stale += 1
        if stale > patience:
            print(f"No improvment {patience} consecutive epochs, early stopping")
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-ccc239971cab> in <module>()
#      40
#      41         # Compute the gradients for parameters.
# ---> 42         loss.backward()
#      43
#      44         # Clip the gradient norms for stable training.
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
test_set = FoodDataset(os.path.join(_dataset_dir,"test"), tfm=test_tfm, mode='test')
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)
# Out:
# One ./food11/test sample ./food11/test/0001.jpg

# %% [markdown]
# # Testing and generate prediction CSV

# %%
model_best = Classifier(Residual_Block, [2, 2, 2, 2]).to(device)
model_best.load_state_dict(torch.load(f"/content/drive/MyDrive/ML/HW3/{_exp_name}_best.ckpt"))

# %%
def training(model,optimizer,criterion,dataloader):
    # ---------- Training ----------
    # Make sure the model is in train mode before training.
    model.train()

        # These are used to record information in training.
    train_loss = []
    train_accs = []

    for batch in dataloader:

        # A batch consists of image data and corresponding labels.
        imgs, label_a, label_b, lam = batch
        imgs, label_a, label_b, lam = imgs.to(device), label_a.to(device), label_b.to(device), lam.to(device)
        imgs, label_a, label_b, = map(Variable, (imgs,label_a,label_b))
        # Forward the data. (Make sure data and model are on the same device.)
        logits = model(imgs.to(device))

        # Calculate the cross-entropy loss.
        # We don't need to apply softmax before computing cross-entropy as it is done automatically.
        loss = mixup_criterion(criterion, logits, label_a, label_b, lam)
        loss = loss.mean()

        # Gradients stored in the parameters in the previous step should be cleared out first.
        optimizer.zero_grad()

        # Compute the gradients for parameters.
        loss.backward()

        # Clip the gradient norms for stable training.
        grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)

        # Update the parameters with computed gradients.
        optimizer.step()

        # Compute the accuracy for current batch.
        pred = logits.argmax(dim=-1)
        acc = ((lam * (pred == label_a)) + ((1 - lam) * (pred == label_b))).float().mean()

        # Record the loss and accuracy.
        train_loss.append(loss.item())
        train_accs.append(acc)
            
    train_loss = sum(train_loss) / len(train_loss)
    train_acc = sum(train_accs) / len(train_accs)

    # Print the information.
    print(f"[ Train | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f}")
    return train_loss, train_acc

# %%
def validation(model,optimizer,criterion,dataloader):
    # ---------- Validation ----------
    # Make sure the model is in eval mode so that some modules like dropout are disabled and work normally.
    model.eval()

    # These are used to record information in validation.
    valid_loss = []
    valid_accs = []

    # Iterate the validation set by batches.
    for batch in dataloader:

        # A batch consists of image data and corresponding labels.
        imgs, label_a, label_b, lam = batch
        #imgs = imgs.half()
        imgs, label_a, label_b, lam = imgs.to(device), label_a.to(device), label_b.to(device), lam.to(device)
        imgs, label_a, label_b, = map(Variable, (imgs,label_a,label_b))
        # We don't need gradient in validation.
        # Using torch.no_grad() accelerates the forward process.
        with torch.no_grad():
            logits = model(imgs.to(device))

        # We can still compute the loss (but not the gradient).
        loss = mixup_criterion(criterion, logits, label_a, label_b, lam)
        loss = loss.mean()

        # Compute the accuracy for current batch.
        pred = logits.argmax(dim=-1)
        acc = ((lam * (pred == label_a)) + ((1 - lam) * (pred == label_b))).float().mean()

        # Record the loss and accuracy.
        valid_loss.append(loss.item())
        valid_accs.append(acc)
        #break

    # The average loss and accuracy for entire validation set is the average of the recorded values.
    valid_loss = sum(valid_loss) / len(valid_loss)
    valid_acc = sum(valid_accs) / len(valid_accs)

    # Print the information.
    print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")
    return valid_loss, valid_acc

# %%
# The number of training epochs and patience.
n_epochs = 10
patience = 5 # If no improvement in 'patience' epochs, early stop
k = 5
splits=KFold(n_splits=k,shuffle=True,random_state=1126)
foldperf={}
history = {'train_loss': [], 'val_loss': [],'train_acc':[],'val_acc':[]}
# For the classification task, we use cross-entropy as the measurement of performance.
criterion = nn.CrossEntropyLoss(label_smoothing=0.15)
fold_acc = dict.fromkeys(['1','2','3','4','5'])
# Initialize optimizer, you may fine-tune some hyperparameters such as learning rate on your own.
optimizer = torch.optim.Adam(model_best.parameters(), lr=0.00005, weight_decay=0.000001) 

# Initialize trackers, these are not parameters and should not be changed
for fold, (train_idx,val_idx) in enumerate(splits.split(np.arange(len(full_set)))):
    model_best = Classifier(Residual_Block, [2, 2, 2, 2]).to(device)
    model_best.load_state_dict(torch.load(f"/content/drive/MyDrive/ML/HW3/{_exp_name}_best.ckpt"))
    best_acc = 0
    stale = 0
    print(f'Fold {fold + 1}')
    train_sampler = SubsetRandomSampler(train_idx)
    val_sampler = SubsetRandomSampler(val_idx)
    train_loader = DataLoader(full_set, batch_size=batch_size, sampler=train_sampler)
    val_loader = DataLoader(full_set, batch_size=batch_size, sampler=val_sampler)
    for epoch in range(n_epochs):
        train_loss, train_acc = training(model_best,optimizer,criterion,train_loader)

        val_loss, val_acc = validation(model_best,optimizer,criterion,val_loader)
        
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc.cpu())
        history['val_acc'].append(val_acc.cpu())
        
        # update logs
        if val_acc > best_acc:
            with open(f"./{_exp_name}_log.txt","a"):
                print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {val_loss:.5f}, acc = {val_acc:.5f} -> best")
        else:
            with open(f"./{_exp_name}_log.txt","a"):
                print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {val_loss:.5f}, acc = {val_acc:.5f}")


        # save models
        if val_acc > best_acc:
            print(f"Best model found at epoch {epoch}, saving model")
            torch.save(model_best.state_dict(), f"/content/drive/MyDrive/ML/HW3/{_exp_name}_Fold{fold+1}_best.ckpt") # only save best to prevent output memory exceed error
            best_acc = val_acc
            fold_acc[f'{fold+1}'] = best_acc
            stale = 0
        else:
            stale += 1
            if stale > patience:
                print(f"No improvment {patience} consecutive epochs, early stopping")
                break
    foldperf[f'fold{fold+1}'] = history

# %%
testl_f,tl_f,testa_f,ta_f=[],[],[],[]
k=5
for f in range(1,k+1):

     tl_f.append(np.mean(foldperf['fold{}'.format(f)]['train_loss']))
     testl_f.append(np.mean(foldperf['fold{}'.format(f)]['val_loss']))

     ta_f.append(np.mean(foldperf['fold{}'.format(f)]['train_acc']))
     testa_f.append(np.mean(foldperf['fold{}'.format(f)]['val_acc']))

print('Performance of {} fold cross validation'.format(k))
print("Average Training Loss: {:.3f} \t Average Test Loss: {:.3f} \t Average Training Acc: {:.2f} \t Average Test Acc: {:.2f}".format(np.mean(tl_f),np.mean(testl_f),np.mean(ta_f),np.mean(testa_f)))

# %%
_exp_name='mixup'
model1 = Classifier(Residual_Block, [2, 2, 2, 2]).to(device)

model2 = Classifier(Residual_Block, [2, 2, 2, 2]).to(device)

model3 = Classifier(Residual_Block, [2, 2, 2, 2]).to(device)

model4 = Classifier(Residual_Block, [2, 2, 2, 2]).to(device)

model5 = Classifier(Residual_Block, [2, 2, 2, 2]).to(device)

model1.load_state_dict(torch.load(f"/content/drive/MyDrive/ML/HW3/{_exp_name}_Fold1_best.ckpt"))
model2.load_state_dict(torch.load(f"/content/drive/MyDrive/ML/HW3/{_exp_name}_Fold2_best.ckpt"))
model3.load_state_dict(torch.load(f"/content/drive/MyDrive/ML/HW3/{_exp_name}_Fold3_best.ckpt"))
model4.load_state_dict(torch.load(f"/content/drive/MyDrive/ML/HW3/{_exp_name}_Fold4_best.ckpt"))
model5.load_state_dict(torch.load(f"/content/drive/MyDrive/ML/HW3/{_exp_name}_Fold5_best.ckpt"))
# Out:
# <All keys matched successfully>

# %%
prediction = []
model.eval()
model1.eval()
model2.eval()
model3.eval()
model4.eval()
model5.eval()
with torch.no_grad():
    for data,_ in test_loader:
        data_original = data.to(device)
        data_flip = transforms.RandomHorizontalFlip(1)(data).to(device)
        data_rotation = transforms.RandomRotation(20)(data).to(device)
        data_gray = transforms.RandomGrayscale(1)(data).to(device)
        data_jitter = transforms.ColorJitter(brightness=0.1, contrast=0.1)(data).to(device)

        test_pred11 = model1(data_original)
        test_pred12 = model1(data_flip)
        test_pred13 = model1(data_rotation)
        test_pred14 = model1(data_gray)
        test_pred15 = model1(data_jitter)
        #test_pred16 = model1(data_per)
        test_pred1 = 0.2*test_pred11 + 0.5*test_pred12 + 0.1*test_pred13 + 0.1*test_pred14 + 0.1*test_pred15

        test_pred21 = model2(data_original)
        test_pred22 = model2(data_flip)
        test_pred23 = model2(data_rotation)
        test_pred24 = model2(data_gray)
        test_pred25 = model2(data_jitter)
        #test_pred26 = model2(data_per)
        test_pred2 = 0.2*test_pred21 + 0.5*test_pred22 + 0.1*test_pred23 + 0.1*test_pred24 + 0.1*test_pred25

        test_pred31 = model3(data_original)
        test_pred32 = model3(data_flip)
        test_pred33 = model3(data_rotation)
        test_pred34 = model3(data_gray)
        test_pred35 = model3(data_jitter)
        #test_pred36 = model3(data_per)
        test_pred3 = 0.2*test_pred31 + 0.5*test_pred32 + 0.1*test_pred33 + 0.1*test_pred34 + 0.1*test_pred35

        test_pred41 = model4(data_original)
        test_pred42 = model4(data_flip)
        test_pred43 = model4(data_rotation)
        test_pred44 = model4(data_gray)
        test_pred45 = model4(data_jitter)
        #test_pred46 = model4(data_per)
        test_pred4 = 0.2*test_pred41 + 0.5*test_pred42 + 0.1*test_pred43 + 0.1*test_pred44 + 0.1*test_pred45


        test_pred51 = model5(data_original)
        test_pred52 = model5(data_flip)
        test_pred53 = model5(data_rotation)
        test_pred54 = model5(data_gray)
        test_pred55 = model5(data_jitter)
        #test_pred56 = model5(data_per)
        test_pred5 = 0.2*test_pred51 + 0.5*test_pred52 + 0.1*test_pred53 + 0.1*test_pred54 + 0.1*test_pred55

        test_pred = (test_pred1+test_pred2+test_pred3+test_pred4+test_pred5)/5
        test_label = np.argmax(test_pred.cpu().data.numpy(), axis=1)
        prediction += test_label.squeeze().tolist()

# %%
#create test csv
def pad4(i):
    return "0"*(4-len(str(i)))+str(i)
df = pd.DataFrame()
df["Id"] = [pad4(i) for i in range(1,len(test_set)+1)]
df["Category"] = prediction
df.to_csv("/content/drive/MyDrive/ML/HW3/submission.csv",index = False)

# %%
# best public score 0.88745
# Residual model with dropout(0.5)
# RandomHorizontalFlip(0.5) RandomRotation(20) RandomGrayScale() and Normalization and mixup
# train on both train and validation data for 150 epochs
# CrossEntropy with label_smoothing=0.2
# Adam with lr = 0.001, weight_decay = 0.00001
# 5 fold cross validation and ensemble, cross_validation with lr=0.0001 and weight_decay=0.00001
# test time augmentation [horizontalflip(1) rotation(20) grayscale(1) colorjitter(brightness=0.1, contrast=0.1)], ratio: original:0.2, flip:0.5, rotation:0.1, grayscale:0.1, colorjitter:0.1

# %% [markdown]
# # Q1. Augmentation Implementation
# ## Implement augmentation by finishing train_tfm in the code with image size of your choice.
# ## Directly copy the following block and paste it on GradeScope after you finish the code
# ### Your train_tfm must be capable of producing 5+ different results when given an identical image multiple times.
# ### Your  train_tfm in the report can be different from train_tfm in your training code.

# %%
train_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    transforms.Resize((128, 128)),
    # You need to add some transforms here.
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.RandomGrayscale(),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.RandomInvert(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],std=[0.5, 0.5, 0.5])
])

# %% [markdown]
# # Q2. Residual Implementation
# ![](https://i.imgur.com/GYsq1Ap.png)
# ## Directly copy the following block and paste it on GradeScope after you finish the code

# %%
class Residual_Network(nn.Module):
    def __init__(self):
        super(Residual_Network, self).__init__()
        
        self.cnn_layer1 = nn.Sequential(
            nn.Conv2d(3, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
        ) # (64, 128, 128)

        self.cnn_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
        ) # (64, 128, 128)

        self.cnn_layer3 = nn.Sequential(
            nn.Conv2d(64, 128, 3, 2, 1),
            nn.BatchNorm2d(128),
        ) # (128, 64, 64)

        self.cnn_layer4 = nn.Sequential(
            nn.Conv2d(128, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
        ) # (128, 64, 64)
        self.cnn_layer5 = nn.Sequential(
            nn.Conv2d(128, 256, 3, 2, 1),
            nn.BatchNorm2d(256),
        ) # (256, 32, 32)
        self.cnn_layer6 = nn.Sequential(
            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
        ) # (256, 32, 32)
        self.fc_layer = nn.Sequential(
            nn.Linear(256* 32* 32, 256),
            nn.ReLU(),
            nn.Linear(256, 11)
        ) 
        self.relu = nn.ReLU()
        '''self.down_sample = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )'''
    def forward(self, x):
        # input (x): [batch_size, 3, 128, 128]
        # output: [batch_size, 11]

        # Extract features by convolutional layers.
        x1 = self.cnn_layer1(x)
        x1 = self.relu(x1)
        
        x2 = self.cnn_layer2(x1)
        x2 = x2 + x1
        x2 = self.relu(x2)
        
        x3 = self.cnn_layer3(x2)
        x3 = self.relu(x3)
        
        x4 = self.cnn_layer4(x3)
        x4 = x4 + x3
        x4 = self.relu(x4)
        
        x5 = self.cnn_layer5(x4)
        x5 = self.relu(x5)
        
        x6 = self.cnn_layer6(x5)
        x6 = x6 + x5
        x6 = self.relu(x6)
        
        # The extracted feature map must be flatten before going to fully-connected layers.
        xout = x6.flatten(1)

        # The features are transformed by fully-connected layers to obtain the final logits.
        xout = self.fc_layer(xout)
        return xout
