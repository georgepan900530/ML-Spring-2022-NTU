# %% [markdown]
# # **Homework 7 - Bert (Question Answering)**
#
# If you have any questions, feel free to email us at mlta-2022-spring@googlegroups.com
#
#
#
# Slide:    [Link](https://docs.google.com/presentation/d/1H5ZONrb2LMOCixLY7D5_5-7LkIaXO6AGEaV2mRdTOMY/edit?usp=sharing)　Kaggle: [Link](https://www.kaggle.com/c/ml2022spring-hw7)　Data: [Link](https://drive.google.com/uc?id=1AVgZvy3VFeg0fX-6WQJMHPVrx3A-M1kb)

# %% [markdown]
# ## Task description
# - Chinese Extractive Question Answering
#   - Input: Paragraph + Question
#   - Output: Answer
#
# - Objective: Learn how to fine tune a pretrained model on downstream task using transformers
#
# - Todo
#     - Fine tune a pretrained chinese BERT model
#     - Change hyperparameters (e.g. doc_stride)
#     - Apply linear learning rate decay
#     - Try other pretrained models
#     - Improve preprocessing
#     - Improve postprocessing
# - Training tips
#     - Automatic mixed precision
#     - Gradient accumulation
#     - Ensemble
#
# - Estimated training time (tesla t4 with automatic mixed precision enabled)
#     - Simple: 8mins
#     - Medium: 8mins
#     - Strong: 25mins
#     - Boss: 2.5hrs

# %% [markdown]
# ## Download Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download link 1
# !gdown --id '1AVgZvy3VFeg0fX-6WQJMHPVrx3A-M1kb' --output hw7_data.zip

# Download Link 2 (if the above link fails) 
# !gdown --id '1qwjbRjq481lHsnTrrF4OjKQnxzgoLEFR' --output hw7_data.zip

# Download Link 3 (if the above link fails) 
# !gdown --id '1QXuWjNRZH6DscSd6QcRER0cnxmpZvijn' --output hw7_data.zip

# !unzip -o hw7_data.zip

# For this HW, K80 < P4 < T4 < P100 <= T4(fp16) < V100
# !nvidia-smi
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1AVgZvy3VFeg0fX-6WQJMHPVrx3A-M1kb
# To: /content/hw7_data.zip
# 100% 9.57M/9.57M [00:00<00:00, 219MB/s]
# Archive:  hw7_data.zip
#   inflating: hw7_dev.json
#   inflating: hw7_test.json
#   inflating: hw7_train.json
# Tue Apr 19 05:39:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Install transformers
#
# Documentation for the toolkit:　https://huggingface.co/transformers/

# %%
# You are allowed to change version of transformers or use other toolkits
# !pip install transformers==4.5.0
# Out:
# Collecting transformers==4.5.0
#   Downloading transformers-4.5.0-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 14.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.0) (2019.12.20)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 84.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.0) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.0) (1.21.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.0) (3.6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 75.4 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.0) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.0) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.0) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.5.0) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.5.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.5.0) (3.0.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.0) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.0) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.0) (1.15.0)
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.49 tokenizers-0.10.3 transformers-4.5.0

# %% [markdown]
# ## Import Packages

# %%
import json
import numpy as np
import random
import torch
from torch.utils.data import DataLoader, Dataset 
from transformers import AdamW, BertForQuestionAnswering, BertTokenizerFast, get_linear_schedule_with_warmup

from tqdm.auto import tqdm

device = "cuda" if torch.cuda.is_available() else "cpu"

# Fix random seed for reproducibility
def same_seeds(seed):
	  torch.manual_seed(seed)
	  if torch.cuda.is_available():
		    torch.cuda.manual_seed(seed)
		    torch.cuda.manual_seed_all(seed)
	  np.random.seed(seed)
	  random.seed(seed)
	  torch.backends.cudnn.benchmark = False
	  torch.backends.cudnn.deterministic = True
same_seeds(0)

# %%
# Change "fp16_training" to True to support automatic mixed precision training (fp16)	
fp16_training = True

if fp16_training:
    # !pip install accelerate==0.2.0
    from accelerate import Accelerator
    accelerator = Accelerator(fp16=True)
    device = accelerator.device

# Documentation for the toolkit:  https://huggingface.co/docs/accelerate/
# Out:
# Collecting accelerate==0.2.0
#   Downloading accelerate-0.2.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.1 MB/s
# Collecting pyaml>=20.4.0
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from accelerate==0.2.0) (1.10.0+cu111)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=20.4.0->accelerate==0.2.0) (3.13)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4.0->accelerate==0.2.0) (4.1.1)
# Installing collected packages: pyaml, accelerate
# Successfully installed accelerate-0.2.0 pyaml-21.10.1

# %% [markdown]
# ## Load Model and Tokenizer

# %%
model1 = BertForQuestionAnswering.from_pretrained("/content/drive/MyDrive/ML/HW7/models/bert1").to(device)
model2 = BertForQuestionAnswering.from_pretrained("/content/drive/MyDrive/ML/HW7/models/bert2").to(device)
model3 = BertForQuestionAnswering.from_pretrained("/content/drive/MyDrive/ML/HW7/models/bert3").to(device)
model4 = BertForQuestionAnswering.from_pretrained("/content/drive/MyDrive/ML/HW7/models/bert4").to(device)
tokenizer = BertTokenizerFast.from_pretrained("hfl/chinese-macbert-large")

# You can safely ignore the warning message (it pops up because new prediction heads for QA are initialized randomly)
# Out:
# Downloading:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/269k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/19.0 [00:00<?, ?B/s]

# %% [markdown]
# ## Read Data
#
# - Training set: 31690 QA pairs
# - Dev set: 4131  QA pairs
# - Test set: 4957  QA pairs
#
# - {train/dev/test}_questions:
#   - List of dicts with the following keys:
#    - id (int)
#    - paragraph_id (int)
#    - question_text (string)
#    - answer_text (string)
#    - answer_start (int)
#    - answer_end (int)
# - {train/dev/test}_paragraphs:
#   - List of strings
#   - paragraph_ids in questions correspond to indexs in paragraphs
#   - A paragraph may be used by several questions

# %%
def read_data(file):
    with open(file, 'r', encoding="utf-8") as reader:
        data = json.load(reader)
    return data["questions"], data["paragraphs"]

train_questions, train_paragraphs = read_data("hw7_train.json")
dev_questions, dev_paragraphs = read_data("hw7_dev.json")
test_questions, test_paragraphs = read_data("hw7_test.json")

# %% [markdown]
# ## Tokenize Data

# %%
# Tokenize questions and paragraphs separately
# 「add_special_tokens」 is set to False since special tokens will be added when tokenized questions and paragraphs are combined in datset __getitem__ 

train_questions_tokenized = tokenizer([train_question["question_text"] for train_question in train_questions], add_special_tokens=False)
dev_questions_tokenized = tokenizer([dev_question["question_text"] for dev_question in dev_questions], add_special_tokens=False)
test_questions_tokenized = tokenizer([test_question["question_text"] for test_question in test_questions], add_special_tokens=False) 

train_paragraphs_tokenized = tokenizer(train_paragraphs, add_special_tokens=False)
dev_paragraphs_tokenized = tokenizer(dev_paragraphs, add_special_tokens=False)
test_paragraphs_tokenized = tokenizer(test_paragraphs, add_special_tokens=False)

# You can safely ignore the warning message as tokenized sequences will be futher processed in datset __getitem__ before passing to model

# %% [markdown]
# ## Dataset and Dataloader

# %%
class QA_Dataset(Dataset):
    def __init__(self, split, questions, tokenized_questions, tokenized_paragraphs):
        self.split = split
        self.questions = questions
        self.tokenized_questions = tokenized_questions
        self.tokenized_paragraphs = tokenized_paragraphs
        self.max_question_len = 60
        self.max_paragraph_len = 400
        
        ##### TODO: Change value of doc_stride #####
        self.doc_stride = 350

        # Input sequence length = [CLS] + question + [SEP] + paragraph + [SEP]
        self.max_seq_len = 1 + self.max_question_len + 1 + self.max_paragraph_len + 1

    def __len__(self):
        return len(self.questions)

    def __getitem__(self, idx):
        question = self.questions[idx]
        tokenized_question = self.tokenized_questions[idx]
        tokenized_paragraph = self.tokenized_paragraphs[question["paragraph_id"]]

        ##### TODO: Preprocessing #####
        # Hint: How to prevent model from learning something it should not learn

        if self.split == "train":
            # Convert answer's start/end positions in paragraph_text to start/end positions in tokenized_paragraph  
            answer_start_token = tokenized_paragraph.char_to_token(question["answer_start"])
            answer_end_token = tokenized_paragraph.char_to_token(question["answer_end"])

            # A single window is obtained by slicing the portion of paragraph containing the answer
            # mid is not always the answer
            mid = int((answer_start_token + answer_end_token) // (2 + random.uniform(-3,3)))
            paragraph_start = max(0, min(mid - self.max_paragraph_len // 2, len(tokenized_paragraph) - self.max_paragraph_len))
            paragraph_end = paragraph_start + self.max_paragraph_len
            
            # Slice question/paragraph and add special tokens (101: CLS, 102: SEP)
            input_ids_question = [101] + tokenized_question.ids[:self.max_question_len] + [102] 
            input_ids_paragraph = tokenized_paragraph.ids[paragraph_start : paragraph_end] + [102]		
            
            # Convert answer's start/end positions in tokenized_paragraph to start/end positions in the window  
            answer_start_token += len(input_ids_question) - paragraph_start
            answer_end_token += len(input_ids_question) - paragraph_start
            
            # Pad sequence and obtain inputs to model 
            input_ids, token_type_ids, attention_mask = self.padding(input_ids_question, input_ids_paragraph)
            return torch.tensor(input_ids), torch.tensor(token_type_ids), torch.tensor(attention_mask), answer_start_token, answer_end_token

        # Validation/Testing
        else:
            input_ids_list, token_type_ids_list, attention_mask_list = [], [], []
            
            # Paragraph is split into several windows, each with start positions separated by step "doc_stride"
            for i in range(0, len(tokenized_paragraph), self.doc_stride):
                
                # Slice question/paragraph and add special tokens (101: CLS, 102: SEP)
                input_ids_question = [101] + tokenized_question.ids[:self.max_question_len] + [102]
                input_ids_paragraph = tokenized_paragraph.ids[i : i + self.max_paragraph_len] + [102]
                
                # Pad sequence and obtain inputs to model
                input_ids, token_type_ids, attention_mask = self.padding(input_ids_question, input_ids_paragraph)
                
                input_ids_list.append(input_ids)
                token_type_ids_list.append(token_type_ids)
                attention_mask_list.append(attention_mask)
            
            return torch.tensor(input_ids_list), torch.tensor(token_type_ids_list), torch.tensor(attention_mask_list)

    def padding(self, input_ids_question, input_ids_paragraph):
        # Pad zeros if sequence length is shorter than max_seq_len
        padding_len = self.max_seq_len - len(input_ids_question) - len(input_ids_paragraph)
        # Indices of input sequence tokens in the vocabulary
        input_ids = input_ids_question + input_ids_paragraph + [0] * padding_len
        # Segment token indices to indicate first and second portions of the inputs. Indices are selected in [0, 1]
        token_type_ids = [0] * len(input_ids_question) + [1] * len(input_ids_paragraph) + [0] * padding_len
        # Mask to avoid performing attention on padding token indices. Mask values selected in [0, 1]
        attention_mask = [1] * (len(input_ids_question) + len(input_ids_paragraph)) + [0] * padding_len
        
        return input_ids, token_type_ids, attention_mask

train_set = QA_Dataset("train", train_questions, train_questions_tokenized, train_paragraphs_tokenized)
dev_set = QA_Dataset("dev", dev_questions, dev_questions_tokenized, dev_paragraphs_tokenized)
test_set = QA_Dataset("test", test_questions, test_questions_tokenized, test_paragraphs_tokenized)

train_batch_size = 4

# Note: Do NOT change batch size of dev_loader / test_loader !
# Although batch size=1, it is actually a batch consisting of several windows from the same QA pair
train_loader = DataLoader(train_set, batch_size=train_batch_size, shuffle=True, pin_memory=True)
dev_loader = DataLoader(dev_set, batch_size=1, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=1, shuffle=False, pin_memory=True)

# %% [markdown]
# ## Function for Evaluation

# %%
def evaluate(data, output1, output2, output3, output4):
    ##### TODO: Postprocessing #####
    # There is a bug and room for improvement in postprocessing 
    # Hint: Open your prediction file to see what is wrong 
    
    answer = ''
    max_prob = float('-inf')
    num_of_windows = data[0].shape[1]
    start_logits = (output1.start_logits + output2.start_logits + output3.start_logits + output4.start_logits) / 4
    end_logits = (output1.end_logits + output2.end_logits + output3.end_logits + output4.end_logits) / 4
    for k in range(num_of_windows):
        # Obtain answer by choosing the most probable start position / end position
        mask = data[1][0][k].bool() & data[2][0][k].bool() # attention mask
        mask = mask.to(device)
        masked_output_start = torch.masked_select(start_logits[k], mask)[:-1].to(device)
        start_prob, start_index = torch.max(masked_output_start, dim=0)
        masked_output_end = torch.masked_select(end_logits[k], mask)[start_index:-1].to(device)
        end_prob, end_index = torch.max(masked_output_end, dim=0)
        end_index += start_index 
        # Probability of answer is calculated as sum of start_prob and end_prob
        prob = start_prob + end_prob
        masked_data = torch.masked_select(data[0][0][k].to(device), mask)[:-1].to(device)
        # Replace answer if calculated probability is larger than previous windows
        # print(start_index,end_index)
        if (prob > max_prob) and (end_index >= start_index) and (end_index - start_index <= 30):
            max_prob = prob
            # Convert tokens to chars (e.g. [1920, 7032] --> "大 金")
            #answer = tokenizer.decode(data[0][0][k][start_index : end_index + 1])
            answer = tokenizer.decode(masked_data[start_index : end_index + 1])

    
    # Remove spaces in answer (e.g. "大 金" --> "大金")
    answer = answer.replace(' ','')
    print("prediction",answer)
    return answer

# %% [markdown]
# ## Testing

# %%
print("Evaluating Test Set ...")

result = []

model1.eval()
model2.eval()
model3.eval()
model4.eval()
with torch.no_grad():
    for data in tqdm(test_loader):
        output1 = model1(input_ids=data[0].squeeze(dim=0).to(device), token_type_ids=data[1].squeeze(dim=0).to(device),
                       attention_mask=data[2].squeeze(dim=0).to(device))
        output2 = model2(input_ids=data[0].squeeze(dim=0).to(device), token_type_ids=data[1].squeeze(dim=0).to(device),
                       attention_mask=data[2].squeeze(dim=0).to(device))
        output3 = model3(input_ids=data[0].squeeze(dim=0).to(device), token_type_ids=data[1].squeeze(dim=0).to(device),
                       attention_mask=data[2].squeeze(dim=0).to(device))
        output4 = model4(input_ids=data[0].squeeze(dim=0).to(device), token_type_ids=data[1].squeeze(dim=0).to(device),
                       attention_mask=data[2].squeeze(dim=0).to(device))
        result.append(evaluate(data, output1, output2, output3, output4))

result_file = "result.csv"
with open(result_file, 'w') as f:	
	  f.write("ID,Answer\n")
	  for i, test_question in enumerate(test_questions):
        # Replace commas in answers with empty strings (since csv is separated by comma)
        # Answers in kaggle are processed in the same way
		    f.write(f"{test_question['id']},{result[i].replace(',','')}\n")

print(f"Completed! Result is in {result_file}")
# Out:
# Evaluating Test Set ...
#   0%|          | 0/4957 [00:00<?, ?it/s]
# prediction 白色羽毛
# prediction 《諸羅縣志》
# prediction 袁晁
# prediction 柏林陸軍學院
# prediction 一局特殊的決勝局
# prediction 聶耳
# prediction 1884年
# prediction 西漢的版圖向西擴張
# prediction 英國
# prediction 醜化對手
# prediction 周星馳
# prediction 三中老
# prediction 無障礙環境
# prediction anticipation
# prediction 2004年
# prediction 硫化氫
# prediction 華萊士
# prediction 外面的部份溫度會比內部核心的低
# prediction 經濟
# prediction 100公里
# prediction 愛爾蘭語
# prediction 荷蘭
# prediction 硫磺
# prediction 塞爾維亞反對黨
# prediction 1910年代
# prediction 外交活動
# prediction 拉丁文
# prediction 猶太基督徒
# prediction 1964年
# prediction 霍克菲爾德
# prediction 北京市原有的46所高校中，有13所被迫外遷
# prediction 《薩蒂里卡》
# prediction 灣仔
# prediction 《鄭和航海圖》中稱為萬生石塘嶼
# prediction 形容一種無限制的、自私、而野蠻的競爭情況
# prediction 1968年
# prediction 新北市
# prediction 小白宮
# prediction 沒有
# prediction 南人
# prediction 宋端宗
# prediction 四千名
# prediction 46億年
# prediction 1070年
# prediction 國民養老保險法
# prediction 水上報告廳
# prediction 1929年
# prediction 航天技術
# prediction 1932年
# prediction 大型購物中心megabox開幕
# prediction 康熙帝
# prediction 自強學堂
# prediction 1960年代
# prediction 亞歷山大一世被刺殺
# prediction 紐約市
# prediction 基督教
# prediction 預覽阿爾法版本
# prediction 100萬
# prediction 新北市
# prediction 佔領行動
# prediction 路易十五
# prediction 中國國民黨
# prediction 中生代侏羅紀
# prediction 阿拉貢國王卡洛斯三世
# prediction 熱帶雨林氣候
# prediction 意圖完全擺脫漢朝的控制
# prediction 蔣中正
# prediction 東漢
# prediction 前三點起落架
# prediction 弘治十二年
# prediction 亞洲
# prediction 1996年
# prediction 德意志聯邦共和國
# prediction 氦
# prediction 西班牙人入侵納瓦爾
# prediction 交通運輸部
# prediction 高麗大學校主樓
# prediction 朱少文
# prediction 羽柴秀吉
# prediction 俾斯麥
# prediction 金泳三
# prediction 1958年
# prediction 靈魂
# prediction 科龍港
# prediction 蓋爾人
# prediction 四次重差觀測術
# prediction 西漢元封二年
# prediction 隋滅南陳
# prediction 佛教
# prediction 1861年
# prediction 豐臣秀吉
# prediction 三吳地區
# prediction 英國
# prediction 大躍進運動
# prediction 國立武昌高等師範學校
# prediction 蘇利南
# prediction 1934年
# prediction 檸檬酸咖啡因療法
# prediction 1913年
# prediction 1949年
# prediction 大象
# prediction 1915年
# prediction 1000年
# prediction 有絲分裂
# prediction 德國
# prediction 高盧帝國
# prediction 仁祖
# prediction 十個
# prediction 佛學論書
# prediction 臺中高農
# prediction 下薩克森邦
# prediction 三天
# prediction 1944年
# prediction 安娜·德·薩伏伊皇后
# prediction 咸豐帝
# prediction 哈林河
# prediction 孟加拉
# prediction 男中音
# prediction 中原
# prediction 60
# prediction 威廉·洛厄爾·普特南
# prediction 中華人民共和國主席
# prediction 德國
# prediction 陳寅恪
# prediction 刺殺
# prediction 未標準化
# prediction 二千九百公尺
# prediction 1939年
# prediction 害怕德軍在東線戰線上沒有足夠兵力應付俄國
# prediction 福建林家
# prediction 用來運貨
# prediction 公民權
# prediction 西人黨
# prediction 2013年
# prediction 臺北
# prediction 查莫洛人
# prediction 杭縣
# prediction 蘇聯
# prediction 38%
# prediction 1941年
# prediction 多腔磁控管雷達技術
# prediction 點石齋畫報
# prediction 南越地區
# prediction 1988年
# prediction 上吊方式
# prediction 吉米卡特
# prediction 沈括
# prediction 《布告各省公啟》
# prediction 阿拉里克
# prediction 德蘇戰爭
# prediction 髒層
# prediction 工業國家
# prediction 1949年
# prediction 最終解決德國問題條約
# prediction 清光緒十七年
# prediction 「雕像」
# prediction 防止中國共產黨滲透
# prediction 65,000平方公里
# prediction 乙醚
# prediction 唐太宗
# prediction 卡爾梅克人
# prediction 1969年11月12日
# prediction 63位
# prediction 副大法官
# prediction 古希臘時代
# prediction 盧安達語
# prediction 填海造地
# prediction 蔣中正
# prediction 農民
# prediction 網景通訊公司
# prediction 9月1日
# prediction 1999年
# prediction 《天淨沙》
# prediction 七十年代
# prediction 公元68年
# prediction 趙佗
# prediction 莎草紙
# prediction 岑智明
# prediction 普魯士大獲全勝
# prediction 公元前362年
# prediction 創建強力政府
# prediction 28歲
# prediction 1950年
# prediction 保加利亞
# prediction 與燃煤取暖或燃油取暖相比，它的效率比較低
# prediction 10度
# prediction 日本社會黨
# prediction 西歐
# prediction 波士頓
# prediction 1992年
# prediction 下旋球
# prediction 屯田兵制度
# prediction 明朝
# prediction 文藝復興
# prediction 2000年
# prediction 1998年
# prediction 道縣玉蟾岩
# prediction 德
# prediction 森林
# prediction 阿森納女子足球俱樂部
# prediction 社會主義市場經濟」
# prediction 較有消費能力的居民
# prediction 1920年
# prediction 美元
# prediction 多倫多
# prediction 在列車前面拉動
# prediction 彌爾
# prediction 中央情報局
# prediction 梅莉·史翠普
# prediction 在時域上數學形式為連續函式的訊號
# prediction 開始顯現本土特色
# prediction 亞歷山大一世
# prediction 威尼斯影展
# prediction 清涼
# prediction 新北市
# prediction 聯盟合作
# prediction 甲午戰爭
# prediction 克孜勒
# prediction 三分天災，七分人禍
# prediction 好在歷史是人民寫的
# prediction 美觀
# prediction 臺中市精密機械科技創新園區
# prediction 西部地區
# prediction 1982年
# prediction 1428年
# prediction 天子
# prediction 塔特拉山
# prediction 莫斯科中山大學
# prediction 發明家
# prediction 2006年
# prediction 沒有
# prediction 《人體器官移植條例》
# prediction 1262年
# prediction 增加米、糖等農作物產量
# prediction 三倍
# prediction 質量大於0.4太陽質量的恆星，會膨脹
# prediction 颱風
# prediction 2016年
# prediction 1972－1973年
# prediction 韓國歷史上第一家商業銀行，而目前國民銀行是韓國最大的銀行。
# prediction 「第一所美式大學」
# prediction 鋁土礦
# prediction 萬神廟
# prediction 布農族
# prediction 黑死病
# prediction 2007年
# prediction 查普曼
# prediction 與比提尼亞國王的性行為中處於被動地位
# prediction 2009年
# prediction 洛杉磯湖人
# prediction 溥[UNK]
# prediction 副主席
# prediction 決勝局必定是單數局
# prediction 廣東省政府委員會
# prediction 遊戲
# prediction 1951年
# prediction 漢語拼音方案
# prediction 1984年
# prediction 高架車站
# prediction 下薩克森邦
# prediction 法蘭西第二帝國
# prediction 東南亞的大城市
# prediction 全勝
# prediction 夜間攔截任務
# prediction 哥白尼日心說
# prediction 濃度低
# prediction 光緒
# prediction 明朝
# prediction 1848年
# prediction 1954年
# prediction 1997年
# prediction 自由韓國黨
# prediction 《南華早報》
# prediction 可以麻痺嗅覺神經
# prediction 佛像
# prediction 阿聯
# prediction 交通基建
# prediction 步兵師
# prediction 日本肥前國平戶島
# prediction 以天狼星在東方地平線的出現
# prediction 自律心肌細胞
# prediction 1961年
# prediction 德語地區
# prediction 離島機場
# prediction 1237年
# prediction 東羅馬
# prediction 晉恭帝
# prediction 德國
# prediction 美國律師協會
# prediction 1654年
# prediction 唐代
# prediction 美川王
# prediction 胡安·林茲
# prediction 日本
# prediction 1998年1月1日
# prediction 第一星族
# prediction 司馬休之
# prediction 鈣離子
# prediction 383年
# prediction 羅納爾迪尼奧
# prediction 戰
# prediction 火山活動
# prediction 利奧三世
# prediction 拉丁字母
# prediction 提升飛機的飛行安全
# prediction 丁基羥基甲苯
# prediction 中緬大戰
# prediction 斯德哥爾摩
# prediction 第三紀中新世
# prediction 中華民國
# prediction 高麗時期
# prediction 齋藤季治郎
# prediction 1958年
# prediction 《馬德里議定書》
# prediction 446種，粳稻和[UNK]稻共1,083
# prediction 曹魏故都智慧之旅
# prediction 亞德港
# prediction 布爾什維克革命
# prediction 金本位制度
# prediction 邊沁
# prediction 紅色
# prediction 1928年
# prediction 商品期貨
# prediction 十多個
# prediction 300美元
# prediction 楊宇霆
# prediction 貴州省最大的體育場所
# prediction 元世祖
# prediction 混合動力自行車
# prediction 數學
# prediction 亞熱帶季風氣候
# prediction 經濟
# prediction 目前沒有觀察到任何語言純[UNK]以力道來區分不同輔音
# prediction 朱一貴
# prediction 農業
# prediction 失一分
# prediction 銃炮
# prediction 1960年、1961年
# prediction 1980年代
# prediction 凱·艾維州長
# prediction [UNK]人國
# prediction 1980年
# prediction 希伯來文
# prediction 第四心音
# prediction 2010年
# prediction 武漢
# prediction 1868年
# prediction 托土拉島
# prediction 中華民國
# prediction 倫敦大學
# prediction 下坡
# prediction 岡仁波齊峰
# prediction 1973年
# prediction 突厥語民族
# prediction 三菱重工業長崎造船廠
# prediction 南斯拉夫社會主義聯邦共和國
# prediction 民主制度的恢復
# prediction 硫化物
# prediction 與丹尼索瓦人混血
# prediction 忽必烈
# prediction 中國
# prediction 2000年
# prediction 蝸牛狀
# prediction 奧地利
# prediction 1954年
# prediction 韓國
# prediction 維京戈達島
# prediction 1956年
# prediction 史都華中校
# prediction 1910年
# prediction 突厥
# prediction 。
# prediction 1988年
# prediction 2011年
# prediction 通過非暴力方式反對環境破壞行為，將問題帶到公眾前辯論
# prediction 巴爾的摩市
# prediction 中華民國政府
# prediction 社團部
# prediction 認為伊迪絲分散了托爾金對學業的注意力
# prediction 電子郵件
# prediction 孔子
# prediction 楊浦區大連路的地鐵站2號口
# prediction 2005年
# prediction 中國對處決犯人一直採取保密的措施
# prediction 烏爾班八世
# prediction 60年代
# prediction 雙循環泵功能
# prediction 1809年
# prediction 國內市場狹小而無法發展
# prediction 民國32年
# prediction 為迅速取得西線勝利
# prediction 幅員遼闊
# prediction 伯克制
# prediction 不如當時最好的活塞發動機
# prediction 國家起源說
# prediction 路易·巴斯德
# prediction 中部科學園區
# prediction 宣統三年
# prediction 1991年
# prediction 三國史記
# prediction 第二次工業革命
# prediction 突厥語
# prediction 拉海納
# prediction 約翰·坎貝爾
# prediction 8小時
# prediction 百變天后
# prediction 民國16年
# prediction 國立廣東大學
# prediction 亞伯拉罕諸教
# prediction 六億七千多萬美金
# prediction 妖怪
# prediction 專家
# prediction 低地蘇格蘭語
# prediction 礦物的風化
# prediction 非常混亂
# prediction 阿爾泰語系
# prediction 皇太極
# prediction 信陽
# prediction 5,000
# prediction 准將
# prediction 質量
# prediction 科技
# prediction 媽祖
# prediction 6個
# prediction 計劃委員會
# prediction 15米
# prediction 蘇丹
# prediction 雲騎尉
# prediction [UNK]
# prediction 2020年代中期
# prediction 恆星
# prediction 那拉氏
# prediction 辛酉政變
# prediction 銅的礦物
# prediction 統一企業
# prediction 小數
# prediction 生物學研究
# prediction 陳誠
# prediction 孫中山
# prediction 蘇俄退出第一次世界大戰
# prediction 德國工業
# prediction 九一八事變
# prediction 1978年
# prediction 日本天皇
# prediction 731美元
# prediction 蒙德維爾遺址
# prediction 嘉義市
# prediction 保護農業生產
# prediction 肺呼氣機制
# prediction 五角星
# prediction 波斯薩珊王朝
# prediction 航海貿易中心
# prediction 海岸高速路阿22
# prediction 降低了紅外線特徵
# prediction 中共中央政治局常委會
# prediction 1945年
# prediction 一條簡單的直線
# prediction 236路
# prediction 盟旗制
# prediction 臺南州
# prediction 布朗茜
# prediction 南緯30度
# prediction 一次大戰期間
# prediction 大滿貫男子單打比賽
# prediction 中華人民共和國
# prediction 保守派
# prediction 網景公司
# prediction 《全唐詩》
# prediction 1912年
# prediction 1982年
# prediction 七年
# prediction 奧地利
# prediction 貝爾實驗室
# prediction 陳奕迅
# prediction 吳三連
# prediction 1917年
# prediction 米勒
# prediction 1月8日
# prediction 掃雷艇部隊
# prediction 海都聯軍被海山和晉王甘麻剌擊潰
# prediction 多黨制
# prediction 民國9年
# prediction 80年代
# prediction 公元前第一個千年的中期
# prediction 東晉時期
# prediction 線傳飛控
# prediction 光明星4號
# prediction 烏孜別克人
# prediction 2555公里
# prediction 第一次國共內戰
# prediction 121年
# prediction 茲維亞德·加姆薩胡爾季阿
# prediction 避免造成路口交通不暢
# prediction 小口徑速射炮
# prediction 荀子
# prediction 清朝
# prediction 7年
# prediction 微笑單車
# prediction 與動力系統結合，將過去兩個分離的系統的控制整合使用
# prediction 中國政法大學
# prediction 瑪黛茶
# prediction 二戰時期
# prediction 鈉鹽
# prediction 江戶時代
# prediction 民國4年
# prediction 西格里
# prediction 1992年
# prediction 軍政
# prediction 貝爾根
# prediction 青蓮居士
# prediction 朱棣
# prediction 十億韓國
# prediction 低稅賦
# prediction 小選舉區制
# prediction 科索沃
# prediction 反對資產階級自由化
# prediction 自由放任
# prediction 工業生物技術
# prediction 四年
# prediction 段祺瑞
# prediction 湯瑪斯伊格頓
# prediction 溪南
# prediction 1925年
# prediction 蝸頂
# prediction 高速發展
# prediction 3%
# prediction 後座雷達官
# prediction 1975年
# prediction 氫硫酸
# prediction 經濟的快速增長
# prediction 使編輯長頁面更容易
# prediction 黨費
# prediction 在同一個生物體中可能同時有雄性及雌性的生殖器官
# prediction 經濟建設
# prediction 《中華民國臨時政府組織大綱》
# prediction 港式酒樓
# prediction 社會政治運動
# prediction 帕吉勒提河
# prediction 「西南美麗的地方」
# prediction 「天」的至高無上
# prediction 開羅
# prediction 2013年
# prediction 林紹良
# prediction 1955年
# prediction 多倫多運輸局
# prediction 前一世紀
# prediction 柵欄
# prediction 1910年
# prediction 老虎
# prediction 狄拉克
# prediction 唐太宗
# prediction 健康寫實電影
# prediction 1956年7月
# prediction 天狼星
# prediction 中生代
# prediction 伊爾庫茨克國立大學
# prediction 鐵木真
# prediction 23406人
# prediction 1789年
# prediction 兩個
# prediction 松陽縣
# prediction 朝鮮日治時期
# prediction 藝聲
# prediction 馬[UNK]
# prediction 總兵官
# prediction 《金驢記》
# prediction 哈大客運專線
# prediction 漢風魏韻
# prediction 自然科學研究
# prediction 反文化運動
# prediction 英國
# prediction 唐文宗
# prediction 轟炸機
# prediction 都卜勒效應
# prediction 義大利
# prediction 中世紀
# prediction 聽放線
# prediction 尹
# prediction 18個
# prediction 至元三十年
# prediction 保守派
# prediction 南海
# prediction 陶瓷
# prediction 1980年代
# prediction 法國
# prediction 西佛羅里達
# prediction 1997年
# prediction 隋代運河舊道
# prediction 9年
# prediction ucla
# prediction 1959年
# prediction 101公里
# prediction 國務院常務會議
# prediction 20倍
# prediction 喬治亞共和國
# prediction 1943年
# prediction 全面性戰爭
# prediction 橫位
# prediction 聯邦憲法未指明屬聯邦政府之權力
# prediction 韓國
# prediction 氯仿
# prediction 土耳其人
# prediction 瀕危物種
# prediction 越戰
# prediction 公民權
# prediction 可再生能源發電
# prediction 極端大陸性氣候
# prediction 金華
# prediction 1929年
# prediction 法國電信
# prediction 笛卡爾
# prediction 1897年
# prediction 中山盛產海鹽
# prediction 華北財經辦事處
# prediction 市場分析
# prediction 上海南站
# prediction 2006年
# prediction 家庭喜劇片
# prediction 反對同性婚姻者
# prediction 男子
# prediction 反對建文帝削藩
# prediction 建築學院
# prediction 朱熹
# prediction 自由民主黨
# prediction 傳播色情
# prediction 植物
# prediction 哈齊客運專線
# prediction 第五區
# prediction 梵蒂岡的武裝軍事力量
# prediction 1983年
# prediction 漢武帝
# prediction 關東地方
# prediction 撤軍
# prediction 巴黎聖母院
# prediction 西方文明開始衝擊朝鮮半島
# prediction 東晉常[UNK]
# prediction 1936年
# prediction 預言
# prediction 非商用
# prediction 五桂山
# prediction 枇杷
# prediction 嘉義市
# prediction 一級產業
# prediction 29個
# prediction 民國31年
# prediction 10月23日
# prediction 《希臘、羅馬名人傳》
# prediction 固有詞
# prediction 第二次世界大戰
# prediction 5000噸級
# prediction 薩羅尼加
# prediction 2015年年底
# prediction 古漢語
# prediction 22年
# prediction 阿列克修斯·杜卡斯
# prediction 瓦倫丁尼安三世
# prediction 喜馬拉雅山脈
# prediction 1937年
# prediction 1964年
# prediction 19世紀
# prediction 油氣開發
# prediction 100公里的高度
# prediction 明孝宗
# prediction 阿圖什
# prediction 第八區
# prediction 1925年
# prediction 照射紫外線
# prediction 九一八事變
# prediction 春秋
# prediction 對大自然的崇拜
# prediction 馬祖
# prediction 1899年
# prediction 牟定縣
# prediction 尼布楚條約
# prediction 中央窩
# prediction 利奧三世
# prediction 殖民主義
# prediction 奧德
# prediction 30米
# prediction 2,000公厘
# prediction 自主性
# prediction 溫和派政策
# prediction 赤城鎮
# prediction 纖維心包
# prediction 羅非魚
# prediction 潘普洛納
# prediction 法國阿爾卑斯山礦泉
# prediction 1848年
# prediction 《臺灣府志》
# prediction 杜林
# prediction 第八位
# prediction 雙方在一盤中戰至6比6
# prediction 民國39年
# prediction 北京郵票廠
# prediction 傑伊條約
# prediction 超新星
# prediction 全斗煥
# prediction 2007年
# prediction dr.rufusb.vonkleinsmid
# prediction 索馬利亞政府司法系統
# prediction 420年
# prediction 軍隊編制問題
# prediction 丁日昌
# prediction 韓國
# prediction 1980年代
# prediction 何韻詩
# prediction 1925年
# prediction 印度河流域文明
# prediction 2009年
# prediction 湘西土家族苗族自治州
# prediction 許貢
# prediction 少
# prediction 北魏孝文帝
# prediction 李定國
# prediction 22條
# prediction 公共健康與醫學領域
# prediction 《新基本法令》
# prediction 1962年
# prediction 洪武三十一年
# prediction 共產黨
# prediction 奧匈帝國
# prediction 突厥汗國
# prediction 白矮星
# prediction 咖啡因
# prediction 司馬元顯
# prediction 階梯狀
# prediction 漳州人
# prediction 6個小時
# prediction 1651年
# prediction 憲法
# prediction 呂驥
# prediction 90年代
# prediction 金日成
# prediction 第5
# prediction 愛德華·懷克-史密斯
# prediction 西班牙瓦倫西亞
# prediction 1787年
# prediction 王保保
# prediction 復仇
# prediction 1898年
# prediction 守舊派
# prediction 古巴
# prediction 端敬王后
# prediction 中生代
# prediction 約瑟夫史達林
# prediction 中華人民共和國
# prediction 維持議會的高度集權
# prediction 抑制人口增加而實行的計劃生育
# prediction 蘇聯遠東軍
# prediction 全國人民代表大會
# prediction 福建社團聯會
# prediction 水委一
# prediction 用來嚇阻鳥群
# prediction 推行反共政策
# prediction 5～8％
# prediction 日本
# prediction 分子雲內部
# prediction 鮮卑部落
# prediction 法蘭西人
# prediction 1918年
# prediction 1939年
# prediction 東三省巡閱使衛隊旅旅長
# prediction 巴黎條約
# prediction 1970年
# prediction 威斯康辛大學麥迪遜分校
# prediction 乾燥
# prediction 麻赫穆德·喀什噶里
# prediction 帕拉多霍祭壇組雕
# prediction 兩個分組賽階段的資格賽賽制
# prediction 周貽淦
# prediction 民國16年
# prediction 13世紀
# prediction 三監之亂
# prediction 周恩來
# prediction 馬略
# prediction 至元十三年
# prediction 磷化氫
# prediction 1970年代
# prediction 圖西族
# prediction 聖餐持紀念說
# prediction 非暴力實踐空腹死刑
# prediction 三國志
# prediction 地心說
# prediction 長沙太守
# prediction 熱遲滯現象
# prediction 1978年
# prediction 上海
# prediction 比利時
# prediction 濃硫酸
# prediction 認為每一種事物都是由原子所組成的
# prediction 「兄弟國的盟約」
# prediction 2011年
# prediction 硫
# prediction 1979年
# prediction 義大利
# prediction 農業
# prediction 卡拉恰伊湖
# prediction 宋理宗
# prediction 阿蘭王國
# prediction 臺北
# prediction 共和黨
# prediction 日本
# prediction 二戰的爆發
# prediction 1976年
# prediction 上海
# prediction 1949年
# prediction 麻省理工學院
# prediction 階級社會
# prediction 1920年代
# prediction 部隊局
# prediction 1449年
# prediction 1986年
# prediction 隆武帝
# prediction 第一次世界大戰
# prediction 孫叔敖
# prediction 《斯納格的奇妙大陸》
# prediction 雙汗制
# prediction 78歲
# prediction 半軍事管制
# prediction 中華全國體育總會
# prediction 恆星自轉
# prediction 人文關懷
# prediction 1972年
# prediction 墮胎法
# prediction 軍閥混戰
# prediction 中國共產黨解放軍
# prediction 扶餘
# prediction 人民頻繁的遷移
# prediction 四世紀
# prediction 對境外落地的信號實施地面頻道干擾
# prediction 政府的長期不穩定
# prediction 匈牙利
# prediction 1979年
# prediction 高句麗
# prediction 蘇區
# prediction 西區門戶計畫
# prediction 太陽
# prediction 1940年
# prediction 妖怪學
# prediction 1987年
# prediction 有人收養照顧
# prediction 汾河
# prediction 關漢卿
# prediction 湯玉麟
# prediction 陳平順
# prediction 主序帶
# prediction 羅貝爾
# prediction 整個站體都位於天橋上
# prediction 1955年
# prediction 蒙古人民共和國加入聯合國
# prediction 金石並用時代
# prediction 天皇
# prediction 朝鮮白頭山
# prediction 德國人
# prediction 2013年
# prediction 羅馬帝國
# prediction 分子雲
# prediction 外邦人
# prediction 生存競爭中自由淘汰的結果
# prediction 1987年
# prediction 韓國
# prediction 王孝通
# prediction 哈比亞利馬納
# prediction 法文老師
# prediction 阿瓦魯阿
# prediction 馬麒
# prediction 基因特質
# prediction 印地語
# prediction 焦爾達諾·布魯諾
# prediction 乾隆
# prediction 長高約八公分
# prediction 過渡期
# prediction 民國43年
# prediction 地質類學科專業
# prediction 北京天文臺任研究員
# prediction 瓜拿納因子
# prediction 狄奧多西
# prediction 2000年6月
# prediction 韓國高鐵
# prediction 美西戰爭
# prediction 尊漢思想
# prediction 蒂羅爾
# prediction 希拉的女祭司
# prediction 供應服務過多
# prediction 1910年革命
# prediction 洛邑
# prediction 遊牧民族，逐水草而居
# prediction 杜慧度
# prediction 憲政改革
# prediction 英國
# prediction 斯塔福德郡
# prediction 元熙元年
# prediction 劉少奇
# prediction 1922年
# prediction 初中
# prediction 作為天候變異、災禍預知、社會秩序以及超自然現象的合理化解釋
# prediction 東德使館
# prediction 冷戰時期
# prediction 1961年
# prediction 恆星殘骸
# prediction 顯微注射
# prediction 馬可波羅
# prediction 新羅馬
# prediction 上海鐵路局
# prediction 離岸人民幣
# prediction 確保比利時的中立
# prediction 路德的德語聖經
# prediction 生育自主權
# prediction 燃燒燃料的速度快
# prediction 加拿大第三師
# prediction 120天
# prediction 1950年代
# prediction 文藝復興
# prediction 行為不檢點
# prediction 文藝復興式
# prediction 淮安
# prediction 1590年
# prediction 1989年
# prediction 埃姆斯蘭
# prediction 柏林國際廣播電台
# prediction 本超星系團
# prediction 春秋時期
# prediction 使郵驛通信十分有效地發揮效能
# prediction 媒體維基
# prediction 人文
# prediction 1949年
# prediction 67個
# prediction 10月1日
# prediction 1884年
# prediction 俄國
# prediction 大慶油田
# prediction 私立大學
# prediction 三座
# prediction 為早期韓國華僑的聚集所在
# prediction 李雄
# prediction 許榮茂
# prediction 汪大淵
# prediction 英語
# prediction [UNK]稻
# prediction 宋真宗
# prediction 120%
# prediction 美國聯邦調查局
# prediction 9月
# prediction 其副汗或小汗多帶有伊利的的稱號
# prediction 唐德剛
# prediction 路易十四
# prediction 韓國
# prediction 0.07個太陽質量
# prediction 閩南人
# prediction 民國28年
# prediction 李煥之
# prediction 公共汽車
# prediction 核質
# prediction 鴨巴甸
# prediction 東正教
# prediction 八角鼓
# prediction
# prediction 文化大革命
# prediction 1642年
# prediction 徐載弼
# prediction 貴由
# prediction 匈奴人
# prediction 芝加哥大學
# prediction 造船業
# prediction 對流線型設計的要求
# prediction 紐格威森林
# prediction 2012年
# prediction 拿破崙
# prediction 戴克里先
# prediction 166年
# prediction 太極兩儀
# prediction 市場經濟
# prediction 1961年
# prediction 亞歷山大六世
# prediction 1871年
# prediction 四五運動
# prediction 70年代
# prediction 1958年底
# prediction 一些國家採胡漢分治的制度
# prediction 涵元門
# prediction 杜甫
# prediction 漢文
# prediction 12次
# prediction 科學社會學
# prediction 約1138公頃
# prediction 《中華人民共和國村民委員會組織法》
# prediction 荷蘭
# prediction 聯合國
# prediction 成功奪得影帝最佳男主角
# prediction 內陸山區
# prediction 當地印度組織
# prediction 白[UNK]紀滅絕事件
# prediction 模特
# prediction 上帝創造萬物
# prediction 1258年
# prediction 元朝
# prediction 1929年
# prediction 1972年
# prediction 新式鐵製蒸汽船
# prediction 文森特
# prediction 反環境保護主義
# prediction 詹姆士·麥迪遜
# prediction 1946年
# prediction 蘇聯紅軍
# prediction 外匯帳戶
# prediction 1991年
# prediction 公共事務學院中和哈佛大學甘迺迪政府學院
# prediction 太陽
# prediction 修道主義
# prediction 1999年
# prediction 亞歷山大漢密爾頓
# prediction 中國
# prediction 1960年
# prediction 國務委員會委員長
# prediction 紐約尼克
# prediction 蓋戳形式
# prediction 東校區
# prediction 100萬到1兆倍
# prediction 第三代
# prediction 匈奴
# prediction 9月6日
# prediction 貴族等級制度
# prediction 工程化核酸酶
# prediction 伊薩克二世
# prediction 統帥
# prediction 外部刺激
# prediction 蔣中正
# prediction 臺灣本身財政負擔
# prediction 武漢行營副主任
# prediction 躲避戰亂
# prediction 朝鮮半島
# prediction 35.3億韓圓
# prediction 狄拉克
# prediction 落實外交政策
# prediction 1823年
# prediction 輔音
# prediction 三人團
# prediction 舊石器時代
# prediction 166年
# prediction 荀子
# prediction 集團軍
# prediction 半日制學堂
# prediction 尷尬事件
# prediction 愷撒
# prediction 韓語
# prediction 倫敦霍洛威
# prediction 佛教
# prediction 烏爾蘇拉
# prediction 1964年
# prediction 印度洋
# prediction 維持現狀
# prediction 挪威
# prediction 南北戰爭
# prediction
# prediction 南華縣
# prediction 英國
# prediction 李紳
# prediction 在道路無需軌道行駛上的電車
# prediction 帝位世襲
# prediction 1060公釐
# prediction 1941年
# prediction 唐史學家
# prediction 荊州劉表
# prediction 慶元
# prediction 軍事委員會北平分會副委員長
# prediction 英美法系
# prediction 石油危機
# prediction 唐朝
# prediction 奧斯陸峽灣
# prediction 1920年
# prediction 硫代硫酸氨
# prediction 《金雲翹傳》
# prediction 89萬人
# prediction 1912年
# prediction 1627年
# prediction 區域性污染
# prediction 阿內加達島
# prediction 唐生智
# prediction 夏季
# prediction 板橋地方法院
# prediction 次級領導人
# prediction 6世紀
# prediction 24所
# prediction 甘肅省
# prediction 領先盤
# prediction 1所
# prediction 義大利耶穌會
# prediction 一個
# prediction 破四舊
# prediction 三次
# prediction 獲得大寧地區的駐牧權
# prediction 俗語
# prediction 郭松齡
# prediction 爆炸性
# prediction 雲南省第二殖邊督辦公署
# prediction 明朝
# prediction 1968年
# prediction 反潛
# prediction 1932年
# prediction 吉田定房
# prediction 世稱恭順
# prediction 氣候分類系統
# prediction 二戰
# prediction 財產資格限制
# prediction 吳國
# prediction 汗位取得不合法
# prediction 奧東·德拉羅什
# prediction 海旁東
# prediction 帕塔普斯科河
# prediction 1945年
# prediction 義熙十一年
# prediction 戰時研發商
# prediction 芬蘭的赫爾辛基
# prediction 《男人四十》
# prediction 羅馬帝國
# prediction 1846年
# prediction 辛亥革命
# prediction 史夔
# prediction 「合會朱陸」
# prediction 阿希佩戈拉公國
# prediction 阿拉伯半島
# prediction 亞歷山大一世
# prediction 加州尤巴城
# prediction 君主
# prediction 天下人
# prediction 日本
# prediction 尼古拉斯·尼葛洛龐帝
# prediction 朱序
# prediction 石油危機
# prediction 教育產業化
# prediction 1992年
# prediction 康拉德·阿登納
# prediction 山東半島
# prediction 聖奧古斯丁
# prediction 大約公元185年
# prediction 弱勢群體
# prediction 大正天皇
# prediction 西區圖書館
# prediction 北齊
# prediction 足利義輝
# prediction 內戰
# prediction 中華人民共和國衛生部
# prediction 人人平等
# prediction 斯拉夫人
# prediction 第4
# prediction 聯邦制
# prediction 1807年
# prediction 波多黎各
# prediction 瑞士蘇黎世州
# prediction 七月初四
# prediction 德國
# prediction 76間
# prediction 民國19年
# prediction 50元
# prediction 國民黨分裂出來的「新臺灣人服務團隊」分散了泛國民黨支持者的票源
# prediction 9局
# prediction 免耕拋秧法
# prediction 七個
# prediction 周恩來
# prediction 卡加梅
# prediction 93位
# prediction 悉曇體
# prediction 5月17日
# prediction 財務分析工具
# prediction
# prediction 海軍少尉
# prediction 德川家康
# prediction 空射火箭
# prediction 1836年
# prediction 敘利亞
# prediction 香港
# prediction 德里克·羅勃茲
# prediction 伊斯蘭教
# prediction 以和平方式抱住大樹來阻止森林砍伐
# prediction 哥廷根亨德爾國際音樂節
# prediction 滬昆高速公路
# prediction 夜裡10點
# prediction 法國
# prediction 歐德謨
# prediction 道本頓
# prediction 通州張家灣
# prediction 青春勵志片
# prediction 《血盟救國軍軍歌》
# prediction 廣州
# prediction 聽診器
# prediction 法蘭西第二帝國覆亡，取而代之的是法蘭西第三共和國
# prediction 唯泰主義
# prediction 1993年
# prediction 《海峽兩岸服務貿易協議》
# prediction 攻擊明朝的軍事重鎮大同
# prediction 自由主義
# prediction 1874年
# prediction 每一聲波周期因而都可以有一定數量的纖維同步發放
# prediction 卡斯特拉
# prediction 李克強
# prediction 河東道
# prediction 挑戰
# prediction 希波丹姆
# prediction 熱帶稀樹草原
# prediction 法國
# prediction 抗日民族統一戰線的具體組織形式
# prediction 63個
# prediction 46公里
# prediction 十六世紀
# prediction 帕多瓦大學
# prediction 八千多年
# prediction 吉隆坡
# prediction 1889年
# prediction 不承擔國家賦役
# prediction 發展局
# prediction 該處是最溫暖的
# prediction 北京電視台
# prediction 舟山撤退
# prediction 十月革命
# prediction 德國
# prediction 美國大學協會
# prediction 公共教育經費
# prediction 日本關東軍
# prediction 開京
# prediction 美國大蕭條時期
# prediction 平抑物價
# prediction 拉丁人僑民
# prediction 明文
# prediction 蔣介石
# prediction 全印穆斯林聯盟
# prediction 受通古斯人壓力
# prediction 喇嘛教
# prediction 鎌倉時代
# prediction 太陽圈
# prediction 建設中國特色社會主義
# prediction 劉裕
# prediction 東正教
# prediction 法蘭西王國教會
# prediction 佛教
# prediction 三代
# prediction 東正教
# prediction 臺北市
# prediction 鄧小平
# prediction 南斯拉夫
# prediction 武陵
# prediction 殺蟲
# prediction 法國大革命
# prediction 自由韓國黨
# prediction 否決權
# prediction 二十世紀
# prediction 積極進攻
# prediction 加拿大
# prediction 1926年
# prediction 義大利汽車之都
# prediction 火箭發動機
# prediction 機械門控通道
# prediction 在軌道上驅動列車
# prediction 聖喬治拉丁文學校
# prediction 23年
# prediction 1948年12月1日
# prediction 武宗系
# prediction 私兵制度
# prediction 魏博拉盧比民達行業工會
# prediction 文章奧府
# prediction 繁衍後代所需基因物質產生的方式
# prediction 非洲
# prediction 瓊州海峽
# prediction 安德魯約翰遜
# prediction 普林斯頓大學
# prediction 83年
# prediction 釣魚台國賓館
# prediction 伊達政宗
# prediction 量子物理學的進展
# prediction 民國5年
# prediction 金融廳
# prediction 潘章
# prediction 班傑明·富蘭克林
# prediction 高雄
# prediction 第二代
# prediction 日美神奈川條約
# prediction 北京
# prediction
# prediction 哈利里德
# prediction 低電磁訊號反射強度
# prediction 柏拉圖
# prediction 波蘭
# prediction 臺灣舉行總統大選
# prediction 英祖四年
# prediction 改良式腳踏車
# prediction 那一夜，我們說相聲
# prediction 二人
# prediction 1830年
# prediction 全球資訊網
# prediction 八月
# prediction 行為主義
# prediction 廣州話
# prediction 傑瑞·威斯特
# prediction 粳稻
# prediction 挪威
# prediction 1800
# prediction 中國郵政集團公司
# prediction 清朝沒有誠意
# prediction 我們是一個民族！
# prediction 亞裔安納托利亞人
# prediction 福島縣會津地區
# prediction 1913年
# prediction 土地銷售
# prediction 阿拉曼人
# prediction 史蒂夫·鮑爾默
# prediction 天花病
# prediction 牡丹峰樂團
# prediction 印度
# prediction 3
# prediction 周敦頤
# prediction 下薩克森邦
# prediction 朱利烏斯·凱撒
# prediction 豫
# prediction 1919年4月13日
# prediction 1133515人
# prediction 喃字
# prediction 排灣族
# prediction 牛津大學
# prediction 普選制度
# prediction 高宗
# prediction 2015年
# prediction 1969年
# prediction 自由民主黨
# prediction 三合院的前院
# prediction 九年一貫之綱要文句太含糊
# prediction 488年
# prediction 病態賭徒
# prediction 全國人民代表大會
# prediction 外太空
# prediction 黃中理
# prediction 扶助弱小民族使之自治自決
# prediction 西班牙
# prediction 1905年
# prediction 美國
# prediction 鐵
# prediction 拿破崙
# prediction 廣東省
# prediction 聖母大學
# prediction 羅馬法
# prediction 應用心理學家
# prediction 希臘
# prediction 拉丁字母
# prediction 《中俄密約》
# prediction 詹姆斯·史都華
# prediction 雙重國籍
# prediction 24英吋克拉克望遠鏡
# prediction 生物質
# prediction 秘書處
# prediction 就地掩埋稻草
# prediction 66種
# prediction 數位訊號
# prediction 回族
# prediction 視錐細胞
# prediction 人口眾多
# prediction 威廉二世
# prediction 遵義會議
# prediction 《我於青春無悔》
# prediction 君士坦丁大帝
# prediction 美國國家草地網球聯盟
# prediction 8月26日
# prediction 希臘字母
# prediction 鐵鉉
# prediction 外交手段
# prediction 1887年
# prediction 2008年
# prediction 阿基米德
# prediction 2010年
# prediction 1918年
# prediction 對刺激的回應
# prediction 魯宗之
# prediction 荷蘭東印度公司對日本幕府散播西班牙企圖顛覆德川幕府陰謀
# prediction 朝鮮王朝
# prediction 2012年
# prediction 生物動力學
# prediction 印度洋暖濕氣流
# prediction 太白山脈
# prediction 中國
# prediction 高強度的鋁合金
# prediction 民國十八年
# prediction 濟州島
# prediction 一萬兌一
# prediction 25個
# prediction 東北停戰協定
# prediction 1996年
# prediction 1985年
# prediction 4世紀
# prediction 顯示自己的獨立自主
# prediction 13世紀
# prediction 港鐵九龍灣站
# prediction 1980年代
# prediction 1997年
# prediction 牛津大學
# prediction 折下吉延
# prediction 越南
# prediction 1914年
# prediction 為會議提供傳譯服務
# prediction 2300多種
# prediction 對能源的需求持續增長
# prediction 女性
# prediction 40倍
# prediction 1959年
# prediction 紅
# prediction 1856年
# prediction 忽必烈
# prediction 反革命事件
# prediction 夫人王光美
# prediction 理察·科伯恩·麥克勞林
# prediction 西德
# prediction 1624年
# prediction 15%
# prediction 道格拉斯
# prediction 奈及利亞
# prediction 亞洲
# prediction 2000年
# prediction 重力作用
# prediction 桑
# prediction
# prediction 2013年2月11日
# prediction 1973年
# prediction 爭取民族權利
# prediction 明治大學
# prediction 哲學家
# prediction 10萬人
# prediction 惠宗
# prediction 抗佝[UNK]病維他命
# prediction 馬來-玻里尼西亞語族
# prediction 45%
# prediction 預算限制
# prediction 意識型態
# prediction 蘇美爾人
# prediction 元代
# prediction 43人
# prediction 限制性消化
# prediction 劉氏
# prediction 超級模特兒
# prediction 兩層
# prediction 志費尼
# prediction 中國共產黨
# prediction 《鋼鐵是怎樣煉成的》
# prediction 1994年12月1日
# prediction 最高榮譽大獎
# prediction 錫克教
# prediction 1986年
# prediction 《安邦定國誌》
# prediction 水上人漁民
# prediction 省級公園
# prediction 米高彭博
# prediction 伊斯蘭教
# prediction 徐樹錚
# prediction 明太祖
# prediction 歷史博物館
# prediction 阿內加達島
# prediction 雷達吸波收材料
# prediction 外國不可能介入內戰
# prediction 朝鮮民主主義人民共和國
# prediction 下層階級
# prediction 公共救濟
# prediction 非洲國家
# prediction 大學
# prediction 九龍灣
# prediction 廣州
# prediction 佛教
# prediction 陳朝
# prediction 11,000間
# prediction 有色人種
# prediction 共產國際
# prediction 漢諾威
# prediction 中央電視台高清綜合頻道
# prediction 石亭之戰
# prediction 《蘇蒙修好條約》
# prediction 主體史學
# prediction 球皺褶
# prediction 1662年
# prediction 1884年
# prediction 第二產業
# prediction 俄羅斯
# prediction 伍斯特
# prediction 整個表面積
# prediction 大量的中東歐地區的共產黨喪失了政權
# prediction 張議潮
# prediction 新幾內亞
# prediction 正德十一年
# prediction 瘟疫四竄
# prediction 法國
# prediction 喜馬拉雅山
# prediction 與國大黨的合作要求英國廢止劃分孟加拉
# prediction 沙俄軍隊
# prediction 200萬立方公尺
# prediction 黑龍江
# prediction 1992年
# prediction 北角區，北角
# prediction 新界
# prediction 蔣中正
# prediction 大和國
# prediction 佛教
# prediction 500hz以下的聲音對基底膜的影響
# prediction 無性生殖
# prediction 外星人入侵地球
# prediction 母親病危
# prediction 第十五屆奧運會
# prediction 鬍鬚狀
# prediction 阿拉巴馬州
# prediction 鋤草祭
# prediction f4u
# prediction 600年
# prediction 迎接2010年上海世界博覽會的召開
# prediction 1980年
# prediction 1958年
# prediction 俄羅斯聯邦軍隊
# prediction 南方墨點法
# prediction 路易斯一世
# prediction 《時代》
# prediction 極權主義
# prediction 《布列斯特-立陶夫斯克條約》
# prediction 路易·勒沃
# prediction 布列塔尼半島美國石油公司
# prediction 後燃器
# prediction 恩域塔球場
# prediction 東吳
# prediction 海煤
# prediction 自體授粉
# prediction 1929年
# prediction 想取快錢
# prediction 徐家匯
# prediction 比爾蓋茲
# prediction 忽必烈
# prediction 華人
# prediction 南斯拉夫內戰
# prediction 《塘沽協定》
# prediction 烏蘭烏德
# prediction 1897年
# prediction 巴拉克·歐巴馬
# prediction 2008年1月27日
# prediction 降低成本
# prediction 將原來關係不大的環境及運輸合於一局
# prediction 杭州[UNK]橋機場
# prediction 哥德人
# prediction 「結束戰爭」
# prediction 管理所屬行政區域的地方官員
# prediction 興王
# prediction 衛奕信
# prediction 非歐幾里得幾何
# prediction 2009年
# prediction 全國重點文物保護單位
# prediction 忽必烈
# prediction 茶峒鎮
# prediction 稀薄的埃歐大氣
# prediction 惠金斯原理
# prediction 黑龍江
# prediction 波士頓理工
# prediction 兩年
# prediction 2010年
# prediction 便於管理漢地
# prediction 喬托號
# prediction 在中國是國家絕密，確切的數字無以得知
# prediction 烏里雅蘇臺將軍
# prediction 聖西門主義
# prediction 日治時期
# prediction 蔡[UNK]
# prediction 中國
# prediction 《刑部大理寺狀》
# prediction 澳大利亞新南威爾斯州
# prediction 恆星相對於太陽運動
# prediction 聖方濟·沙勿略
# prediction 羅馬共和國時期
# prediction 外觀
# prediction 韓國
# prediction 藍屋
# prediction 薩伊
# prediction 85天
# prediction 五個
# prediction 張三祿
# prediction 15世紀
# prediction 文藝喜劇片
# prediction 劉琮
# prediction 高血壓
# prediction 北燕
# prediction 《中華人民共和國全民所有制工業企業法》
# prediction
# prediction 都市再生
# prediction 環境保護主義
# prediction 773年
# prediction 懷柔區
# prediction 七間
# prediction 民間反應不佳
# prediction 光緒十年
# prediction 1970年代
# prediction 希臘語
# prediction 西班牙
# prediction 神經源性
# prediction 加拿大
# prediction 七個
# prediction 安定
# prediction 德國
# prediction 乾旱
# prediction 《內戰記》
# prediction 台北
# prediction 甲午戰爭
# prediction 政府採取反共措施
# prediction 1910年
# prediction 拉丁字母
# prediction 1935年
# prediction 四角號碼檢字法
# prediction 8.6%
# prediction 浙江海商
# prediction 巴西
# prediction 歐洲聯盟委員會
# prediction 增加西側的空曠程度
# prediction 德國
# prediction 蘇聯
# prediction 七年戰爭
# prediction 100米以上
# prediction 咖啡因中毒
# prediction 國民政府
# prediction 漢江
# prediction 青光眼
# prediction 狄托主義
# prediction 學權部
# prediction 1984年
# prediction 射擊斷續器
# prediction 5位
# prediction 芽孢炭疽桿菌
# prediction 1945年
# prediction 北宋
# prediction 米高梅
# prediction 1988年
# prediction 「記錄」號
# prediction 英國
# prediction 耶穌會
# prediction 一戰前夕
# prediction 鐵鉉
# prediction 張伯倫
# prediction 《義勇軍進行曲》
# prediction 棉花
# prediction 卡洛·埃馬努埃萊一世
# prediction 賀知章
# prediction 犯人流放之地
# prediction 漢人不斷侵佔平埔族土地
# prediction 主序前星
# prediction 貝加爾湖
# prediction 厄德
# prediction 羅馬共和國中後期
# prediction 當時儒教興盛
# prediction 危坐二堂，絕無懼色
# prediction 克里斯蒂安尼亞
# prediction 無限制潛艇戰
# prediction 哈大客運專線
# prediction 亞熱帶常綠闊葉林
# prediction 1947年
# prediction 普法戰爭
# prediction 博尼法斯二世
# prediction 約翰·莫根
# prediction 耐腐蝕性
# prediction 1835年
# prediction 咖啡因
# prediction 革命外交
# prediction 1972年
# prediction 保衛大都
# prediction 汪精衛
# prediction 體育部
# prediction 單斜棱晶體
# prediction 直系
# prediction 水牛城勇士
# prediction 孫中山
# prediction 七月十一
# prediction 訪客觀賞區
# prediction 殖民政策
# prediction xx染色體
# prediction 咖啡俱樂部
# prediction 16世紀
# prediction 潮濕的大陸性氣候帶
# prediction 配子
# prediction 猶太人
# prediction 孟郊
# prediction 德克薩斯州石牆郡
# prediction 皖系軍閥
# prediction 清廣東水師提督
# prediction 1965年
# prediction 1967年
# prediction 奧古斯都
# prediction 哲布尊丹巴
# prediction 丁[UNK]
# prediction 負責制訂政策，並由各有關部門負責執行
# prediction 1861年2月9日
# prediction 3月19日
# prediction 漢字
# prediction 安托萬·拉瓦錫
# prediction 伊斯蘭教
# prediction
# prediction 周文公
# prediction 眾議院
# prediction 重要的財源
# prediction 盧安達法郎
# prediction 皖浙贛獨立團
# prediction 德川家康
# prediction 經濟蕭條
# prediction 世族
# prediction 1853年
# prediction 銅鑼灣至太古一帶
# prediction 民國37年
# prediction 1270年
# prediction 動力系統
# prediction 三個
# prediction 香山縣南朗翠亨村
# prediction 清帝國
# prediction 諸葛亮
# prediction 江河級驅逐艦
# prediction 2015年
# prediction 21473平方公里
# prediction 傳教士
# prediction 颶風
# prediction 聯合國世界氣象組織
# prediction 衣服布料
# prediction 海河流域
# prediction 蒙哥
# prediction 700家
# prediction 中國溧陽茶葉節
# prediction 全市綠化比例高
# prediction 收到十二道金牌班師回朝
# prediction 澳大利亞
# prediction 和林哈拉
# prediction 5月20日
# prediction 7980年
# prediction 1962年
# prediction 青島海軍基地
# prediction 姑臧
# prediction 日本各jr鐵路公司的票務櫃臺
# prediction 張作霖
# prediction 波蘭進入戰時狀態，實行軍事管制
# prediction 西方遊客
# prediction 視網膜神經節細胞
# prediction 黎元洪
# prediction 于鳳至
# prediction 中華民國台灣
# prediction 第二次世界大戰
# prediction 1961年
# prediction 白光
# prediction 陳誠
# prediction 1966年
# prediction 奈特·麥克米蘭
# prediction 無佛像時代
# prediction 1977年
# prediction 白色
# prediction 自由聯合關係
# prediction 三次
# prediction 英國
# prediction 孫志剛事件
# prediction 《劃一現行各道地方行政官廳組織令》
# prediction 建築於高山上的城堡
# prediction 1948年
# prediction 蒸汽膨脹
# prediction 隋[UNK]帝
# prediction 石碇區石碇里
# prediction 日本
# prediction 美國心臟學會
# prediction 大英帝國
# prediction 八篇書
# prediction 美軍
# prediction 薩爾
# prediction
# prediction 合作派
# prediction 思覺失調症
# prediction 泰晤士河爆發大惡臭
# prediction 1
# prediction 1990年代
# prediction 阿弗剌昔牙卜
# prediction 24%
# prediction 高麗國
# prediction 後現代主義
# prediction 1828年
# prediction 第三名
# prediction 學生仲裁評議委員會
# prediction 西安招待所
# prediction 1349年
# prediction 湯瑪斯傑佛遜
# prediction 新春期間
# prediction 郵值標籤
# prediction 赫羅尼姆斯·沃爾夫
# prediction 1989年
# prediction 宙斯
# prediction 農耕節
# prediction 俄國革命
# prediction 制衡德軍
# prediction 王猛
# prediction 西洋棋殘局
# prediction 敵我矛盾
# prediction 獨立性
# prediction 西塞羅句法
# prediction 10
# prediction 湖熟
# prediction 英國
# prediction 木星
# prediction 愛滋病毒
# prediction 1993年
# prediction 外蒙古
# prediction 張聞天
# prediction 烏托邦
# prediction 法家
# prediction 五個
# prediction 通古斯地區過於偏遠
# prediction 安大略湖
# prediction 羊肉
# prediction 世宗大王
# prediction 劉駿
# prediction 將部分河水導入恆河運河
# prediction 雙重匯率制度
# prediction 美國
# prediction 史都華
# prediction 意識形態的原因
# prediction 七歲
# prediction 法國
# prediction 1928年
# prediction 5個
# prediction 6500k
# prediction 曼哈頓
# prediction 清咸豐年間
# prediction 君士坦提烏斯
# prediction 外省人
# prediction 關西一帯的日本人由於鄰近朝鮮半島，彌生人
# prediction 甲醇
# prediction 太祖
# prediction 牛隻列印問題
# prediction 英國
# prediction 隱遁鄉里，終生不願意出仕
# prediction 中華人民共和國
# prediction 1590年
# prediction 1941年
# prediction 細胞核
# prediction 在壓力過高的情況下安全閥放氣減壓
# prediction 發生十月革命
# prediction 俄羅斯
# prediction 劉少奇
# prediction 幅員遼闊，選舉人數超過三百萬
# prediction 1943年
# prediction 大多倫多地區
# prediction 文化
# prediction 超過9倍太陽質量的大質量恆星會膨脹
# prediction 赫伯特·喬治·威爾斯
# prediction 純的硫是黃色的晶體
# prediction 「資產負債表」
# prediction 德川家康
# prediction 日本
# prediction 5,000,000倍
# prediction 臺北市仍在
# prediction 韓
# prediction 1789年
# prediction 下薩克森邦邦政府
# prediction 泰勒斯
# prediction 17.5%
# prediction 自萊茵河發動入侵
# prediction 鮑羅廷
# prediction 杜林
# prediction 金合歡
# prediction 13倍
# prediction 黃埔軍校
# prediction 《紅樓夢》
# prediction 一百多年
# prediction 1970年
# prediction 雲南
# prediction 14世紀末
# prediction 電子郵票
# prediction 儒字
# prediction 1204年十字軍洗劫君士坦丁堡
# prediction 尚比亞
# prediction 俄國
# prediction 成熟階段
# prediction 閉門思過，檢查自己是否放棄了那些天賦的心，努力把這些心找回來
# prediction 吠陀梵語
# prediction 1950年代
# prediction 羅伯特·波義耳
# prediction 湯·韋迪加
# prediction 托木斯克州
# prediction 提奧多雷
# prediction 民用航太
# prediction 706萬
# prediction 一夫一妻多妾制
# prediction 伊莉莎白
# prediction 義大利
# prediction 2000年
# prediction 1932年
# prediction 天國的階梯
# prediction 路易-菲利普
# prediction 阿布巴卡爾
# prediction 吳兆南相聲劇藝社
# prediction 《古魯·格蘭特·薩希卜》
# prediction 1865年
# prediction 翟中和
# prediction 1924年
# prediction 德國財政局
# prediction 9%
# prediction 楊宇霆
# prediction 法國
# prediction 詹姆斯·史都華
# prediction 周恩來
# prediction 兵馬繁多，非數省不足安插為由，再拒絕之
# prediction 光化學煙霧
# prediction 藍營
# prediction 國務會議
# prediction 洛厄爾天文台
# prediction 加拿大式雙打
# prediction 三名
# prediction 中日甲午戰爭
# prediction 金門
# prediction 電氣化鐵路
# prediction 《資治通鑑》
# prediction 2006年
# prediction 中華民國實業部
# prediction 1966年
# prediction 多倫多
# prediction 大學生的城市
# prediction 約翰·洛克菲勒
# prediction 1960年代末
# prediction 1815年
# prediction 埃德溫·哈勃
# prediction 胡季[UNK]
# prediction 有絲分裂
# prediction 議會制
# prediction 2005年
# prediction 東西伯利亞喇嘛教則例
# prediction 莫斯科
# prediction 五分之一
# prediction 《英語詞典》
# prediction 魔獸世界
# prediction 克倫威爾路
# prediction 《鳳凰劫》
# prediction 日本
# prediction 它的火山釋放的硫
# prediction 俄羅斯帝國
# prediction 水門事件
# prediction 中山
# prediction 閻錫山
# prediction 1997年
# prediction 托爾金
# prediction 龍興之地
# prediction 開放市場的需要
# prediction 阿伊努人
# prediction 1919年
# prediction 五倍
# prediction 原子能
# prediction 艾森豪
# prediction 3400萬
# prediction 正拍擊球
# prediction 帕西瓦爾·洛厄爾
# prediction 二二八事件
# prediction 紅色
# prediction 澎湖
# prediction 亞硫酸
# prediction 理學
# prediction 1998年
# prediction 民國時期
# prediction 毛澤東
# prediction 1950年
# prediction 高輻射的環境
# prediction 維基百科
# prediction 二氧化碳
# prediction 1939年
# prediction 清朝末年
# prediction 城堡
# prediction 哲學原理研究
# prediction 1997年
# prediction 第六次全國人口普查，全市常住人口
# prediction 北大西洋
# prediction 1455年
# prediction 鄧穎超
# prediction 代表宇宙秩序
# prediction 傳統音樂
# prediction 提防燕王謀反
# prediction 法國
# prediction 保加利亞
# prediction 恢復市場的功能
# prediction 北非的希波大會
# prediction 中華民國政府
# prediction 1834年
# prediction 淋巴液
# prediction 斷罰出征，並全征燒埋銀
# prediction 1901年
# prediction 十八歲
# prediction 近年
# prediction 農歷新年
# prediction 阿布海兒汗時代
# prediction 在緊急的時候以大量的燃料提供非常大的推力
# prediction 1312年
# prediction 1970年
# prediction 30℃
# prediction 以色列
# prediction 無性別的宦官與宮女的結合
# prediction 兩個
# prediction 對日抗戰
# prediction 1989年
# prediction 元武宗
# prediction 天文學家
# prediction 毛澤東
# prediction 中國
# prediction 國際非政府組織
# prediction 2014年12月
# prediction 中部科學園區
# prediction 台北市立體育場
# prediction 曹議金
# prediction 冷戰
# prediction 1893年
# prediction 收容遣送制度
# prediction 中國國民黨
# prediction 《一種美味》
# prediction 狄拉克
# prediction 金黃飽滿
# prediction 移民實邊
# prediction 水軍
# prediction 中國青年黨
# prediction 矽燃燒過程
# prediction 劉少奇
# prediction 瑞士洛桑國際管理學院
# prediction 即捕即解實施前
# prediction 著陸
# prediction 顛覆中共政府
# prediction 丹尼爾奧爾特加
# prediction 幾何學
# prediction 1998年1月1日
# prediction 風之國度
# prediction 蠻族事務局
# prediction 喀爾喀人
# prediction 首席的元老
# prediction 11世紀
# prediction 阿普列尤斯
# prediction 猶太人
# prediction 光度
# prediction 克萊斯勒貸款法案
# prediction 省務會議
# prediction 1610年1月7日
# prediction 荷蘭
# prediction 喬治亞
# prediction 1835年
# prediction 六四天安門事件
# prediction 類比訊號
# prediction 「通俗的
# prediction 每秒30轉
# prediction 哭泣
# prediction 1958年
# prediction 1987年
# prediction 洪堡
# prediction 1847年
# prediction 唐玄宗
# prediction 1968年
# prediction 不動產
# prediction 其英文縮寫首字母為「[UNK]·ㄎㄟ·ㄨㄞ」
# prediction 林肯總統
# prediction 風景怡人
# prediction 元末民變
# prediction 加拿大大草原
# prediction 教育副官
# prediction 1599年
# prediction 3個
# prediction 香港國際機場
# prediction 暴力革命
# prediction 段祺瑞
# prediction 普魯士
# prediction 高句麗
# prediction 西伯利亞鐵路
# prediction 溧陽
# prediction 學會部
# prediction 富蘭克林·德拉諾·羅斯福
# prediction 科什圖尼察
# prediction 1600個
# prediction 婦女投票權
# prediction 500毫升
# prediction 古代
# prediction 民國二年
# prediction 蒙古人
# prediction 正德十三年
# prediction 閏盤
# prediction 愛爾蘭共和國
# prediction eca國際
# prediction 毛澤東
# prediction 蒙哥汗在合州的釣魚城之戰戰死
# prediction 瀧川
# prediction 莫高窟
# prediction 電穿孔細胞
# prediction 建造在中國的第一座主教座堂
# prediction 2次
# prediction 1924年
# prediction 日本
# prediction 稻米
# prediction 宮田製銃所
# prediction 經濟問題
# prediction 1米93
# prediction 鹿兒島
# prediction 外傭
# prediction 縱貫鐵路山線段
# prediction 《1956年清潔空氣法》
# prediction 傑米尼安諾·蒙塔納利
# prediction 大陸新移民
# prediction 亞里斯多德
# prediction 伊斯蘭教法優先地位的憲章，儘管在實踐中教法
# prediction 近海戰鬥
# prediction 菲利浦五世
# prediction 阿爾卑斯山
# prediction 炮兵科教官
# prediction 1984年
# prediction 何鳳山
# prediction 一億光年
# prediction 1995年
# prediction 鯨魚座·優[UNK]
# prediction 日語
# prediction 阿爾法級別
# prediction 20世紀
# prediction 草本
# prediction 涵元殿
# prediction 奧斯卡·赫特維希
# prediction 1971年
# prediction 英國
# prediction 馮國璋
# prediction 增強孩子免疫
# prediction 民國18年
# prediction 年降雨量
# prediction 1913年
# prediction 法國東部
# prediction 灣仔
# prediction 拉丁語
# prediction 南亞
# prediction 婆羅摩笈多
# prediction 貝聿銘
# prediction 世界的中心
# prediction 第53
# prediction 工業革命
# prediction 獻縣張家莊
# prediction 一次世界大戰時期
# prediction 大量安眠藥
# prediction 史坦波中心
# prediction 《科學怪人》
# prediction 詹姆士·波爾克·詹森
# prediction f-16
# prediction 日本
# prediction 《麥健時報告書》
# prediction 江蘇
# prediction 朱齡石
# prediction 中共中央副主席
# prediction 毒氣
# prediction 連接子
# prediction 普洱專區
# prediction 被僱人
# prediction 英國倫敦溫布頓
# prediction 國君身邊的齊泰和黃子澄
# prediction 1529年
# prediction 佐世保重工業
# prediction 申城
# prediction 德川家
# prediction 河川
# prediction 岩石圈
# prediction 香港日治時期
# prediction 聯邦儲備系統
# prediction 1925年
# prediction 由新界鄉村的代表
# prediction 德國
# prediction 亞熱帶
# prediction 1975年
# prediction 日本
# prediction 反共思想
# prediction 首爾話
# prediction 俄羅斯車里雅賓斯克
# prediction 王藍
# prediction 胡錦濤
# prediction 東晉元帝
# prediction 最低層
# prediction 國語
# prediction 絲綢之路
# prediction 5642米
# prediction 殺蟲劑中毒
# prediction 寮國
# prediction 產業工會聯合會
# prediction 通惠河
# prediction 薩繆爾
# prediction 南奧塞提亞自治區
# prediction 浮動匯率制度
# prediction 農業
# prediction 秋天
# prediction 將兩國國界以黑龍江為基本界限劃清
# prediction 「永興」
# prediction 雲南省
# prediction 德國
# prediction 土地改革
# prediction 陽邁一世
# prediction 凱瑟琳·赫本
# prediction
# prediction 聯邦在內戰中取勝
# prediction 玉泉北路
# prediction 1789年
# prediction 280天
# prediction 旅遊業
# prediction 柏拉圖
# prediction 國家地質總局
# prediction 2007年
# prediction 國家歷史文化名城
# prediction 維基媒體基金會
# prediction 一省
# prediction 恆河
# prediction 嫁妝
# prediction 初中
# prediction 最佳演唱團體獎
# prediction 將她視為君主妾室
# prediction 防火能力
# prediction 現代精神醫學
# prediction 機炮
# prediction 寧古塔副都統
# prediction 德國柏林影展
# prediction 接合
# prediction 第四心音
# prediction 李白
# prediction 世襲制度
# prediction 韓國海關
# prediction 英屬印度
# prediction 2009年
# prediction 牛胃氣膨脹
# prediction 沮水
# prediction 吠陀梵語
# prediction 受道家老子思想的用詞影響
# prediction 平面模特兒
# prediction 印第安納大學俱樂部
# prediction 雷達
# prediction 1960年代
# prediction 福爾摩沙高速公路
# prediction 高科技產業
# prediction 東芝
# prediction 新北市
# prediction 川本芳昭
# prediction 伊斯蘭教
# prediction 一年
# prediction 割讓土地
# prediction 八六學潮
# prediction 2002年
# prediction 620年
# prediction 民國2年
# prediction 第一公民
# prediction 現代主義
# prediction 天主教
# prediction 美利堅聯盟國
# prediction 亞歷山大·塞維魯
# prediction 1958年
# prediction 1929年
# prediction 數學科幻
# prediction 房間隔
# prediction 菲律賓
# prediction 湯瑪斯·勃蘭契特·瑞德
# prediction 周恩來
# prediction 超音速
# prediction p-51戰鬥機
# prediction 日本
# prediction 民國37年
# prediction 模擬別人的言行
# prediction 1900年
# prediction 李察·賓特利
# prediction 印尼
# prediction 康熙四十八年
# prediction 荊州
# prediction 摩利爾法學院
# prediction 22個
# prediction 克里米亞戰爭
# prediction 國防部空軍司令部
# prediction 北京
# prediction 1945年
# prediction 倭寇
# prediction 閉關鎖國
# prediction 1972年
# prediction 2013年
# prediction 史達林
# prediction 大連
# prediction 1918年
# prediction 年輕恆星
# prediction 非金屬類材料
# prediction 阿拉貢王國
# prediction 聯合國人權委員會
# prediction 庫里爾台大會
# prediction 氫
# prediction 頭
# prediction 費城學院和研究院
# prediction 二氧化碳
# prediction 穀類作物
# prediction 勒布夫
# prediction xy染色體
# prediction 後代
# prediction 熱帶雨林氣候
# prediction 王白駒
# prediction 劉備
# prediction 第三心音
# prediction 咸康七年
# prediction 鋁合金
# prediction 道格拉斯
# prediction 玉米
# prediction 東羅馬帝國
# prediction 五個
# prediction 民國25年
# prediction 松花江
# prediction 美國
# prediction 宋太祖趙匡胤
# prediction 太陽能電池板
# prediction 2008年
# prediction 南北韓高級別會談機制
# prediction 紅水河
# prediction 新蒙古人種
# prediction 斯芬·佩斯
# prediction 2001年
# prediction 大道東
# prediction 27千兆瓦
# prediction 副熱帶濕潤氣候
# prediction 1200萬名
# prediction 總督
# prediction 2008年
# prediction 29.48萬人
# prediction 1982年
# prediction 林天宏
# prediction 杜篤瑪
# prediction 12個
# prediction 西伯利亞
# prediction 櫻花大道
# prediction 焦爾達諾·布魯諾
# prediction 國際網球協會
# prediction 僑州郡縣
# prediction 一種比較具體的修飾手法
# prediction 官僚主義者階級
# prediction 刺史
# prediction 四個腔隙
# prediction 1180年
# prediction 三歲
# prediction 失眠
# prediction 雷焦卡拉布里亞國家考古博物館
# prediction 阿克爾自治市
# prediction 香港
# prediction 都市計劃
# prediction 西班牙
# prediction 布爾人
# prediction 產婦之前有無生產，以及其姿勢與活動能力
# prediction 校園一卡通
# prediction 第18
# prediction 海澄公
# prediction 氮氣
# prediction 外國人
# prediction 汪兆銘
# prediction 金銀珠寶
# prediction 1919年
# prediction 1939年
# prediction 供寄遞郵件貼用
# prediction 噪聲
# prediction 西塞羅
# prediction 白河
# prediction 蘇聯海軍
# prediction 音樂方面
# prediction 《四十二章經》
# prediction 阿爾杜伊尼卡家族
# prediction 工業發展
# prediction 海因利希・弗格勒
# prediction 第五套
# prediction 景洪市
# prediction 韓國憲法
# prediction 爭取陽光
# prediction 《失落的故事集》
# prediction 1918年
# prediction 200米
# prediction 原始宗教
# prediction 第1區
# prediction 博物學
# prediction 杭州
# prediction 機鼻
# prediction 1999年
# prediction 馮特
# prediction 彰化市民代表會
# prediction 法國大革命
# prediction 明朝
# prediction 2013年
# prediction 朱德
# prediction 陳元帥，神諱陳湯銘
# prediction 漢武帝時期
# prediction 1963年
# prediction 東經116度
# prediction 西排立
# prediction 主語+謂語+賓語
# prediction 主序帶
# prediction 電磁波理論模型
# prediction 臺灣郵票
# prediction 1927年
# prediction 2014年
# prediction 已消失
# prediction 2007年
# prediction 法國
# prediction 向世人展現了腓特烈大帝的軍事天才
# prediction 外匯商店
# prediction 鞏固自己及子孫的統治
# prediction 蒙古語
# prediction 甲醇
# prediction 元太宗
# prediction 15,625億
# prediction 印度教經文
# prediction 1218年
# prediction 918年
# prediction 北非作戰階段
# prediction 依法治國
# prediction 1987年
# prediction dna連線酶
# prediction 金軍
# prediction 半決賽
# prediction 坐在輪椅上擊球
# prediction 球皺褶
# prediction 梁[UNK]
# prediction 40年
# prediction 2901.3平方公里
# prediction 桃園市
# prediction 郭守時
# prediction 高等學校新生入學考試制度
# prediction 大陸冷氣團南下，有強烈東北季風吹襲
# prediction 「學習偉大領袖毛澤東」
# prediction 19世紀
# prediction 檀君古朝鮮
# prediction 清順治帝
# prediction 朝鮮勞動黨中央委員會委員
# prediction 清宣宗時代
# prediction 蒙漢兩元政治
# prediction 黑色貝雷帽
# prediction 三國史記
# prediction 四次
# prediction 林彪
# prediction 技術發明
# prediction 1973年
# prediction 摩門教
# prediction 分裂
# prediction 社會輿論
# prediction 1603年
# prediction 一分
# prediction 火山國家公園
# prediction 2013年
# prediction 客運與貨運市場的逐漸成長
# prediction 新石器時代
# prediction 孔齊
# prediction 李·德富雷斯特
# prediction 1958年
# prediction 世界氣象組織
# prediction 通貨膨脹
# prediction 1820年代
# prediction 規劃環境地政局
# prediction 350kw
# prediction 天主教
# prediction 食品業
# prediction 1958年
# prediction 2010年
# prediction 柏樹
# prediction 7,920公里/小時
# prediction 仙台市
# prediction 史和平
# prediction 蓋銷
# prediction 哈爾濱
# prediction 1967年
# prediction 義和團事變
# prediction 混合苦膽的酒
# prediction 建文二年
# prediction 關島組織法
# prediction 2008年
# prediction 邊防具體業務工作
# prediction 米蘭·內迪奇
# prediction 19世紀晚期
# prediction 商業貿易中徵收的關稅和貿易稅
# prediction 合不勒汗
# prediction 高句麗
# prediction 窩闊台汗國
# prediction 民國14年
# prediction 49.3萬人
# prediction 巴納德
# prediction 量子光學
# prediction 糧食
# prediction 哈德遜河
# prediction 全國地圖正保御國繪圖
# prediction 民國3年
# prediction 投保人
# prediction 主序帶的階段
# prediction 坎貝爾
# prediction 港島區
# prediction 1221年
# prediction 阿得雷德的去世
# prediction 《中華人民共和國憲法》
# prediction 二十歲
# prediction 雙打比賽
# prediction 中村法道
# prediction 高要
# prediction 鐵穆爾
# prediction 391年
# prediction 英國精神醫學期刊
# prediction 1849年
# prediction 1260年
# prediction 13小時
# prediction 氦
# prediction 戰基處營區
# prediction 蒙古貴族
# prediction 巴西爾二世
# prediction 黑死病
# prediction 1948年6月20日
# prediction 卡胡盧伊
# prediction 硫化氫
# prediction 氮化硫
# prediction 三屆
# prediction 1972年
# prediction 都市計劃
# prediction 色指數
# prediction 日本
# prediction 情感支持
# prediction 6位
# prediction 司馬休之
# prediction 煤煙消除會
# prediction 公民化
# prediction 宏碁
# prediction 國民政府時期
# prediction 愛因斯坦
# prediction 傻瓜塔
# prediction 宋忠
# prediction 廣州的粵菜，中山
# prediction 匹茲堡
# prediction 白塞爾
# prediction 格子型系統
# prediction 《動員戡亂時期臨時條款》
# prediction [UNK]靼海峽
# prediction 1989年
# prediction 花垣鎮
# prediction 東部
# prediction 模特
# prediction 7%
# prediction 韓國
# prediction 於紅館舉行演唱會最高場數紀錄
# prediction 與鄧穎超新婚之夜
# prediction 泰國
# prediction 農民階層
# prediction 孔恩
# prediction 索契
# prediction 比利時
# prediction 重慶理工大學
# prediction 支持臺灣獨立
# prediction 足利尊氏
# prediction 托木斯克
# prediction 蘇丹達爾富爾
# prediction 1905年
# prediction 《臺灣自救運動宣言》
# prediction 詳細規劃
# prediction 十億年
# prediction 1486年
# prediction 英國
# prediction 1950年代
# prediction
# prediction 南極條約協商會議
# prediction 布里亞特人
# prediction 建炎二年
# prediction 民國8年
# prediction 1843年
# prediction 279年
# prediction 中國大陸
# prediction 西元前1534年
# prediction 瓦倫本哥國家公園
# prediction 1906年
# prediction 釋迦牟尼
# prediction 1960年代
# prediction 1640年
# prediction 交通不便
# prediction 威尼斯人
# prediction 東涌線
# prediction 梅艷芳是女低音，類似徐小鳳
# prediction 1841年2月10日
# prediction 1997年
# prediction 2005年7月21日
# prediction 宋代
# prediction 國家預防腐敗局
# prediction 風機高度愈高，發電量愈多
# prediction 大學生研究計劃
# prediction 爽文市
# prediction 1994年
# prediction 王亞南
# prediction 茂蘿街
# prediction 八零年代
# prediction 1234年
# prediction 日本
# prediction 瑞派克路
# prediction 白熱電燈泡
# prediction 第三代
# prediction 黨委通過口頭傳達等行政手段
# prediction 康熙三十二年
# prediction 重工業
# prediction 中央印製廠
# prediction 1952年
# prediction 十二月屠殺的事件中，多達15位的政治反對領袖遭到執政政府的暗殺
# prediction 驅逐艦因其具備多功能性
# prediction 十月革命
# prediction 張成澤
# prediction 收藏者
# prediction 2500年
# prediction 1904年
# prediction 臺北市仍在
# prediction 輻射
# prediction 紹興十一年
# prediction 巨石
# prediction 調節氣溫
# prediction 日本青年社
# prediction 廣東籍
# prediction 羅馬帝國
# prediction 自由派
# prediction 1990年代
# prediction 秋明州
# prediction 倫敦煙霧事件
# prediction 加州
# prediction 自由
# prediction 韓國
# prediction 不穩定性
# prediction 常於9－10月回到黑龍江、烏蘇里江等河中產卵
# prediction 亨利克萊
# prediction 歐美國家
# prediction 濟州島
# prediction 赫爾伯特·查普曼
# prediction 噪音過大
# prediction 廿八歲
# prediction 濟南
# prediction 2016年
# prediction 印度國民軍士兵大審判
# prediction 榮休教宗
# prediction 美日
# prediction 2比1
# prediction 參議院
# prediction 1861年
# prediction 1991年
# prediction 臺灣
# prediction 1953年12月
# prediction 白[UNK]紀末滅絕事件
# prediction 2003年3月4日
# prediction 曼莫漢·辛格
# prediction 刺激性
# prediction 七七事變
# prediction 激進黨
# prediction 1895年
# prediction 中華民國99年12月25日
# prediction 萊茵魯爾
# prediction 漢拿山
# prediction 拒絕投降
# prediction 慈禧皇太后
# prediction 1600分
# prediction 馬爾吉特
# prediction 失分
# prediction 第一次鴉片戰爭
# prediction 特殊黨員
# prediction 中國
# prediction 蔡素玉議員
# prediction 加拿大
# prediction 工藝上的難度
# prediction 「鄧小平建設有中國特色社會主義理論」
# prediction 1999年
# prediction 4個
# prediction 溫州
# prediction 下薩克森邦
# prediction 《宅地法》
# prediction 中途公園
# prediction 駐越美軍
# prediction 燈罩
# prediction 高房價
# prediction 1849年
# prediction 2016年9月30日
# prediction 改革法案
# prediction 解放軍
# prediction 1949年
# prediction 伊斯蘭教
# prediction 東勝寺一役
# prediction 6
# prediction 伊斯蘭教
# prediction 暴雪娛樂公司
# prediction 第二次世界大戰
# prediction 歷史學家
# prediction 理論心理學
# prediction 西方墨點法
# prediction 136.03萬人
# prediction 唐朝
# prediction 飛彈
# prediction 伍德羅·威爾遜
# prediction 與空氣隔絕
# prediction 中央軍委
# prediction 溥佳
# prediction 台中軟體園區
# prediction 1803年
# prediction 特瓦族
# prediction 百濟個性溫和的雕塑
# prediction 麻州
# prediction 杜林
# prediction 庫侖阻力
# prediction 沒有完整校舍
# prediction 一邊一國」
# prediction 耶穌會
# prediction 西塞羅
# prediction 英軍司令部
# prediction 土地改革政策
# prediction 土耳其
# prediction 2013年
# prediction 忠孝橋
# prediction 摩根
# prediction 1960年
# prediction 高崗
# prediction 1930年
# prediction 海水淡化
# prediction 大學文憑
# prediction 海蝕洞
# prediction 爭議性
# prediction 1779年
# prediction 印尼
# prediction 人本主義
# prediction 首爾塔洞公園
# prediction 任何涉及中國代表權變更問題的議案都是重要問題案
# prediction 英國
# prediction 電視
# prediction 3%
# prediction 8200年
# prediction 普法戰爭
# prediction 什錦麵
# prediction 供給創造需求
# prediction 中東
# prediction 民國三十八年
# prediction 鄧演達
# prediction 土魯斯的阿爾比派
# prediction 鮭魚
# prediction 中國大陸
# prediction 甘蔗
# prediction 不滿北條氏專制政權
# prediction 第一個用戶嘗試儲存網頁
# prediction 約翰·福特
# prediction 昆明公交公司
# prediction 2010年
# prediction 巴洛克風格
# prediction 動員勘亂時期臨時條款
# prediction 2008年
# prediction 納粹黨
# prediction 清政府
# prediction 拿破崙
# prediction 戰時的盟軍破壞
# prediction 漢魏故城
# prediction 1920年代
# prediction 東北易幟
# prediction 威廉一世
# prediction 人造衛星
# prediction 35號
# prediction 1702年
# prediction 對於渦輪葉片的耗損提高許多
# prediction 新加坡
# prediction 同盟國
# prediction 1944年
# prediction 標準中文
# prediction 布里斯托大學
# prediction 河運
# prediction 伏爾加河
# prediction 國際動物命名委員會
# prediction 黃金自由貿易
# prediction 施耐庵
# prediction 集中式太陽能發電站
# prediction 大韓帝國
# prediction 約克公爵
# prediction 第265任
# prediction 成了第一條公共蒸汽鐵路
# prediction 死亡
# prediction 40人
# prediction 阿拉瓦克印第安人
# prediction 告士打道以北
# prediction jr集團
# prediction 最大飛行速度
# prediction 12個
# prediction 米菓
# prediction 伽利略
# prediction 1875年
# prediction 裏海
# prediction 1863年
# prediction 1828年
# prediction 1597年
# prediction 1829年
# prediction 杜林
# prediction 2008年
# prediction 毛利家
# prediction 侏[UNK]紀
# prediction 張漢娜
# prediction 拿破崙
# prediction 342年
# prediction 「11月祭
# prediction 中華人民共和國
# prediction 愛格思海金斯公司
# prediction 阿拉巴馬州
# prediction 2015年
# prediction 《羅馬十二帝王傳》
# prediction 呂蒙
# prediction 傑斐遜·戴維斯
# prediction 1867年
# prediction 70%
# prediction 狩獵採集社會
# prediction 第三世界國家
# prediction 國民黨
# prediction 入學考試
# prediction 擔心引起教會勢力的強烈反彈
# prediction 大瘟疫
# prediction 鄂圖曼帝國
# prediction 1986年
# prediction 明代
# prediction 1951年4月13日
# prediction 基督教
# prediction 心血管疾病
# prediction 石油天然氣研發中心
# prediction 元朝
# prediction 硫酸
# prediction 義大利戰爭
# prediction 超級基金法
# prediction 中華人民共和國
# prediction 納粹德國
# prediction 募兵制
# prediction 1933年
# prediction 1994年
# prediction 丙子胡亂
# prediction 1606年
# prediction 天主教會
# prediction 有關國軍參與海外派遣活動的法律案
# prediction 大滿貫
# prediction 華沙
# prediction 伯力
# prediction 強硬的外交政策
# prediction 三種不同的輔音長度
# prediction 8世紀
# prediction 約翰二世·科穆寧皇帝
# prediction 凡爾賽宮
# prediction 北海道帝國大學
# prediction 2008年
# prediction 信陽
# prediction 「地區邊界」
# prediction 電腦
# prediction 動物命名法
# prediction 2016年
# prediction 1789年
# prediction
# prediction 國際生物科學聯合會
# prediction 屬下被朝廷處死
# prediction 金靴獎
# prediction 齊格蒙特三世
# prediction 天文學
# ...
# prediction 沖積平原
# prediction 張之洞
# prediction 1993年
# prediction 李達
# prediction 法國
# prediction 1993年
# prediction 威廉吉爾伯特
# prediction 吉爾古特
# prediction 班傑明富蘭克林
# prediction 富蘭克林
# prediction 琥珀摩擦實驗
# prediction 熱能
# prediction 變壓器
# prediction 法拉第定律
# prediction 纖維性抽搐
# prediction 最佳作品獎
# prediction 之初
# prediction 五部
# prediction 美國電影藝術與科學學院
# prediction 香川普勞圖斯
# prediction 更具成熟追求形式的完美
# prediction 奧古斯都
# prediction 20世紀
# prediction 5000倍
# prediction 距離比較遠
# prediction 三天半
# prediction 公元前3500年
# prediction 幼發拉底河
# prediction 尼羅河
# prediction 恆河
# prediction 美國電影藝術與科學學院
# prediction 奧斯卡金像獎
# prediction 杜比劇院
# prediction 西德尼斯科爾斯基
# prediction 洛杉磯地區
# prediction 學院邀請
# prediction 1939年
# prediction 盛業大廈大學
# prediction 廈門大學
# prediction 教師教學質量不好
# prediction 戊戌變法
# prediction 梁啓超
# prediction 伊藤博文
# prediction 王俊凱
# prediction 蘇聯
# prediction 外交的騙局
# prediction 外國公使
# prediction 義和拳
# prediction 歐美日列強
# prediction 2007年
# prediction 21196.18公里
# prediction 春秋戰國時代
# prediction 漢長城
# prediction 蒙古
# prediction 北齊
# prediction 朝鮮平壤
# prediction 契丹
# prediction 明朝
# prediction 點燃煙火
# prediction 長城
# prediction 中英煙臺條約
# prediction 馬關條約
# prediction 重慶
# prediction 重慶
# prediction 嘉陵道
# prediction 日本
# prediction 重慶
# prediction 火災演習
# prediction 重慶
# prediction 重慶
# prediction 兵工廠
# prediction 沙坪壩公園
# prediction 浦東濱海
# prediction 重慶
# prediction 藥用植物
# prediction 第七
# prediction 電子工業
# prediction 重慶
# prediction 馬關條約
# prediction 損壞莊稼
# prediction 土製裝甲
# prediction 高爆反坦克彈
# prediction 整合型間隙是裝甲
# prediction 臺北國際金融中心
# prediction 陳水扁
# prediction 2003年
# prediction 巡撫
# prediction 中國共產黨
# prediction 西班牙
# prediction 1895年
# prediction 馬州
# prediction 反對同性婚姻
# prediction 摩梭人
# prediction 1995年
# prediction 單身收養制度
# prediction 1600萬
# prediction 社會壓力
# prediction 婚禮產業
# prediction 荷蘭
# prediction 德國
# prediction 五個
# prediction 1884年
# prediction 德國
# prediction 1939年
# prediction 1929年
# prediction 賓夕法尼亞州
# prediction 太空遊客
# prediction 60歲
# prediction 二國將軍
# prediction 英國
# prediction 1989年
# prediction 波蘭
# prediction 綠島
# prediction 機車
# prediction 兩個
# prediction 大學畢業生
# prediction 米爾頓
# prediction 1903年
# prediction 大般若經
# prediction 玄奘
# prediction 宋朝
# prediction 東吳大學
# prediction 1999年
# prediction 可以互相溝通
# prediction 閩南語
# prediction 1945年
# prediction 1968年
# prediction 1942年
# prediction 1944年
# prediction 75歲
# prediction 美國電影學會
# prediction 1985年
# prediction 1991年
# prediction 1948年
# prediction 大白兔
# prediction 優秀西部片演員
# prediction 1947年
# prediction 成年人最高榮譽
# prediction 1945年
# prediction 2008年
# prediction 美國空軍
# prediction 史都華
# prediction 1951年
# prediction 比佛利山莊
# prediction 瓊克勞馥春
# prediction 政治
# prediction 1940年
# prediction 本
# prediction 豐臣秀吉
# prediction 1598年
# prediction 岩石圈
# prediction 大量放射性元素衰變加熱
# prediction 太平洋
# prediction 一個月
# prediction 動態測量隨訪
# prediction 腎病
# prediction 商品的生產地
# prediction 美國
# prediction 日本
# prediction 1899年
# prediction 2008年
# prediction 1789年
# prediction 德川幕府
# prediction 1868年
# prediction 1899年
# prediction 聯合國
# prediction 釣魚臺
# prediction 爬行動物
# prediction 山羊
# prediction 釣魚臺主權的爭議
# prediction 15世紀
# prediction 1952年
# prediction 1940年
# prediction 美軍戰機
# prediction 航路標誌法
# prediction 1月14日
# prediction 1857年
# prediction 馬賴
# prediction 葛羅男爵
# prediction 1858年
# prediction 6月13日
# prediction 2011年
# prediction 美國地質調查局
# prediction 東芝
# prediction 會計造假案件，主要爲來自晶片及半導體部門的虛假營銷
# prediction 1875年
# prediction 2006年
# prediction 第二次世界大戰
# prediction 公元372年
# prediction 北魏藝術風格
# prediction 印度佛教文化
# prediction 蘇門答臘島
# prediction 非常注重傳統
# prediction 往往以裝飾爲主
# prediction 12世紀
# prediction 水墨畫
# prediction 漢明帝
# prediction 米揚大佛
# prediction 南北朝時期
# prediction 北魏風格
# prediction 唐代
# prediction 長安
# prediction 莫高窟
# prediction 約翰赫歇爾
# prediction 1826年
# prediction 君主制
# prediction 匈牙利
# prediction 激進黨
# prediction 如若效忠國王，南斯拉夫會變成君主制國家
# prediction 1921年
# prediction 拉丁文
# prediction 倭寇
# prediction 南宋
# prediction 清同治年間
# prediction 愛情萬歲
# prediction 候鳥
# prediction 2001年
# prediction 地中海貧血症狀
# prediction 1790年
# prediction 瑞士
# prediction 米盧斯
# prediction 1939年
# prediction 皇家自由醫院
# prediction 皇家自由醫院
# prediction 1973年
# prediction 八角大樓
# prediction 理事會
# prediction 副教務長
# prediction 中國民主建國會
# prediction 文化教育界高級人士
# prediction 工商企業家
# prediction 榮毅仁
# prediction 1945年
# prediction 國際聯盟
# prediction 58個
# prediction 凡爾賽條約
# prediction 1960年
# prediction 1968年
# prediction 外圍賽
# prediction 歐洲足球錦標賽
# prediction 西班牙
# prediction 抽籤
# prediction 1927年
# prediction 1955年
# prediction 法國
# prediction 蘇聯
# prediction 地區性國際政治組織
# prediction 非洲
# prediction 內蒙古自治區
# prediction 關內
# prediction 朝陽市
# prediction 四個
# prediction 國防大臣
# prediction 徵兵制
# prediction 波斯灣東南岸
# prediction 1960年代
# prediction 西方商業模式
# prediction 英國
# prediction 1852年
# prediction 很合理的稅制
# prediction 1966年
# prediction 1971年
# prediction 2006年
# prediction 七倍
# prediction 皇家法律
# prediction 142個
# prediction 紅線
# prediction 1947年
# prediction 其他族裔
# prediction 1960年
# prediction 法律制裁
# prediction 共和末期
# prediction 羅馬公民權
# prediction 奧古斯都
# prediction 銀幣
# prediction 百夫長
# prediction 河南
# prediction 2002年
# prediction 黃河鐵路公路大橋
# prediction 1952年
# prediction 美國哥倫比亞大學歸國碩士
# prediction 蕭樹滋
# prediction 何克抗
# prediction 李克東
# prediction 饅頭
# prediction 溫州人
# prediction 小籠饅頭
# prediction 重慶市
# prediction 丘陵地帶
# prediction 山地
# prediction 西德
# prediction 磚石
# prediction 反法西斯防衛牆
# prediction 柏林圍牆
# prediction 四個
# prediction 1949年
# prediction 1949年
# prediction 1961年
# prediction 東德領導人
# prediction 客座教授
# prediction 肝癌
# prediction 1978年
# prediction 1977年
# prediction 1978年
# prediction 國際奧委會第48屆年會
# prediction 中華人民共和國代表團
# prediction 楊虎城
# prediction 分離主義
# prediction 李烈鈞
# prediction 孔祥熙公館
# prediction 軍事委員會
# prediction 肝臟
# prediction 刺激劑
# prediction 麥角胺
# prediction 英國
# prediction 1713年
# prediction 奧地利
# prediction 中國鐵道部
# prediction 文化大革命
# prediction 陳玉昶
# prediction 人民日報
# prediction 香港站
# prediction 2005年
# prediction 博覽館站
# prediction 九龍站
# prediction
# prediction 劉邦
# prediction 淮河流域
# prediction 助餐三行動
# prediction 私立研究型大學
# prediction 班傑明富蘭克林
# prediction 穆爾電子工程學院
# prediction 第四
# prediction 唐朝
# prediction 劍橋大學
# prediction 92英畝
# prediction 獸醫學院
# prediction 雨水
# prediction 露點溫度
# prediction 土耳其
# prediction 貝爾格勒
# prediction 1941年
# prediction 1958年
# prediction 俄羅斯聯邦
# prediction 共和國元首
# prediction 第二次世界大戰
# prediction 中南海
# prediction 明代
# prediction 1406年
# prediction 北海
# prediction 袁世凱
# prediction 袁世凱
# prediction 中南海
# prediction 新華門
# prediction 1963年
# prediction 彰化縣
# prediction 2014年
# prediction 平原
# prediction 1959年
# prediction 花蓮市
# prediction 花蓮市
# prediction 四年
# prediction 市政會議
# prediction 加入歐盟
# prediction 基督教
# prediction 1403年
# prediction 723公里
# prediction 高加索山區
# prediction 150名
# prediction 俄羅斯
# prediction 農業
# prediction 計劃經濟
# prediction 2006年
# prediction 東鎮校
# prediction 關東地震
# prediction 1930年
# prediction 1933年
# prediction 九龍寨城
# prediction 九龍戰神
# prediction 1998年
# prediction 黃大仙區
# prediction 經濟拮据
# prediction 1917年
# prediction 一個月
# prediction 杭州
# prediction 1934年
# prediction 陳春鳳
# prediction 程程真
# prediction 廣州行營
# prediction 西班牙語
# prediction 83.4%
# prediction 黃河
# prediction 山地
# prediction 北宋
# prediction 修水
# prediction 49.2%
# prediction 41種
# prediction 54種
# prediction 喜馬拉雅山
# prediction 7095米
# prediction 喜馬拉雅山脈
# prediction 庚子賠款
# prediction 清華學堂
# prediction 1943年
# prediction 1897年
# prediction 瀕危物種
# prediction 恐龍
# prediction 金正恩
# prediction 社會主義市場經濟體制
# prediction 金正恩
# prediction 2009年
# prediction 金正恩
# prediction 第149位
# prediction 卡蓋拉河
# prediction 2006年
# prediction 公路網絡
# prediction 農村
# prediction 1974年
# prediction 鼓
# prediction 聯合國
# prediction 圖西族
# prediction 君主制
# prediction 特瓦族
# prediction 1999年
# prediction 彩電中心
# prediction 2010年
# prediction 央視網
# prediction 1988年
# prediction 2009年初
# prediction 消費者視爲是被動的
# prediction 所有有意義的文化產物
# prediction 針對特別一個文化來進行的學術研究
# prediction 58勝24負
# prediction 羅馬隊
# prediction 紐約尼克
# prediction 2003年
# prediction 61勝21負
# prediction 2004年
# prediction 真人
# prediction 道士
# prediction 全真派
# prediction 正一派
# prediction 英國
# prediction 托爾金
# prediction 邪惡
# prediction 芬蘭
# prediction 1914年
# prediction 1911年
# prediction 1815年
# prediction 1934年
# prediction 島上風光
# prediction 人權狀況
# prediction 20世紀
# prediction 清末民初
# prediction 王怡
# prediction 戶籍制度
# prediction 保護勞動者的合法權益
# prediction 文化大革命
# prediction 中華人民共和國外交部
# prediction 沙祖康
# prediction 汪洋
# prediction 中國大陸
# prediction 新聞法
# prediction 苦修隱居
# prediction 張作霖
# prediction 畜牧業
# prediction 集體勞動組件被個體勞動所取代
# prediction 原始社會解體後
# prediction 19世紀
# prediction 拿破崙
# prediction 改變土地產權制度
# prediction 1857年
# prediction 1862年
# prediction 將組織混亂的軍隊的指揮權掌握在自己手中
# prediction 1870年
# prediction 德意志帝國
# prediction 1873年
# prediction 1850年
# prediction 普選權的保護者
# prediction 穩固自己的地位
# prediction 中華人民共和國
# prediction 2000年
# prediction 戰國時期
# prediction 5月
# prediction 道教
# prediction 加拿大
# prediction 問你伯
# prediction 博湖
# prediction 冰河時期
# prediction 用以製造箭頭
# prediction 1611年
# prediction 蘇維埃俄國
# prediction 1987年
# prediction 航空運輸
# prediction 空鐵聯運
# prediction 航空運輸
# prediction 2395平方公里
# prediction 麗江專區
# prediction 200米
# prediction 古裝風箏場
# prediction 卡賓槍
# prediction 可以連發
# prediction 中國大陸
# prediction 第一次世界大戰
# prediction 德國
# prediction 德國
# prediction 1980年
# prediction 陝西省
# prediction 長江流域
# prediction 北
# prediction 溫帶季風氣候
# prediction 常綠闊葉木本植物
# prediction 蜀道難
# prediction 1912年
# prediction 關東大地震
# prediction 第一次世界大戰
# prediction 日治時期
# prediction 1927年
# prediction 盧溝橋事變
# prediction 太平洋戰爭
# prediction 修改日美安保條約
# prediction 修改日美安保條約
# prediction 患上喉癌
# prediction 田中角榮
# prediction 貪污醜聞
# prediction 一連串的醜聞
# prediction 日本社會黨
# prediction 平成時代
# prediction 飛鳥時代
# prediction 奠定中國式的官僚制度的基礎
# prediction 645年
# prediction 天武天皇時期
# prediction 源平合戰
# prediction 149年
# prediction 北條時政
# prediction 女媧
# prediction 女媧善於補天
# prediction 人類始祖
# prediction 物理化學
# prediction 化學物理學
# prediction 1977年
# prediction 北美洲
# prediction 空氣稀薄的山區
# prediction 1540年
# prediction 葡萄牙
# prediction 方濟各沙勿略
# prediction 印度
# prediction 朱棣
# prediction 和談破裂
# prediction 河北戰事不利
# prediction 七月初十
# prediction 保定
# prediction 徐氏
# prediction 873人
# prediction 恢復了洪武年間廢除的錦衣衛
# prediction 擊敗武高
# prediction 朱權
# prediction 李景隆大軍
# prediction 平安
# prediction 潮州體育館
# prediction 籃球
# prediction 潮州市體委
# prediction 中國四大古橋
# prediction 2001年
# prediction 亞熱帶海洋性季風氣候
# prediction 李青
# prediction 潮州
# prediction 人多地少
# prediction 9800日元
# prediction 5800日元
# prediction 1995年
# prediction 民族主義
# prediction 68億
# prediction 哈里發
# prediction 賓夕法尼亞州
# prediction 世界鋼都
# prediction 2006年
# prediction 美式橄欖球
# prediction 石灰石
# prediction 戰爭對鋼鐵的需求量猛增
# prediction 皮之寶
# prediction 文藝復興時期
# prediction 瑞士近衛隊
# prediction 朱爾雷邦德
# prediction 西班牙
# prediction 積極進攻
# prediction 譚詠麟
# prediction 南海
# prediction 甘泉島
# prediction 中越西沙海戰
# prediction 日本
# prediction 中華民國
# prediction 白崇禧
# prediction 第二次國共內戰失利
# prediction 1950年
# prediction 美國公路邊的加油站附屬小店
# prediction 1930年
# prediction 都市化程度高
# prediction 阿斯頓公園球場
# prediction 拉素
# prediction 1987年
# prediction 5000000美元
# prediction 1993年
# prediction 1998年
# prediction 嘉靖九年
# prediction 三層
# prediction 祈年殿
# prediction 七星石
# prediction 巴西
# prediction 拉丁美洲
# prediction 1859年
# prediction 物種的演化是通過自然選擇的方式實現的
# prediction 住宅區
# prediction 二次大戰
# prediction 火水燈
# prediction 土瓜灣道
# prediction 2012年
# prediction 25個
# prediction 老羅斯福
# prediction 岳飛
# prediction 張俊
# prediction 完顏宗弼
# prediction 後勤的問題
# prediction 始終不能
# prediction 趙鼎
# prediction 岳家軍
# prediction 莫須有
# prediction 儒家
# prediction 河北省
# prediction 5月
# prediction 公元前216年
# prediction 大興區
# prediction 磨砂
# prediction 甲午戰爭
# prediction 消極政策
# prediction 馬關條約
# prediction 50年
# prediction 本省人
# prediction 1980年代
# prediction 1988年
# prediction 電腦主機板
# prediction 1996年
# prediction 李登輝
# prediction 連戰
# prediction 多元文化主義
# prediction 葡萄牙語
# prediction 海拔高度
# prediction 黑潮洋流
# prediction 1972年
# prediction 烏山頭水庫
# prediction 1684年
# prediction 戰略地位
# prediction 1960年代
# prediction 擺脫石油危機
# prediction 1987年
# prediction 中國國民黨
# prediction 日治時期
# prediction 21個
# prediction 中華人民共和國
# prediction 社會福利基金會
# prediction 臺灣醫界聯盟基金會
# prediction 2007年
# prediction 中華民國國際經濟合作協會
# prediction 臺灣亞太發展基金會
# prediction 1995年
# prediction 中秋
# prediction 元宵節
# prediction 臺灣廟宇香火鼎盛
# prediction 清治時期
# prediction 四面環海
# prediction 珍珠奶茶
# prediction 英語
# prediction 1932年
# prediction 與漢人通婚
# prediction 布袋戲
# prediction 16世紀
# prediction 葡萄牙
# prediction 27個
# prediction 日本文化
# prediction 二戰
# prediction 反共抗俄
# prediction 中華隊
# prediction 雅典
# prediction 巧固球
# prediction 法國
# prediction 繁殖
# prediction 公共衛生問題
# prediction 飛鳥與飛機相撞造成的飛行安全事故
# prediction 100億美元
# prediction 四川省
# prediction 普賢菩薩
# prediction 粵語
# prediction 北方官話
# prediction 漢朝
# prediction 瑞士
# prediction 奧地利
# prediction 阿爾卑斯山脈
# prediction 挪威
# prediction 1948年
# prediction 德國
# prediction 倫敦
# prediction 英國
# prediction 德國
# prediction 電腦控制技術
# prediction 國家郵政局
# prediction 1949年
# prediction 1995年
# prediction 26名
# prediction 1972年
# prediction 1972年
# prediction 田納西州
# prediction 1998年
# prediction 高爾
# prediction 2006年
# prediction 英國
# prediction 物理學
# prediction 1984年
# prediction 1930年
# prediction 父親
# prediction 新南威爾士大學
# prediction 狄拉克
# prediction 科本哈根
# prediction 真空極化
# prediction 1930年
# prediction 不想出名
# prediction 認知花店磁場中的起點
# prediction 1937年
# prediction 佛教
# prediction 天道
# prediction 到達涅槃的境界
# prediction 巨大捕食壓力
# prediction 加州
# prediction 洋務運動
# prediction 馮桂芬
# prediction 穆斯林
# prediction 伊斯蘭黃金時代
# prediction 十字軍東征
# prediction 中國
# prediction 新柏拉圖主義
# prediction 科學革命
# prediction 1687年
# prediction 劉銘傳
# prediction 舊金山和約
# prediction 毛澤東
# prediction 支持日本關于歸還領土的要求是中國的一貫政策
# prediction 中國大陸
# prediction 公元三世紀
# prediction 班固
# prediction 1992年
# prediction 周英撤離中國大陸
# prediction 2005年
# prediction 1994年
# prediction 普京
# prediction 蘇聯
# prediction 哭泣
# prediction 18小時
# prediction 食物中毒
# prediction 經濟海域
# prediction 美國
# prediction 英國
# prediction 下議院
# prediction 五年
# prediction 不信任案
# prediction 愛爾蘭
# prediction 法蘭西王國
# prediction 愛德華三世
# prediction 國內的貴族政治與神職人員影響重大
# prediction 人民選舉
# prediction 授權的程序
# prediction 宋代
# prediction 伊斯蘭教
# prediction 北高加索
# prediction 一二八事變
# prediction 1937年
# prediction 上海北站升格爲上海總站。
# prediction 1983年
# prediction 1984年
# prediction 江澤民
# prediction 新客站
# prediction 1987年
# prediction 華東建築設計院
# prediction 軟席候車室
# prediction 避免購票人羣與進出站人羣的對衝
# prediction 福建籍
# prediction 三成
# prediction 新加坡
# prediction 2004年
# prediction 北郊
# prediction 金朝陽集團
# prediction 香港
# prediction 香港
# prediction 炮台山
# prediction 祖籍
# prediction 北宋
# prediction 福建
# prediction 六七暴動
# prediction 1950年
# prediction 深圳
# prediction 荃灣新市鎮
# prediction 不毛之地
# prediction 蔬菜
# prediction 九龍東
# prediction 廣東
# prediction 1945年
# prediction 中國新政府沒收私人財產
# prediction 灣仔區
# prediction 上環
# prediction 潮州人
# prediction 語言相約
# prediction 英國
# prediction 郭春秧
# prediction 閩東人
# prediction 陳隆基
# prediction 福州
# prediction 太平天國戰亂
# prediction 北角
# prediction 灣仔發展商業區
# prediction 2012年
# prediction 色情行業
# prediction 山水瘦肉粥街
# prediction 1980年代
# prediction 尖沙咀的金巴利街
# prediction 13%
# prediction 青龍教
# prediction 男
# prediction 574800人
# prediction 1161
# prediction 1954年
# prediction 太平號驅逐艦，遭解放軍魚雷快艇集成
# prediction 臺灣
# prediction 金剛計劃
# prediction 蘇聯政府
# prediction 2月24日
# prediction 太平洋
# prediction 臺東市
# prediction 鯉魚山
# prediction 劉銘傳
# prediction 1976年
# prediction 主席
# prediction 全國人民代表大會進行補選
# prediction 1982年
# prediction 雅克考文
# prediction 新石器時代
# prediction 白朗軍以中華民國伏旱，桃園軍的旗幟輾轉作戰
# prediction 民國18年
# prediction 民國16年
# prediction 民國34年
# prediction 直行向北發展，向南防禦
# prediction 晉冀魯豫野戰軍
# prediction 湖北省
# prediction 高石碑鎮
# prediction 呂亮
# prediction 南京
# prediction 反間計
# prediction 腹背受敵
# prediction 軍功
# prediction 嘉靖七年
# prediction 高原
# prediction 破火山口
# prediction 南極
# prediction 岩石圈受到壓縮應力
# prediction 聯邦總理
# prediction 不能
# prediction 1871年
# prediction 互相制衡作用
# prediction 立法
# prediction 約翰洛克
# prediction 美國
# prediction 國民議會
# prediction 1974年
# prediction 防止國家權力被濫用，尤其是被針對，用於對反對派的誣告陷害
# prediction 孫中山
# prediction 考試
# prediction 2005年
# prediction 國防部
# prediction 6萬人
# prediction 中華人民共和國
# prediction 安徽省
# prediction 一處
# prediction 巴丹島
# prediction 美國工業工程師學會
# prediction 讓產量得到提高
# prediction 產業工程
# prediction 工業工程
# prediction 南華早報
# prediction 1913年
# prediction 1987年
# prediction 日本
# prediction 王向偉
# prediction 2006年
# prediction 中國網通集團
# prediction 阿里，不哥
# prediction 阿里不哥兵敗投降
# prediction 易經
# prediction 元世祖
# prediction 1275年
# prediction 颱風來襲
# prediction 解決財政問題
# prediction 1260年
# prediction 忽必烈
# prediction 1279年
# prediction 太虛大師
# prediction 南京
# prediction 福建
# prediction 徹底掃除北元勢力
# prediction 1388年
# prediction 農村
# prediction 中書省
# prediction 1260年
# prediction 1238年
# prediction 法國
# prediction 1316年
# prediction 馬可波羅遊記
# prediction 1217年
# prediction 探馬赤軍
# prediction 官田
# prediction 河北
# prediction 自然災害
# prediction 畜牧業
# prediction 加金絲織物
# prediction 黃道婆
# prediction 官營政策
# prediction 杭州
# prediction 宋元時期
# prediction 元朝
# prediction 丘處機
# prediction 伊斯蘭教
# prediction 色目人擅長理財
# prediction 王羲之
# prediction 草書
# prediction 景德鎮
# prediction 元代
# prediction 貝南
# prediction 約魯巴
# prediction 阿達馬瓦高原
# prediction 熱帶草原氣候
# prediction 石油出口
# prediction 北京
# prediction 燕京大學
# prediction 工學院
# prediction 美國
# prediction 中華人民共和國
# prediction 2005年
# prediction 舊金山和約
# prediction 1970年代
# prediction 新加坡
# prediction 鼓勵內外廠商投資具體電路，電腦等高科技產業
# prediction 2002年
# prediction 1970年代
# prediction 老人安養，餘額托架
# prediction 1970年代
# prediction 臺灣原住民
# prediction 1947年
# prediction 1950年代
# prediction 高雄市
# prediction 江南岸
# prediction 1988年
# prediction 19世紀
# prediction 給予印度人在中央及省級立法院有限的權力
# prediction 奧斯曼伊斯蘭政權
# prediction 阿姆利則慘案
# prediction 日本
# prediction 後勤補給的中斷
# prediction 引入刑事司法法案
# prediction 媒體的輿論
# prediction 2011年
# prediction 1960年代
# prediction 1980年代
# prediction 北海艦隊
# Completed! Result is in result.csv

# %%
from google.colab import files
files.download('/content/result.csv')

# %%
import pandas as pd
pred = pd.read_csv('/content/result.csv',index_col='ID')
pred
# Out:
#         Answer
# ID
# 0         白色羽毛
# 1       《諸羅縣志》
# 2           袁晁
# 3       柏林陸軍學院
# 4     一局特殊的決勝局
# ...        ...
# 4952     媒體的輿論
# 4953     2011年
# 4954    1960年代
# 4955    1980年代
# 4956      北海艦隊
#
# [4957 rows x 1 columns]

# %%
# 0.84832 
# max_q_len = 60
# 400, 350
